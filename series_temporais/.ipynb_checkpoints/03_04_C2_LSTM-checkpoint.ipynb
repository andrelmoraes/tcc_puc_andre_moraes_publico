# %% [markdown]
# # Modelo LSTM para predição
#
# ---
#
#
# ___

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import math
import requests
import json
import os
import statsmodels.api as sm
import tensorflow as tf
from pandas import concat

from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore")

from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)

import math

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## 1. Importando os datasets

# %%
dataset_cluster2_series = pd.read_csv("datasets//dataset_cluster2_series.csv", header=0, index_col=0)
dataset_cluster2_validacao = pd.read_csv("datasets//dataset_cluster2_validation.csv", header=0, index_col=0)

# %%
dataset_cluster2_series.head(20)
# Out:
#                      indice_pimpf  ipca  taxa_selic  taxa_cambio   ibcbr  \
# mes
# 2004-01-01 00:00:00         104.0  0.76       16.32       136.19   98.59
# 2004-02-01 00:00:00         103.1  0.61       16.30       139.84   99.45
# 2004-03-01 00:00:00         113.0  0.47       16.19       138.89  111.98
# 2004-04-01 00:00:00         107.8  0.37       15.96       138.85  107.36
# 2004-05-01 00:00:00         108.9  0.51       15.77       148.25  106.03
# 2004-06-01 00:00:00         113.1  0.71       15.80       149.04  107.00
# 2004-07-01 00:00:00         110.9  0.91       15.77       143.11  111.47
# 2004-08-01 00:00:00         113.2  0.69       15.86       140.62  110.65
# 2004-09-01 00:00:00         107.6  0.33       16.09       135.23  109.21
# 2004-10-01 00:00:00         103.8  0.44       16.41       133.55  108.89
# 2004-11-01 00:00:00         108.6  0.69       16.96       129.60  109.59
# 2004-12-01 00:00:00         108.9  0.86       17.50       124.90  107.56
# 2005-01-01 00:00:00         105.4  0.58       17.93       123.29  103.52
# 2005-02-01 00:00:00         103.3  0.59       18.47       118.92  104.00
# 2005-03-01 00:00:00         101.0  0.61       18.97       124.02  115.42
# 2005-04-01 00:00:00         105.4  0.87       19.32       118.03  112.35
# 2005-05-01 00:00:00         104.9  0.49       19.61       111.59  110.86
# 2005-06-01 00:00:00         105.6 -0.02       19.75       109.88  111.50
# 2005-07-01 00:00:00          99.9  0.25       19.72       108.29  113.15
# 2005-08-01 00:00:00         103.5  0.17       19.75       108.07  115.15
#
#                       arrecadacao
# mes
# 2004-01-01 00:00:00  6.709728e+09
# 2004-02-01 00:00:00  5.844144e+09
# 2004-03-01 00:00:00  5.757594e+09
# 2004-04-01 00:00:00  7.872113e+09
# 2004-05-01 00:00:00  7.156122e+09
# 2004-06-01 00:00:00  7.048868e+09
# 2004-07-01 00:00:00  8.450281e+09
# 2004-08-01 00:00:00  7.101401e+09
# 2004-09-01 00:00:00  7.709141e+09
# 2004-10-01 00:00:00  8.787191e+09
# 2004-11-01 00:00:00  6.845525e+09
# 2004-12-01 00:00:00  7.922471e+09
# 2005-01-01 00:00:00  9.171569e+09
# 2005-02-01 00:00:00  6.970914e+09
# 2005-03-01 00:00:00  7.356128e+09
# 2005-04-01 00:00:00  9.611372e+09
# 2005-05-01 00:00:00  7.820801e+09
# 2005-06-01 00:00:00  7.480434e+09
# 2005-07-01 00:00:00  8.976327e+09
# 2005-08-01 00:00:00  7.829660e+09

# %%
dataset_cluster2_validacao.head(20)
# Out:
#                      indice_pimpf  ipca  taxa_selic  taxa_cambio   ibcbr  \
# mes
# 2020-01-01 00:00:00         101.5  0.21        4.40       116.16  133.60
# 2020-02-01 00:00:00          99.6  0.25        4.19       121.84  134.63
# 2020-03-01 00:00:00          95.7  0.07        3.95       136.52  136.72
# 2020-04-01 00:00:00          68.2 -0.31        3.65       147.97  119.13
# 2020-05-01 00:00:00          76.2 -0.38        3.01       157.50  119.79
# 2020-06-01 00:00:00          90.3  0.26        2.58       145.32  126.18
# 2020-07-01 00:00:00          96.8  0.36        2.15       148.27  135.82
# 2020-08-01 00:00:00          97.5  0.24        1.94       153.47  135.50
# 2020-09-01 00:00:00         104.9  0.64        1.90       150.84  137.14
# 2020-10-01 00:00:00         101.2  0.86        1.90       155.93  139.62
# 2020-11-01 00:00:00         104.1  0.89        1.90       149.31  138.10
# 2020-12-01 00:00:00         110.2  1.35        1.90       139.66  139.53
#
#                       arrecadacao
# mes
# 2020-01-01 00:00:00  3.553139e+10
# 2020-02-01 00:00:00  2.220378e+10
# 2020-03-01 00:00:00  1.932962e+10
# 2020-04-01 00:00:00  2.014531e+10
# 2020-05-01 00:00:00  1.314481e+10
# 2020-06-01 00:00:00  1.234030e+10
# 2020-07-01 00:00:00  1.983441e+10
# 2020-08-01 00:00:00  2.206463e+10
# 2020-09-01 00:00:00  2.362301e+10
# 2020-10-01 00:00:00  3.264090e+10
# 2020-11-01 00:00:00  2.663530e+10
# 2020-12-01 00:00:00  2.910259e+10

# %% [markdown]
# ## 2. Preparando o dataset para a rede neural LSTM

# %%
serie_cluster2 = np.array(dataset_cluster2_series)

# %%
print(serie_cluster2)
# Out:
# [[1.04000000e+02 7.60000000e-01 1.63200000e+01 1.36190000e+02
#   9.85900000e+01 6.70972820e+09]
#  [1.03100000e+02 6.10000000e-01 1.63000000e+01 1.39840000e+02
#   9.94500000e+01 5.84414384e+09]
#  [1.13000000e+02 4.70000000e-01 1.61900000e+01 1.38890000e+02
#   1.11980000e+02 5.75759405e+09]
#  ...
#  [1.02500000e+02 1.00000000e-01 5.38000000e+00 1.16420000e+02
#   1.42760000e+02 3.04153471e+10]
#  [9.94000000e+01 5.10000000e-01 4.90000000e+00 1.17740000e+02
#   1.38840000e+02 2.43810682e+10]
#  [1.00600000e+02 1.15000000e+00 4.59000000e+00 1.14940000e+02
#   1.37540000e+02 2.67613395e+10]]

# %%
validacao_cluster2 = np.array(dataset_cluster2_validacao)

# %%
print(validacao_cluster2)
# Out:
# [[ 1.01500000e+02  2.10000000e-01  4.40000000e+00  1.16160000e+02
#    1.33600000e+02  3.55313926e+10]
#  [ 9.96000000e+01  2.50000000e-01  4.19000000e+00  1.21840000e+02
#    1.34630000e+02  2.22037820e+10]
#  [ 9.57000000e+01  7.00000000e-02  3.95000000e+00  1.36520000e+02
#    1.36720000e+02  1.93296182e+10]
#  [ 6.82000000e+01 -3.10000000e-01  3.65000000e+00  1.47970000e+02
#    1.19130000e+02  2.01453135e+10]
#  [ 7.62000000e+01 -3.80000000e-01  3.01000000e+00  1.57500000e+02
#    1.19790000e+02  1.31448091e+10]
#  [ 9.03000000e+01  2.60000000e-01  2.58000000e+00  1.45320000e+02
#    1.26180000e+02  1.23402953e+10]
#  [ 9.68000000e+01  3.60000000e-01  2.15000000e+00  1.48270000e+02
#    1.35820000e+02  1.98344139e+10]
#  [ 9.75000000e+01  2.40000000e-01  1.94000000e+00  1.53470000e+02
#    1.35500000e+02  2.20646283e+10]
#  [ 1.04900000e+02  6.40000000e-01  1.90000000e+00  1.50840000e+02
#    1.37140000e+02  2.36230069e+10]
#  [ 1.01200000e+02  8.60000000e-01  1.90000000e+00  1.55930000e+02
#    1.39620000e+02  3.26409023e+10]
#  [ 1.04100000e+02  8.90000000e-01  1.90000000e+00  1.49310000e+02
#    1.38100000e+02  2.66353020e+10]
#  [ 1.10200000e+02  1.35000000e+00  1.90000000e+00  1.39660000e+02
#    1.39530000e+02  2.91025891e+10]]

# %%
np.random.seed(10)

# %% [markdown]
# ### 2.1 Normalizando a escala do dataset

# %%
## Criando um scaler para o campo de saída


scaler_in = MinMaxScaler(feature_range=(0, 1))
scaler_out = MinMaxScaler(feature_range=(0, 1))

serie_cluster2 = scaler_in.fit_transform(serie_cluster2)
validacao_cluster2 = scaler_out.fit_transform(validacao_cluster2)



# Criando um scaler específico para a 

arrecadacao = np.array(dataset_cluster2_series['arrecadacao'])

arrecadacao = arrecadacao.reshape(-1,1)

arrecadacao = scaler_out.fit_transform(arrecadacao)

print(arrecadacao)
# Out:
# [[0.03258086]
#  [0.00296163]
#  [0.        ]
#  [0.07235622]
#  [0.04785592]
#  [0.0441858 ]
#  [0.09214043]
#  [0.04598342]
#  [0.06677954]
#  [0.10366908]
#  [0.03722766]
#  [0.07407942]
#  [0.11682201]
#  [0.04151831]
#  [0.05469985]
#  [0.13187154]
#  [0.07060039]
#  [0.05895345]
#  [0.11014108]
#  [0.07090353]
#  [0.07700231]
#  [0.16416674]
#  [0.09744627]
#  [0.11213089]
#  [0.12486865]
#  [0.05797586]
#  [0.06387974]
#  [0.17741105]
#  [0.08167977]
#  [0.11999606]
#  [0.16436577]
#  [0.12618198]
#  [0.14139686]
#  [0.21211499]
#  [0.09045643]
#  [0.12425117]
#  [0.16237571]
#  [0.08432679]
#  [0.10792445]
#  [0.20161983]
#  [0.14222492]
#  [0.098757  ]
#  [0.17971434]
#  [0.1275581 ]
#  [0.19000759]
#  [0.22272385]
#  [0.16499588]
#  [0.20578432]
#  [0.26222916]
#  [0.15031711]
#  [0.17221395]
#  [0.2967193 ]
#  [0.17138792]
#  [0.19515643]
#  [0.35349327]
#  [0.24176565]
#  [0.24450835]
#  [0.45168363]
#  [0.20395508]
#  [0.12147409]
#  [0.2025613 ]
#  [0.04036885]
#  [0.10351295]
#  [0.18653692]
#  [0.11094218]
#  [0.16882412]
#  [0.24208447]
#  [0.12660772]
#  [0.1675929 ]
#  [0.29620439]
#  [0.23221715]
#  [0.21866833]
#  [0.32009209]
#  [0.16525108]
#  [0.19922473]
#  [0.35309403]
#  [0.23552611]
#  [0.22364249]
#  [0.29902133]
#  [0.21253082]
#  [0.23641584]
#  [0.32825231]
#  [0.24197444]
#  [0.26418516]
#  [0.42201073]
#  [0.19703786]
#  [0.24879731]
#  [0.39047809]
#  [0.25103481]
#  [0.27781989]
#  [0.39413867]
#  [0.27683942]
#  [0.28167543]
#  [0.43997682]
#  [0.27907784]
#  [0.27588717]
#  [0.50856809]
#  [0.21582087]
#  [0.24490927]
#  [0.44600058]
#  [0.27387218]
#  [0.26646429]
#  [0.41498876]
#  [0.26147179]
#  [0.29607455]
#  [0.4213769 ]
#  [0.30487599]
#  [0.30700389]
#  [0.55540876]
#  [0.20210447]
#  [0.30069994]
#  [0.46783811]
#  [0.32937723]
#  [0.31052485]
#  [0.45311248]
#  [0.3302779 ]
#  [0.33054256]
#  [0.50319381]
#  [0.35006472]
#  [0.4329728 ]
#  [0.6152642 ]
#  [0.30579004]
#  [0.34782465]
#  [0.49607412]
#  [0.32293873]
#  [0.34019919]
#  [0.44541205]
#  [0.33101109]
#  [0.33743148]
#  [0.55818561]
#  [0.46862513]
#  [0.38020963]
#  [0.59332449]
#  [0.26732763]
#  [0.34797445]
#  [0.50013365]
#  [0.3408367 ]
#  [0.35119806]
#  [0.52161009]
#  [0.4111889 ]
#  [0.39954949]
#  [0.4620382 ]
#  [0.35096198]
#  [0.37276951]
#  [0.54297166]
#  [0.27362894]
#  [0.31985313]
#  [0.3581235 ]
#  [0.31769925]
#  [0.29420823]
#  [0.35649077]
#  [0.28608499]
#  [0.31130499]
#  [0.37544671]
#  [0.35434155]
#  [0.37017729]
#  [0.5474707 ]
#  [0.25461801]
#  [0.32480474]
#  [0.50844907]
#  [0.32315812]
#  [0.32476463]
#  [0.42447718]
#  [0.4093634 ]
#  [0.42071698]
#  [0.5911202 ]
#  [0.57707546]
#  [0.49367377]
#  [0.78511854]
#  [0.39374663]
#  [0.47501422]
#  [0.68403328]
#  [0.46281862]
#  [0.47631805]
#  [0.79333424]
#  [0.5047974 ]
#  [0.66364286]
#  [0.90203719]
#  [0.68450761]
#  [0.70842886]
#  [1.        ]
#  [0.53519485]
#  [0.57174429]
#  [0.85551692]
#  [0.5973734 ]
#  [0.63027567]
#  [0.9416527 ]
#  [0.69651853]
#  [0.6121431 ]
#  [0.84375793]
#  [0.63727234]
#  [0.71872229]]

# %%
print(serie_cluster2)
# Out:
# [[0.58379888 0.63870968 0.7737467  0.85310928 0.         0.03258086]
#  [0.55865922 0.54193548 0.77242744 0.8948331  0.01606276 0.00296163]
#  [0.83519553 0.4516129  0.7651715  0.88397348 0.25009339 0.        ]
#  ...
#  [0.54189944 0.21290323 0.05211082 0.62711477 0.82499066 0.84375793]
#  [0.45530726 0.47741935 0.02044855 0.64220393 0.75177437 0.63727234]
#  [0.48882682 0.89032258 0.         0.61019662 0.72749346 0.71872229]]

# %%
print(validacao_cluster2)
# Out:
# [[0.79285714 0.34104046 1.         0.         0.70619815 1.        ]
#  [0.74761905 0.36416185 0.916      0.13739719 0.75646657 0.4253135 ]
#  [0.6547619  0.26011561 0.82       0.49250121 0.85846755 0.30137957]
#  [0.         0.04046243 0.7        0.76947267 0.         0.33655235]
#  [0.19047619 0.         0.444      1.         0.03221083 0.03469063]
#  [0.52619048 0.3699422  0.272      0.7053701  0.34407028 0.        ]
#  [0.68095238 0.42774566 0.1        0.77672956 0.81454368 0.32314636]
#  [0.69761905 0.3583815  0.016      0.90251572 0.79892631 0.41931319]
#  [0.87380952 0.58959538 0.         0.83889695 0.87896535 0.48651047]
#  [0.78571429 0.71676301 0.         0.96202225 1.         0.87536207]
#  [0.8547619  0.73410405 0.         0.80188679 0.92581747 0.61640062]
#  [1.         1.         0.         0.5684567  0.99560761 0.72279002]]

# %% [markdown]
# ### 2.2 Convertendo o array em um modelo de dados 3D para entrada na rede LSTM
#
# ---
# Créditos: https://machinelearningmastery.com/convert-time-series-supervised-learning-problem-python/
#
# Para fazer a predição, utilizei os 12 primeiros meses para predizer o seguinte. Com isso, o dataset perde 12 meses, uma vez que os 11 primeiros meses não possuem 12 meses anteriores e o último mês não possui valor conhecido da arrecadação do mês subsequente.
#
# ___

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
 
raw = DataFrame()
raw['ob1'] = [x for x in range(10)]
raw['ob2'] = [x for x in range(50, 60)]
# values = raw.values
values = pd.DataFrame(serie_cluster2).values
serie_cluster2_prepared = series_to_supervised(values,12)
print(serie_cluster2_prepared)
# Out:
#      var1(t-12)  var2(t-12)  var3(t-12)  var4(t-12)  var5(t-12)  var6(t-12)  \
# 12     0.583799    0.638710    0.773747    0.853109    0.000000    0.032581
# 13     0.558659    0.541935    0.772427    0.894833    0.016063    0.002962
# 14     0.835196    0.451613    0.765172    0.883973    0.250093    0.000000
# 15     0.689944    0.387097    0.750000    0.883516    0.163803    0.072356
# 16     0.720670    0.477419    0.737467    0.990969    0.138962    0.047856
# ..          ...         ...         ...         ...         ...         ...
# 187    0.522346    0.090323    0.119393    0.593850    0.835637    0.504797
# 188    0.399441    0.458065    0.119393    0.651120    0.696302    0.663643
# 189    0.483240    0.438710    0.119393    0.533265    0.768771    0.902037
# 190    0.427374    0.012903    0.119393    0.535894    0.728988    0.684508
# 191    0.326816    0.245161    0.119393    0.563443    0.704894    0.708429
#
#      var1(t-11)  var2(t-11)  var3(t-11)  var4(t-11)  ...  var3(t-1)  \
# 12     0.558659    0.541935    0.772427    0.894833  ...   0.851583
# 13     0.835196    0.451613    0.765172    0.883973  ...   0.879947
# 14     0.689944    0.387097    0.750000    0.883516  ...   0.915567
# 15     0.720670    0.477419    0.737467    0.990969  ...   0.948549
# 16     0.837989    0.606452    0.739446    1.000000  ...   0.971636
# ..          ...         ...         ...         ...  ...        ...
# 187    0.399441    0.458065    0.119393    0.651120  ...   0.119393
# 188    0.483240    0.438710    0.119393    0.533265  ...   0.086412
# 189    0.427374    0.012903    0.119393    0.535894  ...   0.073879
# 190    0.326816    0.245161    0.119393    0.563443  ...   0.052111
# 191    0.402235    0.354839    0.119393    0.516918  ...   0.020449
#
#      var4(t-1)  var5(t-1)  var6(t-1)   var1(t)   var2(t)   var3(t)   var4(t)  \
# 12    0.724051   0.167538   0.074079  0.622905  0.522581  0.879947  0.705647
# 13    0.705647   0.092081   0.116822  0.564246  0.529032  0.915567  0.655693
# 14    0.655693   0.101046   0.041518  0.500000  0.541935  0.948549  0.713992
# 15    0.713992   0.314344   0.054700  0.622905  0.709677  0.971636  0.645519
# 16    0.645519   0.257004   0.131872  0.608939  0.464516  0.990765  0.571902
# ..         ...        ...        ...       ...       ...       ...       ...
# 187   0.525263   0.827979   0.941653  0.413408  0.219355  0.086412  0.602080
# 188   0.602080   0.806500   0.696519  0.519553  0.122581  0.073879  0.636603
# 189   0.636603   0.741688   0.612143  0.541899  0.212903  0.052111  0.627115
# 190   0.627115   0.824991   0.843758  0.455307  0.477419  0.020449  0.642204
# 191   0.642204   0.751774   0.637272  0.488827  0.890323  0.000000  0.610197
#
#       var5(t)   var6(t)
# 12   0.092081  0.116822
# 13   0.101046  0.041518
# 14   0.314344  0.054700
# 15   0.257004  0.131872
# 16   0.229174  0.070600
# ..        ...       ...
# 187  0.806500  0.696519
# 188  0.741688  0.612143
# 189  0.824991  0.843758
# 190  0.751774  0.637272
# 191  0.727493  0.718722
#
# [180 rows x 78 columns]

# %% [markdown]
# ### 2.3 Dividindo o dataset em sets de treino e teste

# %%
# split into train and test sets
values = serie_cluster2_prepared.values
# Base de treino com 144 meses
periodo_treino = 156
train = values[:periodo_treino, :]
test = values[periodo_treino:, :]

# %%
print(train)
# Out:
# [[0.58379888 0.63870968 0.7737467  ... 0.70564701 0.09208069 0.11682201]
#  [0.55865922 0.54193548 0.77242744 ... 0.65569273 0.10104595 0.04151831]
#  [0.83519553 0.4516129  0.7651715  ... 0.71399177 0.31434442 0.05469985]
#  ...
#  [0.27374302 0.31612903 0.62401055 ... 0.36362597 0.69760926 0.5911202 ]
#  [0.41620112 0.26451613 0.61411609 ... 0.38443073 0.68210684 0.57707546]
#  [0.44134078 0.34193548 0.59762533 ... 0.38968907 0.69648861 0.49367377]]

# %%
print(test)
# Out:
# [[0.48324022 0.39354839 0.56596306 ... 0.36636946 0.62457975 0.78511854]
#  [0.44413408 0.36129032 0.54287599 ... 0.37802926 0.58386253 0.39374663]
#  [0.5027933  0.30967742 0.49868074 ... 0.39140375 0.80388495 0.47501422]
#  ...
#  [0.48324022 0.43870968 0.11939314 ... 0.62711477 0.82499066 0.84375793]
#  [0.4273743  0.01290323 0.11939314 ... 0.64220393 0.75177437 0.63727234]
#  [0.32681564 0.24516129 0.11939314 ... 0.61019662 0.72749346 0.71872229]]

# %%
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (156, 1, 77) (156,) (24, 1, 77) (24,)

# %% [markdown]
# ## 3. Implementando o modelo LSTM
#
# ---
#
# Notas da modelagem da rede neural recorrente:
#
# 1. O aumento do número de épocas não teve efeito na convergência da função loss.
#
# 100 épocas:
#
# ![image.png](modelo_lstm_1_100_epochs.png)
#
# 500 épocas:
#
# ![image.png](modelo_lstm_1_500_epochs.png)
#
# 1000 épocas:
#
# ![image.png](modelo_lstm_1_1000_epochs.png)
#
#
#
# 1. O aumento do número de batchs (inteiros relativos ao tamanho da amostra de treino: 144) teve efeito na convergência da função loss.
#
#
# Batch 12:
#
#
# ![image.png](modelo_lstm_1_batch_12.png)
#
# Batch 24:
#
#
# ![image.png](modelo_lstm_1_batch_24.png)
#
#
# Batch 36:
#
#
# ![image.png](modelo_lstm_1_batch_36.png)
#
#
#
# Batch 48:
#
#
# ![image.png](modelo_lstm_1_batch_48.png)
#
#
# Batch 60:
#
#
# ![image.png](modelo_lstm_1_batch_60.png)
#
#
# Batch 72:
#
#
# ![image.png](modelo_lstm_1_batch_72.png)
#
#
# Batch 144:
#
#
# ![image.png](modelo_lstm_1_batch_144.png)

# %% [markdown]
# Modelo 1:
#
# `
# model = Sequential()
# model.add(LSTM(50, return_sequences = True, input_shape=(train_X.shape[1], train_X.shape[2])))
# model.add(Dropout(0.2))
# model.add(Dense(1))
# model.compile(loss='mae', optimizer='adam')`
#
# `history = model.fit(train_X, train_y, epochs=100, batch_size=72,
#                     validation_data=(test_X, test_y), verbose=2, shuffle=False)`
#
# Resultado:
#
# ![image.png](modelo_lstm_1.png)
#
# Modelo 2:
#
# `model = Sequential()
# model.add(LSTM(50, return_sequences = True, input_shape=(train_X.shape[1], train_X.shape[2])))
# model.add(Dropout(0.2))
# model.add(LSTM(50, return_sequences = True,))
# model.add(Dropout(0.2))
# model.add(Dense(1))
# model.compile(loss='mae', optimizer='adam')`
#
# `history = model.fit(train_X, train_y, epochs=100, batch_size=72,
#                     validation_data=(test_X, test_y), verbose=2, shuffle=False)`
#
# Resultado:
#
# ![image.png](modelo_lstm_2.png)
#
#
#
# Modelo 3:
#
#
#
# `model = Sequential()
# model.add(LSTM(78, return_sequences = True, input_shape=(train_X.shape[1], train_X.shape[2])))
# model.add(Dropout(0.2))
# model.add(LSTM(156, return_sequences = True))
# model.add(Dropout(0.2))
# model.add(LSTM(156, return_sequences = True))
# model.add(Dropout(0.2))
# model.add(LSTM(156, return_sequences = True,))
# model.add(Dropout(0.2))
# model.add(LSTM(156, return_sequences = True,))
# model.add(Dropout(0.2))
# model.add(Dense(1))
# model.compile(loss='mean_squared_error', optimizer='adam')
# history = model.fit(train_X, train_y, epochs=100, batch_size=36,
#                     validation_data=(test_X, test_y), verbose=2, shuffle=False)`
#
# RMSE: 0.13
#
#
# Modelo 4:
#
#
# `model = Sequential()
# model.add(LSTM(78, return_sequences = True, input_shape=(train_X.shape[1], train_X.shape[2])))
# model.add(Dropout(0.2))
# model.add(LSTM(156, return_sequences = True))
# model.add(Dropout(0.2))
# model.add(LSTM(156, return_sequences = True))
# model.add(Dropout(0.2))
# model.add(LSTM(156, return_sequences = True,))
# model.add(Dropout(0.2))
# model.add(LSTM(156, return_sequences = True,))
# model.add(Dropout(0.2))
# model.add(LSTM(156, return_sequences = True,))
# model.add(Dropout(0.2))
# model.add(Dense(1))
# model.compile(loss='mean_squared_error', optimizer='adam')
# history = model.fit(train_X, train_y, epochs=100, batch_size=36,
#                     validation_data=(test_X, test_y), verbose=2, shuffle=False)`
#
# RMSE: 0.103
#
#
# Modelo 5: (Sem dropout)
#
#
# `model = Sequential()
# model.add(LSTM(78, return_sequences = True, input_shape=(train_X.shape[1], train_X.shape[2])))
# model.add(LSTM(156, return_sequences = True,))
# model.add(LSTM(156, return_sequences = True,))
# model.add(LSTM(156, return_sequences = True,))
# model.add(LSTM(156, return_sequences = True,))
# model.add(LSTM(156, return_sequences = True,))
# model.add(Dense(1))
# model.compile(loss='mean_squared_error', optimizer='adam')
# history = model.fit(train_X, train_y, epochs=100, batch_size=36,
#                     validation_data=(test_X, test_y), verbose=2, shuffle=False)`
#
# RMSE: 0.093
#
# ![image.png](melhor_resultado_lstm.png)
#
# ![image.png](melhor_resultado_treinamento_modelo.png)

# %%
train_X.shape
# Out:
# (156, 1, 77)

# %%
np.random.seed(10)

# design network
model = Sequential()
model.add(LSTM(78, return_sequences = True, input_shape=(train_X.shape[1], train_X.shape[2])))
# O método Dropout é utilizado para reduzir o overfitting
# model.add(Dropout(0.2))

model.add(LSTM(156, return_sequences = True))
# model.add(Dropout(0.2))

model.add(LSTM(156, return_sequences = True))
# model.add(Dropout(0.2))

model.add(LSTM(156, return_sequences = True))
# model.add(Dropout(0.2))

model.add(LSTM(156, return_sequences = True))
# model.add(Dropout(0.2))

model.add(LSTM(156, return_sequences = True))
# model.add(Dropout(0.2))

model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='Adam')
# fit network
history = model.fit(train_X, train_y, epochs=100, batch_size=32, 
                    validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/100
# 5/5 - 7s - loss: 0.0906 - val_loss: 0.4402
# Epoch 2/100
# 5/5 - 0s - loss: 0.0733 - val_loss: 0.3890
# Epoch 3/100
# 5/5 - 0s - loss: 0.0508 - val_loss: 0.3102
# Epoch 4/100
# 5/5 - 0s - loss: 0.0224 - val_loss: 0.1770
# Epoch 5/100
# 5/5 - 0s - loss: 0.0153 - val_loss: 0.1171
# Epoch 6/100
# 5/5 - 0s - loss: 0.0250 - val_loss: 0.1536
# Epoch 7/100
# 5/5 - 0s - loss: 0.0206 - val_loss: 0.1828
# Epoch 8/100
# 5/5 - 0s - loss: 0.0188 - val_loss: 0.1876
# Epoch 9/100
# 5/5 - 0s - loss: 0.0173 - val_loss: 0.1756
# Epoch 10/100
# 5/5 - 0s - loss: 0.0158 - val_loss: 0.1555
# Epoch 11/100
# 5/5 - 0s - loss: 0.0153 - val_loss: 0.1386
# Epoch 12/100
# 5/5 - 0s - loss: 0.0150 - val_loss: 0.1322
# Epoch 13/100
# 5/5 - 0s - loss: 0.0134 - val_loss: 0.1290
# Epoch 14/100
# 5/5 - 0s - loss: 0.0110 - val_loss: 0.1160
# Epoch 15/100
# 5/5 - 0s - loss: 0.0092 - val_loss: 0.1000
# Epoch 16/100
# 5/5 - 0s - loss: 0.0087 - val_loss: 0.0973
# Epoch 17/100
# 5/5 - 0s - loss: 0.0081 - val_loss: 0.0953
# Epoch 18/100
# 5/5 - 0s - loss: 0.0076 - val_loss: 0.0908
# Epoch 19/100
# 5/5 - 0s - loss: 0.0073 - val_loss: 0.0906
# Epoch 20/100
# 5/5 - 0s - loss: 0.0071 - val_loss: 0.0879
# Epoch 21/100
# 5/5 - 0s - loss: 0.0069 - val_loss: 0.0818
# Epoch 22/100
# 5/5 - 0s - loss: 0.0067 - val_loss: 0.0773
# Epoch 23/100
# 5/5 - 0s - loss: 0.0065 - val_loss: 0.0720
# Epoch 24/100
# 5/5 - 0s - loss: 0.0063 - val_loss: 0.0668
# Epoch 25/100
# 5/5 - 0s - loss: 0.0061 - val_loss: 0.0626
# Epoch 26/100
# 5/5 - 0s - loss: 0.0059 - val_loss: 0.0576
# Epoch 27/100
# 5/5 - 0s - loss: 0.0057 - val_loss: 0.0526
# Epoch 28/100
# 5/5 - 0s - loss: 0.0055 - val_loss: 0.0466
# Epoch 29/100
# 5/5 - 0s - loss: 0.0052 - val_loss: 0.0403
# Epoch 30/100
# 5/5 - 0s - loss: 0.0049 - val_loss: 0.0336
# Epoch 31/100
# 5/5 - 0s - loss: 0.0047 - val_loss: 0.0278
# Epoch 32/100
# 5/5 - 0s - loss: 0.0044 - val_loss: 0.0217
# Epoch 33/100
# 5/5 - 0s - loss: 0.0041 - val_loss: 0.0185
# Epoch 34/100
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0149
# Epoch 35/100
# 5/5 - 0s - loss: 0.0036 - val_loss: 0.0152
# Epoch 36/100
# 5/5 - 0s - loss: 0.0033 - val_loss: 0.0166
# Epoch 37/100
# 5/5 - 0s - loss: 0.0031 - val_loss: 0.0198
# Epoch 38/100
# 5/5 - 0s - loss: 0.0032 - val_loss: 0.0192
# Epoch 39/100
# 5/5 - 0s - loss: 0.0029 - val_loss: 0.0176
# Epoch 40/100
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0231
# Epoch 41/100
# 5/5 - 0s - loss: 0.0029 - val_loss: 0.0198
# Epoch 42/100
# 5/5 - 0s - loss: 0.0044 - val_loss: 0.0183
# Epoch 43/100
# 5/5 - 0s - loss: 0.0036 - val_loss: 0.0282
# Epoch 44/100
# 5/5 - 0s - loss: 0.0066 - val_loss: 0.0386
# Epoch 45/100
# 5/5 - 0s - loss: 0.0149 - val_loss: 0.0407
# Epoch 46/100
# 5/5 - 0s - loss: 0.0059 - val_loss: 0.0165
# Epoch 47/100
# 5/5 - 0s - loss: 0.0101 - val_loss: 0.0807
# Epoch 48/100
# 5/5 - 0s - loss: 0.0051 - val_loss: 0.0210
# Epoch 49/100
# 5/5 - 0s - loss: 0.0067 - val_loss: 0.0229
# Epoch 50/100
# 5/5 - 0s - loss: 0.0067 - val_loss: 0.0448
# Epoch 51/100
# 5/5 - 0s - loss: 0.0030 - val_loss: 0.0110
# Epoch 52/100
# 5/5 - 0s - loss: 0.0047 - val_loss: 0.0173
# Epoch 53/100
# 5/5 - 0s - loss: 0.0056 - val_loss: 0.0241
# Epoch 54/100
# 5/5 - 0s - loss: 0.0033 - val_loss: 0.0108
# Epoch 55/100
# 5/5 - 0s - loss: 0.0031 - val_loss: 0.0157
# Epoch 56/100
# 5/5 - 0s - loss: 0.0029 - val_loss: 0.0115
# Epoch 57/100
# 5/5 - 0s - loss: 0.0029 - val_loss: 0.0112
# Epoch 58/100
# 5/5 - 0s - loss: 0.0029 - val_loss: 0.0115
# Epoch 59/100
# 5/5 - 0s - loss: 0.0028 - val_loss: 0.0121
# Epoch 60/100
# 5/5 - 0s - loss: 0.0029 - val_loss: 0.0118
# Epoch 61/100
# 5/5 - 0s - loss: 0.0029 - val_loss: 0.0122
# Epoch 62/100
# 5/5 - 0s - loss: 0.0033 - val_loss: 0.0117
# Epoch 63/100
# 5/5 - 0s - loss: 0.0031 - val_loss: 0.0119
# Epoch 64/100
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0114
# Epoch 65/100
# 5/5 - 0s - loss: 0.0033 - val_loss: 0.0112
# Epoch 66/100
# 5/5 - 0s - loss: 0.0042 - val_loss: 0.0119
# Epoch 67/100
# 5/5 - 0s - loss: 0.0031 - val_loss: 0.0107
# Epoch 68/100
# 5/5 - 0s - loss: 0.0035 - val_loss: 0.0116
# Epoch 69/100
# 5/5 - 0s - loss: 0.0027 - val_loss: 0.0106
# Epoch 70/100
# 5/5 - 0s - loss: 0.0028 - val_loss: 0.0106
# Epoch 71/100
# 5/5 - 0s - loss: 0.0025 - val_loss: 0.0108
# Epoch 72/100
# 5/5 - 0s - loss: 0.0026 - val_loss: 0.0106
# Epoch 73/100
# 5/5 - 0s - loss: 0.0025 - val_loss: 0.0109
# Epoch 74/100
# 5/5 - 0s - loss: 0.0028 - val_loss: 0.0106
# Epoch 75/100
# 5/5 - 0s - loss: 0.0028 - val_loss: 0.0106
# Epoch 76/100
# 5/5 - 0s - loss: 0.0035 - val_loss: 0.0103
# Epoch 77/100
# 5/5 - 0s - loss: 0.0032 - val_loss: 0.0102
# Epoch 78/100
# 5/5 - 0s - loss: 0.0044 - val_loss: 0.0118
# Epoch 79/100
# 5/5 - 0s - loss: 0.0031 - val_loss: 0.0097
# Epoch 80/100
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0129
# Epoch 81/100
# 5/5 - 0s - loss: 0.0026 - val_loss: 0.0094
# Epoch 82/100
# 5/5 - 0s - loss: 0.0026 - val_loss: 0.0104
# Epoch 83/100
# 5/5 - 0s - loss: 0.0023 - val_loss: 0.0096
# Epoch 84/100
# 5/5 - 0s - loss: 0.0022 - val_loss: 0.0097
# Epoch 85/100
# 5/5 - 0s - loss: 0.0022 - val_loss: 0.0098
# Epoch 86/100
# 5/5 - 0s - loss: 0.0022 - val_loss: 0.0099
# Epoch 87/100
# 5/5 - 0s - loss: 0.0022 - val_loss: 0.0100
# Epoch 88/100
# 5/5 - 0s - loss: 0.0023 - val_loss: 0.0102
# Epoch 89/100
# 5/5 - 0s - loss: 0.0024 - val_loss: 0.0099
# Epoch 90/100
# 5/5 - 0s - loss: 0.0029 - val_loss: 0.0098
# Epoch 91/100
# 5/5 - 0s - loss: 0.0031 - val_loss: 0.0099
# Epoch 92/100
# 5/5 - 0s - loss: 0.0047 - val_loss: 0.0108
# Epoch 93/100
# 5/5 - 0s - loss: 0.0035 - val_loss: 0.0099
# Epoch 94/100
# 5/5 - 0s - loss: 0.0051 - val_loss: 0.0178
# Epoch 95/100
# 5/5 - 0s - loss: 0.0026 - val_loss: 0.0089
# Epoch 96/100
# 5/5 - 0s - loss: 0.0026 - val_loss: 0.0124
# Epoch 97/100
# 5/5 - 0s - loss: 0.0020 - val_loss: 0.0089
# Epoch 98/100
# 5/5 - 0s - loss: 0.0020 - val_loss: 0.0093
# Epoch 99/100
# 5/5 - 0s - loss: 0.0020 - val_loss: 0.0090
# Epoch 100/100
# 5/5 - 0s - loss: 0.0020 - val_loss: 0.0091

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()

# %%
# make a prediction


yhat = model.predict(test_X)
test_X_final = test_X.reshape(test_X.shape[0], test_X.shape[2])
# invert scaling for forecast



inv_yhat = np.concatenate((np.squeeze(yhat, axis=(2,)), test_X_final[:, :-1]), axis=1)

# inv_yhat = scaler_in.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

# invert scaling for actual

test_y_final = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y_final, test_X_final[:, 1:]), axis=1)
# inv_y = scaler_in.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))

mape = np.mean(np.abs((inv_y - inv_yhat) / test_y)) * 100
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.095

# %%
test_y_inv = scaler_out.inverse_transform(test_y_final)
yhat_final_inv = scaler_out.inverse_transform(np.squeeze(yhat, axis=(2,)))

# Plota o valor observado vs previsto. 
plt.plot(test_y_inv, label='Esperado')
plt.plot(yhat_final_inv, label='Previsto LSTM')
plt.legend()
plt.title('Teste LSTM - MAPE: %.4f' % mape)
plt.xticks(ticks=(0,5,11,17,23), labels=['2018-01', '2018-06', '2018-12', '2019-06', '2019-12'])
plt.grid(True,axis='y')
plt.show()

# %%
plot_model(model, show_shapes=True)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 1, 78)             48672
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1, 156)            146640
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 156)            195312
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 1, 156)            195312
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 1, 156)            195312
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 1, 156)            195312
# _________________________________________________________________
# dense (Dense)                (None, 1, 1)              157
# =================================================================
# Total params: 976,717
# Trainable params: 976,717
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 2.3 Validando a predição

# %%
print(validacao_cluster2)
# Out:
# [[0.79285714 0.34104046 1.         0.         0.70619815 1.        ]
#  [0.74761905 0.36416185 0.916      0.13739719 0.75646657 0.4253135 ]
#  [0.6547619  0.26011561 0.82       0.49250121 0.85846755 0.30137957]
#  [0.         0.04046243 0.7        0.76947267 0.         0.33655235]
#  [0.19047619 0.         0.444      1.         0.03221083 0.03469063]
#  [0.52619048 0.3699422  0.272      0.7053701  0.34407028 0.        ]
#  [0.68095238 0.42774566 0.1        0.77672956 0.81454368 0.32314636]
#  [0.69761905 0.3583815  0.016      0.90251572 0.79892631 0.41931319]
#  [0.87380952 0.58959538 0.         0.83889695 0.87896535 0.48651047]
#  [0.78571429 0.71676301 0.         0.96202225 1.         0.87536207]
#  [0.8547619  0.73410405 0.         0.80188679 0.92581747 0.61640062]
#  [1.         1.         0.         0.5684567  0.99560761 0.72279002]]

# %%
values_predict = series_to_supervised(pd.DataFrame(validacao_cluster2).values, 12).values

print(values_predict)
# Out:
# []

# %%
validacao_cluster2 = pd.Series(validacao_cluster2['arrecadacao'].values, index=validacao_cluster2.index)
validacao_cluster2.head()
# Out:
# mes
# 2020-01-01 00:00:00    1.000000
# 2020-02-01 00:00:00    0.425313
# 2020-03-01 00:00:00    0.301380
# 2020-04-01 00:00:00    0.336552
# 2020-05-01 00:00:00    0.034691
# dtype: float64

# %%
#Faz a previsão no mesmo tamanho que a base de teste
yhat = cluster2_aarima.predict(n_periods=len(validacao_cluster2), exogenous = validacao_cluster2_exog)
yhat = pd.Series(yhat, index = validacao_cluster2.index)
#Obtém o intervalo de confiança 
conf_int = cluster2_aarima.predict(len(validacao_cluster2), return_conf_int=True, alpha = 0.05, exogenous = validacao_cluster2_exog)

# %%
conf_int
# Out:
# (array([0.64761098, 0.34629915, 0.37921882, 0.27953151, 0.12463374,
#         0.24811141, 0.48601034, 0.37186629, 0.40836115, 0.57809564,
#         0.47510482, 0.47912548]),
#  array([[0.57262666, 0.72259531],
#         [0.27044835, 0.42214995],
#         [0.30336802, 0.45506962],
#         [0.20368071, 0.35538231],
#         [0.04878294, 0.20048454],
#         [0.17226061, 0.32396221],
#         [0.41015954, 0.56186114],
#         [0.29601549, 0.44771709],
#         [0.33251035, 0.48421196],
#         [0.50224484, 0.65394644],
#         [0.39925402, 0.55095562],
#         [0.40327468, 0.55497628]]))

# %%
conf_int_inv = scaler_valid.inverse_transform(pd.DataFrame(conf_int[1]))
conf_int_inv
# Out:
# array([[2.56201358e+10, 2.90980735e+10],
#        [1.86122892e+10, 2.21304158e+10],
#        [1.93757326e+10, 2.28938592e+10],
#        [1.70638743e+10, 2.05820010e+10],
#        [1.34716253e+10, 1.69897519e+10],
#        [1.63352078e+10, 1.98533344e+10],
#        [2.18523450e+10, 2.53704716e+10],
#        [1.92052194e+10, 2.27233460e+10],
#        [2.00515753e+10, 2.35697019e+10],
#        [2.39879042e+10, 2.75060308e+10],
#        [2.15994342e+10, 2.51175608e+10],
#        [2.16926775e+10, 2.52108042e+10]])

# %%
#Plota o resultado do modelo
plt.plot(scaler_valid.inverse_transform(pd.DataFrame(validacao_cluster2)), label='Valor Esperado')
plt.plot(scaler_valid.inverse_transform(pd.DataFrame(yhat)), color='red', label='AUTO-ARIMA')
plt.fill_between(validacao_cluster2.index, conf_int_inv[:,0], conf_int_inv[:,1], color='k', alpha=.08)
plt.title('Teste AUTO-ARIMA - MAPE: %.4f' % mape(yhat,validacao_cluster2))
plt.grid(True,axis='y')
plt.legend(loc='upper left')
