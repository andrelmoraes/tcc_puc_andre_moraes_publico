# %% [markdown]
# # Modelo SARIMAX
#
# ---
# O modelo implementado a seguir mostra os resultados para o algoritmo SARIMAX, incluindo variáveis exógenas (preditores diversos do valor a ser analizado na série temporal).
#
# ___

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import math
import requests
import json
import os
import statsmodels.api as sm
from sklearn.preprocessing import MinMaxScaler
from math import sqrt
from sklearn.metrics import mean_squared_error
import itertools
import pmdarima as pm

from statsmodels.tsa.statespace.sarimax import SARIMAX

import warnings
warnings.filterwarnings("ignore")

from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)

# %% [markdown]
# ## 1. Importando os datasets

# %%
dataset_cluster2_series = pd.read_csv("datasets//dataset_cluster2_series.csv")
dataset_cluster2_validacao = pd.read_csv("datasets//dataset_cluster2_validation.csv")

# %%
dataset_cluster2_series.head(20)
# Out:
#                     mes  indice_pimpf  ipca  taxa_selic  taxa_cambio   ibcbr  \
# 0   2004-01-01 00:00:00         104.0  0.76       16.32       136.19   98.59
# 1   2004-02-01 00:00:00         103.1  0.61       16.30       139.84   99.45
# 2   2004-03-01 00:00:00         113.0  0.47       16.19       138.89  111.98
# 3   2004-04-01 00:00:00         107.8  0.37       15.96       138.85  107.36
# 4   2004-05-01 00:00:00         108.9  0.51       15.77       148.25  106.03
# 5   2004-06-01 00:00:00         113.1  0.71       15.80       149.04  107.00
# 6   2004-07-01 00:00:00         110.9  0.91       15.77       143.11  111.47
# 7   2004-08-01 00:00:00         113.2  0.69       15.86       140.62  110.65
# 8   2004-09-01 00:00:00         107.6  0.33       16.09       135.23  109.21
# 9   2004-10-01 00:00:00         103.8  0.44       16.41       133.55  108.89
# 10  2004-11-01 00:00:00         108.6  0.69       16.96       129.60  109.59
# 11  2004-12-01 00:00:00         108.9  0.86       17.50       124.90  107.56
# 12  2005-01-01 00:00:00         105.4  0.58       17.93       123.29  103.52
# 13  2005-02-01 00:00:00         103.3  0.59       18.47       118.92  104.00
# 14  2005-03-01 00:00:00         101.0  0.61       18.97       124.02  115.42
# 15  2005-04-01 00:00:00         105.4  0.87       19.32       118.03  112.35
# 16  2005-05-01 00:00:00         104.9  0.49       19.61       111.59  110.86
# 17  2005-06-01 00:00:00         105.6 -0.02       19.75       109.88  111.50
# 18  2005-07-01 00:00:00          99.9  0.25       19.72       108.29  113.15
# 19  2005-08-01 00:00:00         103.5  0.17       19.75       108.07  115.15
#
#      tjlp  pib_mensal  preco_brent  desembolso   arrecadacao
# 0   10.00   1735331.5        31.18      1107.0  6.709728e+09
# 1   10.00   1746819.2        30.87      2559.0  5.844144e+09
# 2   10.00   1765492.2        33.80      4302.0  5.757594e+09
# 3    9.75   1781058.0        33.36      5474.0  7.872113e+09
# 4    9.75   1800951.1        37.92      5976.0  7.156122e+09
# 5    9.75   1828299.9        35.19      7338.0  7.048868e+09
# 6    9.75   1853700.2        38.37      8251.0  8.450281e+09
# 7    9.75   1878059.7        43.03      8887.0  7.101401e+09
# 8    9.75   1894202.4        43.38      9562.0  7.709141e+09
# 9    9.75   1909813.0        49.82     11099.0  8.787191e+09
# 10   9.75   1933090.2        43.05     12842.0  6.845525e+09
# 11   9.75   1957751.2        39.64     15526.0  7.922471e+09
# 12   9.75   1976732.7        44.28      2089.0  9.171569e+09
# 13   9.75   1994573.0        45.56      3051.0  6.970914e+09
# 14   9.75   2012678.1        53.08      4797.0  7.356128e+09
# 15   9.75   2032903.2        51.86      5966.0  9.611372e+09
# 16   9.75   2050901.0        48.67      7363.0  7.820801e+09
# 17   9.75   2066440.6        54.31     10274.0  7.480434e+09
# 18   9.75   2079143.4        57.58     11523.0  8.976327e+09
# 19   9.75   2097211.1        64.09     13512.0  7.829660e+09

# %%
dataset_cluster2_validacao.head(20)
# Out:
#                     mes  indice_pimpf  ipca  taxa_selic  taxa_cambio   ibcbr  \
# 0   2020-01-01 00:00:00         101.5  0.21        4.40       116.16  133.60
# 1   2020-02-01 00:00:00          99.6  0.25        4.19       121.84  134.63
# 2   2020-03-01 00:00:00          95.7  0.07        3.95       136.52  136.72
# 3   2020-04-01 00:00:00          68.2 -0.31        3.65       147.97  119.13
# 4   2020-05-01 00:00:00          76.2 -0.38        3.01       157.50  119.79
# 5   2020-06-01 00:00:00          90.3  0.26        2.58       145.32  126.18
# 6   2020-07-01 00:00:00          96.8  0.36        2.15       148.27  135.82
# 7   2020-08-01 00:00:00          97.5  0.24        1.94       153.47  135.50
# 8   2020-09-01 00:00:00         104.9  0.64        1.90       150.84  137.14
# 9   2020-10-01 00:00:00         101.2  0.86        1.90       155.93  139.62
# 10  2020-11-01 00:00:00         104.1  0.89        1.90       149.31  138.10
# 11  2020-12-01 00:00:00         110.2  1.35        1.90       139.66  139.53
#
#     tjlp  pib_mensal  preco_brent  desembolso   arrecadacao
# 0   5.09   7435826.2        63.60       257.0  3.553139e+10
# 1   5.09   7463826.9        55.00       792.0  2.220378e+10
# 2   5.09   7485253.1        32.98      1294.0  1.932962e+10
# 3   4.94   7422874.5        23.34      2254.0  2.014531e+10
# 4   4.94   7365193.7        31.02      3078.0  1.314481e+10
# 5   4.94   7359646.6        39.93      4283.0  1.234030e+10
# 6   4.91   7349280.0        42.81      4883.0  1.983441e+10
# 7   4.91   7348772.7        44.26      7081.0  2.206463e+10
# 8   4.91   7367379.0        41.09      7525.0  2.362301e+10
# 9   4.55   7386165.6        40.47      8319.0  3.264090e+10
# 10  4.55   7417829.9        43.23      9338.0  2.663530e+10
# 11  4.55   7447858.3        49.87     12673.0  2.910259e+10

# %%
# Montado as séries de entrada (arrecadação e demais variáveis) e as séries de validação (arrecadação e demais variáveis)



serie_cluster2 = dataset_cluster2_series.copy()
serie_cluster2_exog = dataset_cluster2_series.copy()

validacao_cluster2 = dataset_cluster2_validacao.copy()
validacao_cluster2_exog = dataset_cluster2_validacao.copy()


serie_cluster2 = serie_cluster2.drop(['indice_pimpf', 'ipca', 'taxa_selic', 'taxa_cambio', 'ibcbr',
                                     'tjlp','pib_mensal','preco_brent','desembolso'], axis=1)
serie_cluster2_exog = serie_cluster2_exog.drop(['arrecadacao'], axis=1)

validacao_cluster2 = validacao_cluster2.drop(['indice_pimpf', 'ipca', 'taxa_selic', 'taxa_cambio', 'ibcbr',
                                     'tjlp','pib_mensal','preco_brent','desembolso'], axis=1)
validacao_cluster2_exog = validacao_cluster2_exog.drop(['arrecadacao'], axis=1)

# %%
serie_cluster2.head()
# Out:
#                    mes   arrecadacao
# 0  2004-01-01 00:00:00  6.709728e+09
# 1  2004-02-01 00:00:00  5.844144e+09
# 2  2004-03-01 00:00:00  5.757594e+09
# 3  2004-04-01 00:00:00  7.872113e+09
# 4  2004-05-01 00:00:00  7.156122e+09

# %%
serie_cluster2_exog.head()
# Out:
#                    mes  indice_pimpf  ipca  taxa_selic  taxa_cambio   ibcbr  \
# 0  2004-01-01 00:00:00         104.0  0.76       16.32       136.19   98.59
# 1  2004-02-01 00:00:00         103.1  0.61       16.30       139.84   99.45
# 2  2004-03-01 00:00:00         113.0  0.47       16.19       138.89  111.98
# 3  2004-04-01 00:00:00         107.8  0.37       15.96       138.85  107.36
# 4  2004-05-01 00:00:00         108.9  0.51       15.77       148.25  106.03
#
#     tjlp  pib_mensal  preco_brent  desembolso
# 0  10.00   1735331.5        31.18      1107.0
# 1  10.00   1746819.2        30.87      2559.0
# 2  10.00   1765492.2        33.80      4302.0
# 3   9.75   1781058.0        33.36      5474.0
# 4   9.75   1800951.1        37.92      5976.0

# %%
validacao_cluster2.head()
# Out:
#                    mes   arrecadacao
# 0  2020-01-01 00:00:00  3.553139e+10
# 1  2020-02-01 00:00:00  2.220378e+10
# 2  2020-03-01 00:00:00  1.932962e+10
# 3  2020-04-01 00:00:00  2.014531e+10
# 4  2020-05-01 00:00:00  1.314481e+10

# %%
validacao_cluster2_exog.head()
# Out:
#                    mes  indice_pimpf  ipca  taxa_selic  taxa_cambio   ibcbr  \
# 0  2020-01-01 00:00:00         101.5  0.21        4.40       116.16  133.60
# 1  2020-02-01 00:00:00          99.6  0.25        4.19       121.84  134.63
# 2  2020-03-01 00:00:00          95.7  0.07        3.95       136.52  136.72
# 3  2020-04-01 00:00:00          68.2 -0.31        3.65       147.97  119.13
# 4  2020-05-01 00:00:00          76.2 -0.38        3.01       157.50  119.79
#
#    tjlp  pib_mensal  preco_brent  desembolso
# 0  5.09   7435826.2        63.60       257.0
# 1  5.09   7463826.9        55.00       792.0
# 2  5.09   7485253.1        32.98      1294.0
# 3  4.94   7422874.5        23.34      2254.0
# 4  4.94   7365193.7        31.02      3078.0

# %%
## Modificando as escalas. Como os datasets possuem dimensões diferentes, serão criados 4 scalers separados

scaler_in = MinMaxScaler(feature_range=(0, 1))
scaler_in_exog = MinMaxScaler(feature_range=(0, 1))

scaler_valid = MinMaxScaler(feature_range=(0, 1))
scaler_valid_exog = MinMaxScaler(feature_range=(0, 1))

serie_cluster2 = pd.DataFrame(scaler_in.fit_transform(serie_cluster2[['arrecadacao']]))
serie_cluster2_exog = pd.DataFrame(scaler_in_exog.fit_transform(serie_cluster2_exog[['indice_pimpf', 'ipca', 'taxa_selic', 
                                'taxa_cambio', 'ibcbr', 'tjlp','pib_mensal','preco_brent','desembolso']]))

# Definindo um scaler específico para a validação


validacao_cluster2 = pd.DataFrame(scaler_valid.fit_transform(validacao_cluster2[['arrecadacao']]))
validacao_cluster2_exog = pd.DataFrame(scaler_valid_exog.fit_transform(validacao_cluster2_exog[['indice_pimpf', 'ipca', 
                                'taxa_selic', 'taxa_cambio', 'ibcbr', 'tjlp','pib_mensal','preco_brent','desembolso']]))

# %%
serie_cluster2.columns=['arrecadacao']
serie_cluster2_exog.columns=['indice_pimpf', 'ipca','taxa_selic', 'taxa_cambio', 'ibcbr', 'tjlp',
                             'pib_mensal','preco_brent','desembolso']
validacao_cluster2.columns=['arrecadacao']
validacao_cluster2_exog.columns=['indice_pimpf', 'ipca','taxa_selic', 'taxa_cambio', 'ibcbr', 
                                 'tjlp','pib_mensal','preco_brent','desembolso']
serie_cluster2.head()
# Out:
#    arrecadacao
# 0     0.032581
# 1     0.002962
# 2     0.000000
# 3     0.072356
# 4     0.047856

# %%
## Montando os datasets com arrecadação e variáveis exógenas e colocando o mês como índice da série


serie_cluster2.index = dataset_cluster2_series.mes

serie_cluster2_exog.index = dataset_cluster2_series.mes

validacao_cluster2.index = dataset_cluster2_validacao.mes

validacao_cluster2_exog.index = dataset_cluster2_validacao.mes

# %%
serie_cluster2.head()
# Out:
#                      arrecadacao
# mes
# 2004-01-01 00:00:00     0.032581
# 2004-02-01 00:00:00     0.002962
# 2004-03-01 00:00:00     0.000000
# 2004-04-01 00:00:00     0.072356
# 2004-05-01 00:00:00     0.047856

# %%
validacao_cluster2.head()
# Out:
#                      arrecadacao
# mes
# 2020-01-01 00:00:00     1.000000
# 2020-02-01 00:00:00     0.425313
# 2020-03-01 00:00:00     0.301380
# 2020-04-01 00:00:00     0.336552
# 2020-05-01 00:00:00     0.034691

# %%
dataset_cluster2_series.head()
# Out:
#                    mes  indice_pimpf  ipca  taxa_selic  taxa_cambio   ibcbr  \
# 0  2004-01-01 00:00:00         104.0  0.76       16.32       136.19   98.59
# 1  2004-02-01 00:00:00         103.1  0.61       16.30       139.84   99.45
# 2  2004-03-01 00:00:00         113.0  0.47       16.19       138.89  111.98
# 3  2004-04-01 00:00:00         107.8  0.37       15.96       138.85  107.36
# 4  2004-05-01 00:00:00         108.9  0.51       15.77       148.25  106.03
#
#     tjlp  pib_mensal  preco_brent  desembolso   arrecadacao
# 0  10.00   1735331.5        31.18      1107.0  6.709728e+09
# 1  10.00   1746819.2        30.87      2559.0  5.844144e+09
# 2  10.00   1765492.2        33.80      4302.0  5.757594e+09
# 3   9.75   1781058.0        33.36      5474.0  7.872113e+09
# 4   9.75   1800951.1        37.92      5976.0  7.156122e+09

# %%
serie_cluster2.head()
# Out:
#                      arrecadacao
# mes
# 2004-01-01 00:00:00     0.032581
# 2004-02-01 00:00:00     0.002962
# 2004-03-01 00:00:00     0.000000
# 2004-04-01 00:00:00     0.072356
# 2004-05-01 00:00:00     0.047856

# %%
serie_cluster2_exog.head()
# Out:
#                      indice_pimpf      ipca  taxa_selic  taxa_cambio  \
# mes
# 2004-01-01 00:00:00      0.583799  0.638710    0.773747     0.853109
# 2004-02-01 00:00:00      0.558659  0.541935    0.772427     0.894833
# 2004-03-01 00:00:00      0.835196  0.451613    0.765172     0.883973
# 2004-04-01 00:00:00      0.689944  0.387097    0.750000     0.883516
# 2004-05-01 00:00:00      0.720670  0.477419    0.737467     0.990969
#
#                         ibcbr  tjlp  pib_mensal  preco_brent  desembolso
# mes
# 2004-01-01 00:00:00  0.000000  1.00    0.000000     0.003687    0.009199
# 2004-02-01 00:00:00  0.016063  1.00    0.002025     0.000679    0.028092
# 2004-03-01 00:00:00  0.250093  1.00    0.005318     0.029106    0.050771
# 2004-04-01 00:00:00  0.163803  0.95    0.008062     0.024837    0.066020
# 2004-05-01 00:00:00  0.138962  0.95    0.011570     0.069079    0.072552

# %%
validacao_cluster2.head(12)
# Out:
#                      arrecadacao
# mes
# 2020-01-01 00:00:00     1.000000
# 2020-02-01 00:00:00     0.425313
# 2020-03-01 00:00:00     0.301380
# 2020-04-01 00:00:00     0.336552
# 2020-05-01 00:00:00     0.034691
# 2020-06-01 00:00:00     0.000000
# 2020-07-01 00:00:00     0.323146
# 2020-08-01 00:00:00     0.419313
# 2020-09-01 00:00:00     0.486510
# 2020-10-01 00:00:00     0.875362
# 2020-11-01 00:00:00     0.616401
# 2020-12-01 00:00:00     0.722790

# %%
validacao_cluster2_exog.head(12)
# Out:
#                      indice_pimpf      ipca  taxa_selic  taxa_cambio  \
# mes
# 2020-01-01 00:00:00      0.792857  0.341040       1.000     0.000000
# 2020-02-01 00:00:00      0.747619  0.364162       0.916     0.137397
# 2020-03-01 00:00:00      0.654762  0.260116       0.820     0.492501
# 2020-04-01 00:00:00      0.000000  0.040462       0.700     0.769473
# 2020-05-01 00:00:00      0.190476  0.000000       0.444     1.000000
# 2020-06-01 00:00:00      0.526190  0.369942       0.272     0.705370
# 2020-07-01 00:00:00      0.680952  0.427746       0.100     0.776730
# 2020-08-01 00:00:00      0.697619  0.358382       0.016     0.902516
# 2020-09-01 00:00:00      0.873810  0.589595       0.000     0.838897
# 2020-10-01 00:00:00      0.785714  0.716763       0.000     0.962022
# 2020-11-01 00:00:00      0.854762  0.734104       0.000     0.801887
# 2020-12-01 00:00:00      1.000000  1.000000       0.000     0.568457
#
#                         ibcbr      tjlp  pib_mensal  preco_brent  desembolso
# mes
# 2020-01-01 00:00:00  0.706198  1.000000    0.637846     1.000000    0.000000
# 2020-02-01 00:00:00  0.756467  1.000000    0.843009     0.786388    0.043090
# 2020-03-01 00:00:00  0.858468  1.000000    1.000000     0.239444    0.083521
# 2020-04-01 00:00:00  0.000000  0.722222    0.542948     0.000000    0.160841
# 2020-05-01 00:00:00  0.032211  0.722222    0.120318     0.190760    0.227207
# 2020-06-01 00:00:00  0.344070  0.722222    0.079674     0.412072    0.324259
# 2020-07-01 00:00:00  0.814544  0.666667    0.003717     0.483607    0.372584
# 2020-08-01 00:00:00  0.798926  0.666667    0.000000     0.519622    0.549613
# 2020-09-01 00:00:00  0.878965  0.666667    0.136329     0.440884    0.585374
# 2020-10-01 00:00:00  1.000000  0.000000    0.273980     0.425484    0.649323
# 2020-11-01 00:00:00  0.925817  0.000000    0.505986     0.494039    0.731395
# 2020-12-01 00:00:00  0.995608  0.000000    0.726006     0.658967    1.000000

# %% [markdown]
# ## 2. Implementando o modelo Auto-Arima

# %%
#Define função para calcular o MAPE - Mean Absolute Percentage Error
def mape(y_pred,y_true):

    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# Define a função para calcular o RMSE 

def rmse(y_pred, y_true):
    return sqrt(mean_squared_error(y_true, y_pred))

# %%
# Ajustar parâmetros de plotagem
#plt.rcParams.keys()
plt.rcParams["text.color"] = 'Blue'
plt.rcParams["axes.titlesize"] = 20
plt.rcParams["axes.labelsize"] = 12
plt.rcParams["xtick.labelsize"] = 12
plt.rcParams["ytick.labelsize"] = 12
plt.rcParams["legend.fontsize"] = 12
plt.rcParams["figure.figsize"] = [15, 6]
plt.rcParams["lines.linewidth"] = 2.0

# %% [markdown]
# ### 2.1 Separando os dataframes de treino e teste

# %%
# Utilizando 80% do dataset para treino e 20% para teste

train, test = serie_cluster2[:144], serie_cluster2[144:]
train_exog, test_exog = serie_cluster2_exog[:144], serie_cluster2_exog[144:]

# %%
len(train)
# Out:
# 144

# %%
len(test)
# Out:
# 48

# %%
train = pd.Series(train['arrecadacao'].values, index=train.index)
train.head()
# Out:
# mes
# 2004-01-01 00:00:00    0.032581
# 2004-02-01 00:00:00    0.002962
# 2004-03-01 00:00:00    0.000000
# 2004-04-01 00:00:00    0.072356
# 2004-05-01 00:00:00    0.047856
# dtype: float64

# %%
test = pd.Series(test['arrecadacao'].values, index=test.index)

test.head()
# Out:
# mes
# 2016-01-01 00:00:00    0.542972
# 2016-02-01 00:00:00    0.273629
# 2016-03-01 00:00:00    0.319853
# 2016-04-01 00:00:00    0.358124
# 2016-05-01 00:00:00    0.317699
# dtype: float64

# %% [markdown]
# ## 2.2 Treinando o modelo
#
# ---
# O modelo será treinado com os seguintes parâmetros:
# <ul>
#     <li>m = 12, para um período de 12 meses</li>
#     <li>stationarity = False, uma vez que a série não é estacionária, como visto na análise exploratória</li>
#     <li>seasonal = True, já que vimos que a série de arrecadação apresenta sazonalidade</li>
#     <li>stepwise = False, aproveitando o reduzido tamanho da série para analisar todas as combinações de hiperparâmetros</li>
#     <li>trend = t</li>
# </ul>

# %%
cluster2_aarima = pm.auto_arima(train, X = train_exog,  m=12, stationarity=False, seasonal=True, stepwise=False,
                           supress_warnings=True, error_action='ignore', trace=True, trend = 't')


# cluster2_aarima.fit(train)
# Out:
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=-437.384, Time=0.23 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=-459.466, Time=0.40 sec
#  ARIMA(0,0,0)(0,1,2)[12] intercept   : AIC=-465.741, Time=1.03 sec
#  ARIMA(0,0,0)(1,1,0)[12] intercept   : AIC=-463.853, Time=0.55 sec
#  ARIMA(0,0,0)(1,1,1)[12] intercept   : AIC=-465.784, Time=0.69 sec
#  ARIMA(0,0,0)(1,1,2)[12] intercept   : AIC=-463.381, Time=2.04 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=-470.212, Time=1.00 sec
#  ARIMA(0,0,0)(2,1,1)[12] intercept   : AIC=-467.095, Time=1.23 sec
#  ARIMA(0,0,0)(2,1,2)[12] intercept   : AIC=-463.911, Time=2.95 sec
#  ARIMA(0,0,1)(0,1,0)[12] intercept   : AIC=-437.213, Time=0.20 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=-464.004, Time=1.20 sec
#  ARIMA(0,0,1)(0,1,2)[12] intercept   : AIC=-469.055, Time=2.03 sec
#  ARIMA(0,0,1)(1,1,0)[12] intercept   : AIC=-458.277, Time=0.67 sec
#  ARIMA(0,0,1)(1,1,1)[12] intercept   : AIC=-467.137, Time=1.44 sec
#  ARIMA(0,0,1)(1,1,2)[12] intercept   : AIC=-463.569, Time=3.77 sec
#  ARIMA(0,0,1)(2,1,0)[12] intercept   : AIC=-470.301, Time=1.41 sec
#  ARIMA(0,0,1)(2,1,1)[12] intercept   : AIC=-469.076, Time=2.78 sec
#  ARIMA(0,0,1)(2,1,2)[12] intercept   : AIC=-466.166, Time=2.86 sec
#  ARIMA(0,0,2)(0,1,0)[12] intercept   : AIC=-435.067, Time=0.26 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=-456.539, Time=1.11 sec
#  ARIMA(0,0,2)(0,1,2)[12] intercept   : AIC=-464.622, Time=1.59 sec
#  ARIMA(0,0,2)(1,1,0)[12] intercept   : AIC=-460.084, Time=1.12 sec
#  ARIMA(0,0,2)(1,1,1)[12] intercept   : AIC=-465.043, Time=1.64 sec
#  ARIMA(0,0,2)(1,1,2)[12] intercept   : AIC=-462.621, Time=3.37 sec
#  ARIMA(0,0,2)(2,1,0)[12] intercept   : AIC=-468.164, Time=1.61 sec
#  ARIMA(0,0,2)(2,1,1)[12] intercept   : AIC=-468.732, Time=2.14 sec
#  ARIMA(0,0,3)(0,1,0)[12] intercept   : AIC=-433.673, Time=0.27 sec
#  ARIMA(0,0,3)(0,1,1)[12] intercept   : AIC=-466.452, Time=1.76 sec
#  ARIMA(0,0,3)(0,1,2)[12] intercept   : AIC=-455.999, Time=1.56 sec
#  ARIMA(0,0,3)(1,1,0)[12] intercept   : AIC=-463.409, Time=1.52 sec
#  ARIMA(0,0,3)(1,1,1)[12] intercept   : AIC=-461.755, Time=0.74 sec
#  ARIMA(0,0,3)(2,1,0)[12] intercept   : AIC=-471.100, Time=2.74 sec
#  ARIMA(0,0,4)(0,1,0)[12] intercept   : AIC=-432.250, Time=0.75 sec
#  ARIMA(0,0,4)(0,1,1)[12] intercept   : AIC=-462.865, Time=1.97 sec
#  ARIMA(0,0,4)(1,1,0)[12] intercept   : AIC=-450.962, Time=0.32 sec
#  ARIMA(0,0,5)(0,1,0)[12] intercept   : AIC=-433.513, Time=0.88 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=-437.182, Time=0.18 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=-460.117, Time=0.45 sec
#  ARIMA(1,0,0)(0,1,2)[12] intercept   : AIC=-469.186, Time=2.30 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=-458.677, Time=0.42 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=-467.095, Time=0.67 sec
#  ARIMA(1,0,0)(1,1,2)[12] intercept   : AIC=-464.302, Time=2.33 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=-471.557, Time=3.11 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=-470.789, Time=2.32 sec
#  ARIMA(1,0,0)(2,1,2)[12] intercept   : AIC=-465.996, Time=2.41 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=-435.281, Time=0.21 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=-457.742, Time=0.61 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=-465.775, Time=1.56 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=-463.944, Time=1.31 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=-465.889, Time=1.29 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=-453.366, Time=1.68 sec
#  ARIMA(1,0,1)(2,1,0)[12] intercept   : AIC=-468.442, Time=2.67 sec
#  ARIMA(1,0,1)(2,1,1)[12] intercept   : AIC=-468.864, Time=3.02 sec
#  ARIMA(1,0,2)(0,1,0)[12] intercept   : AIC=-433.163, Time=0.60 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=-453.981, Time=1.04 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=-454.014, Time=1.81 sec
#  ARIMA(1,0,2)(1,1,0)[12] intercept   : AIC=-452.812, Time=1.04 sec
#  ARIMA(1,0,2)(1,1,1)[12] intercept   : AIC=-452.832, Time=1.31 sec
#  ARIMA(1,0,2)(2,1,0)[12] intercept   : AIC=-454.905, Time=0.83 sec
#  ARIMA(1,0,3)(0,1,0)[12] intercept   : AIC=-431.024, Time=0.28 sec
#  ARIMA(1,0,3)(0,1,1)[12] intercept   : AIC=-454.297, Time=0.78 sec
#  ARIMA(1,0,3)(1,1,0)[12] intercept   : AIC=-452.469, Time=0.44 sec
#  ARIMA(1,0,4)(0,1,0)[12] intercept   : AIC=-428.593, Time=0.28 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=-435.211, Time=0.22 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=-457.895, Time=0.46 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=-465.615, Time=1.69 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=-456.552, Time=0.46 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=-465.277, Time=0.83 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=-462.548, Time=1.99 sec
#  ARIMA(2,0,0)(2,1,0)[12] intercept   : AIC=-469.625, Time=3.42 sec
#  ARIMA(2,0,0)(2,1,1)[12] intercept   : AIC=-466.387, Time=1.76 sec
#  ARIMA(2,0,1)(0,1,0)[12] intercept   : AIC=-431.374, Time=0.25 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=-453.361, Time=0.93 sec
#  ARIMA(2,0,1)(0,1,2)[12] intercept   : AIC=-460.421, Time=1.95 sec
#  ARIMA(2,0,1)(1,1,0)[12] intercept   : AIC=-458.376, Time=2.94 sec
#  ARIMA(2,0,1)(1,1,1)[12] intercept   : AIC=-462.606, Time=1.14 sec
#  ARIMA(2,0,1)(2,1,0)[12] intercept   : AIC=-466.674, Time=2.20 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=-431.392, Time=0.67 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=-455.054, Time=0.61 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=-458.152, Time=1.37 sec
#  ARIMA(2,0,3)(0,1,0)[12] intercept   : AIC=-354.055, Time=0.65 sec
#  ARIMA(3,0,0)(0,1,0)[12] intercept   : AIC=-433.644, Time=0.25 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=-457.410, Time=0.86 sec
#  ARIMA(3,0,0)(0,1,2)[12] intercept   : AIC=-465.636, Time=1.98 sec
#  ARIMA(3,0,0)(1,1,0)[12] intercept   : AIC=-463.151, Time=2.79 sec
#  ARIMA(3,0,0)(1,1,1)[12] intercept   : AIC=-464.915, Time=2.03 sec
#  ARIMA(3,0,0)(2,1,0)[12] intercept   : AIC=-468.054, Time=2.55 sec
#  ARIMA(3,0,1)(0,1,0)[12] intercept   : AIC=-431.694, Time=0.32 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=-459.998, Time=0.69 sec
#  ARIMA(3,0,1)(1,1,0)[12] intercept   : AIC=-453.708, Time=0.57 sec
#  ARIMA(3,0,2)(0,1,0)[12] intercept   : AIC=-427.680, Time=0.32 sec
#  ARIMA(4,0,0)(0,1,0)[12] intercept   : AIC=-432.538, Time=0.22 sec
#  ARIMA(4,0,0)(0,1,1)[12] intercept   : AIC=-456.418, Time=0.41 sec
#  ARIMA(4,0,0)(1,1,0)[12] intercept   : AIC=-455.038, Time=0.40 sec
#  ARIMA(4,0,1)(0,1,0)[12] intercept   : AIC=-430.292, Time=0.24 sec
#  ARIMA(5,0,0)(0,1,0)[12] intercept   : AIC=-433.541, Time=0.28 sec
#
# Best model:  ARIMA(1,0,0)(2,1,0)[12] intercept
# Total fit time: 124.363 seconds

# %%
cluster2_aarima.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  144
# Model:             SARIMAX(1, 0, 0)x(2, 1, 0, 12)   Log Likelihood                 249.779
# Date:                            Fri, 09 Jul 2021   AIC                           -471.557
# Time:                                    14:28:19   BIC                           -431.198
# Sample:                                01-01-2004   HQIC                          -455.157
#                                      - 12-01-2015
# Covariance Type:                              opg
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# drift        -4.021e-05      0.000     -0.082      0.934      -0.001       0.001
# indice_pimpf     0.0511      0.033      1.560      0.119      -0.013       0.115
# ipca            -0.0013      0.031     -0.042      0.967      -0.063       0.060
# taxa_selic       0.0962      0.044      2.202      0.028       0.011       0.182
# taxa_cambio      0.0451      0.040      1.131      0.258      -0.033       0.123
# ibcbr            0.0953      0.122      0.781      0.435      -0.144       0.334
# tjlp            -0.0773      0.043     -1.802      0.071      -0.161       0.007
# pib_mensal       0.4185      0.483      0.867      0.386      -0.528       1.365
# preco_brent      0.0732      0.029      2.538      0.011       0.017       0.130
# desembolso      -0.0102      0.039     -0.264      0.792      -0.086       0.066
# ar.L1            0.1198      0.113      1.062      0.288      -0.101       0.341
# ar.S.L12        -0.5726      0.108     -5.304      0.000      -0.784      -0.361
# ar.S.L24        -0.2662      0.109     -2.435      0.015      -0.480      -0.052
# sigma2           0.0013      0.000      7.790      0.000       0.001       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.46   Jarque-Bera (JB):               105.44
# Prob(Q):                              0.50   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.86   Skew:                             1.29
# Prob(H) (two-sided):                  0.04   Kurtosis:                         6.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### 2.3 Grid Search para determinar o melhor conjunto de parâmetros
#
# Créditos: https://towardsdatascience.com/grid-search-for-sarimax-parameters-adbd5104cb8b

# %%
### Define Parameter Ranges to Test ###

# Note: higher numbers will result in code taking much longer to run
# Here we have it set to test p,d,q each = 0, 1 & 2

# Define the p, d and q parameters to take any value between 0 and 3 (exclusive)
p = d = q = range(0, 3)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
# Note: here we have 12 in the 's' position as we have monthly data
# You'll want to change this according to your time series' frequency
pdqs = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

### Run Grid Search ###

# Note: this code will take a while to run

# Define function
def sarimax_gridsearch(ts,  ts_exog, pdq, pdqs, tendencia, maxiter=50,  freq='M'):
    '''
    Input: 
        ts : your time series data
        pdq : ARIMA combinations from above
        pdqs : seasonal ARIMA combinations from above
        maxiter : number of iterations, increase if your model isn't converging
        frequency : default='M' for month. Change to suit your time series frequency
            e.g. 'D' for day, 'H' for hour, 'Y' for year. 
        
    Return:
        Prints out top 5 parameter combinations
        Returns dataframe of parameter combinations ranked by BIC
    '''
    print("Running...")
    # Run a grid search with pdq and seasonal pdq parameters and get the best BIC value
    ans = []
    for comb in pdq:
        for combs in pdqs:
            try:
                print(combs)
                mod = sm.tsa.statespace.SARIMAX(ts, exog=ts_exog, # this is your time series you will input
                                                order=comb,
                                                seasonal_order=combs,
                                                enforce_stationarity=True,
                                                enforce_invertibility=True, trend = tendencia)

                output = mod.fit(maxiter=maxiter) 
                ans.append([comb, combs, output.bic])
                print('SARIMAX {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
            except:
                print("Leaving...")
                continue
            
    # Find the parameters with minimal BIC value

    # Convert into dataframe
    ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])

    # Sort and return top 5 combinations
    ans_df = ans_df.sort_values(by=['aic'],ascending=True)[0:10]
    
    return ans_df
    
### Apply function to your time series data ###

# Remember to change frequency to match your time series data
sarimax_gridsearch(train, train_exog, pdq, pdqs, 't')
# Out:
# Running...
# (0, 0, 0, 12)
# SARIMAX (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =-332.0919868641311
# (0, 0, 1, 12)
# SARIMAX (0, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =-384.5324295795133
# (0, 0, 2, 12)
# SARIMAX (0, 0, 0) x (0, 0, 2, 12)12 : AIC Calculated =-420.23481609056523
# (0, 1, 0, 12)
# SARIMAX (0, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =-437.38438897033245
# (0, 1, 1, 12)
# SARIMAX (0, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =-459.46624436327284
# (0, 1, 2, 12)
# SARIMAX (0, 0, 0) x (0, 1, 2, 12)12 : AIC Calculated =-465.74055517054853
# (0, 2, 0, 12)
# SARIMAX (0, 0, 0) x (0, 2, 0, 12)12 : AIC Calculated =-278.2175475225258
# (0, 2, 1, 12)
# SARIMAX (0, 0, 0) x (0, 2, 1, 12)12 : AIC Calculated =-276.21757281647035
# (0, 2, 2, 12)
# SARIMAX (0, 0, 0) x (0, 2, 2, 12)12 : AIC Calculated =-274.2175728920129
# (1, 0, 0, 12)
# SARIMAX (0, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =-467.5156129089959
# (1, 0, 1, 12)
# SARIMAX (0, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =-301.8644621676087
# (1, 0, 2, 12)
# SARIMAX (0, 0, 0) x (1, 0, 2, 12)12 : AIC Calculated =-479.582267406634
# (1, 1, 0, 12)
# SARIMAX (0, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =-463.8525379717057
# (1, 1, 1, 12)
# SARIMAX (0, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =-465.78414204156064
# (1, 1, 2, 12)
# SARIMAX (0, 0, 0) x (1, 1, 2, 12)12 : AIC Calculated =-463.3805030268662
# (1, 2, 0, 12)
# SARIMAX (0, 0, 0) x (1, 2, 0, 12)12 : AIC Calculated =-326.1589471001572
# (1, 2, 1, 12)
# SARIMAX (0, 0, 0) x (1, 2, 1, 12)12 : AIC Calculated =-329.74479554104585
# (1, 2, 2, 12)
# SARIMAX (0, 0, 0) x (1, 2, 2, 12)12 : AIC Calculated =-337.544797065736
# (2, 0, 0, 12)
# SARIMAX (0, 0, 0) x (2, 0, 0, 12)12 : AIC Calculated =-328.0919896860236
# (2, 0, 1, 12)
# SARIMAX (0, 0, 0) x (2, 0, 1, 12)12 : AIC Calculated =-465.9795830373412
# (2, 0, 2, 12)
# SARIMAX (0, 0, 0) x (2, 0, 2, 12)12 : AIC Calculated =-461.62095563985395
# (2, 1, 0, 12)
# SARIMAX (0, 0, 0) x (2, 1, 0, 12)12 : AIC Calculated =-470.2116216275366
# (2, 1, 1, 12)
# SARIMAX (0, 0, 0) x (2, 1, 1, 12)12 : AIC Calculated =-467.095107621779
# (2, 1, 2, 12)
# SARIMAX (0, 0, 0) x (2, 1, 2, 12)12 : AIC Calculated =-463.9107407838362
# (2, 2, 0, 12)
# SARIMAX (0, 0, 0) x (2, 2, 0, 12)12 : AIC Calculated =-368.9750788992082
# (2, 2, 1, 12)
# SARIMAX (0, 0, 0) x (2, 2, 1, 12)12 : AIC Calculated =-376.2154158976475
# (2, 2, 2, 12)
# SARIMAX (0, 0, 0) x (2, 2, 2, 12)12 : AIC Calculated =-320.6968938673723
# (0, 0, 0, 12)
# SARIMAX (0, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =-342.76181879730564
# (0, 0, 1, 12)
# SARIMAX (0, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =-386.83445399469014
# (0, 0, 2, 12)
# SARIMAX (0, 0, 1) x (0, 0, 2, 12)12 : AIC Calculated =-419.99273502181774
# (0, 1, 0, 12)
# SARIMAX (0, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =-437.2126492243096
# (0, 1, 1, 12)
# SARIMAX (0, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =-464.00373765734093
# (0, 1, 2, 12)
# SARIMAX (0, 0, 1) x (0, 1, 2, 12)12 : AIC Calculated =-469.05530782109844
# (0, 2, 0, 12)
# SARIMAX (0, 0, 1) x (0, 2, 0, 12)12 : AIC Calculated =-276.18590688537165
# (0, 2, 1, 12)
# SARIMAX (0, 0, 1) x (0, 2, 1, 12)12 : AIC Calculated =-274.18593161386207
# (0, 2, 2, 12)
# SARIMAX (0, 0, 1) x (0, 2, 2, 12)12 : AIC Calculated =-272.1859316530946
# (1, 0, 0, 12)
# SARIMAX (0, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =-461.974803603699
# (1, 0, 1, 12)
# SARIMAX (0, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =-281.65492690277
# (1, 0, 2, 12)
# SARIMAX (0, 0, 1) x (1, 0, 2, 12)12 : AIC Calculated =-466.2125245111132
# (1, 1, 0, 12)
# SARIMAX (0, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =-458.2767779995356
# (1, 1, 1, 12)
# SARIMAX (0, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =-467.1365830909841
# (1, 1, 2, 12)
# SARIMAX (0, 0, 1) x (1, 1, 2, 12)12 : AIC Calculated =-463.5685233706738
# (1, 2, 0, 12)
# SARIMAX (0, 0, 1) x (1, 2, 0, 12)12 : AIC Calculated =-325.9635851859308
# (1, 2, 1, 12)
# SARIMAX (0, 0, 1) x (1, 2, 1, 12)12 : AIC Calculated =-325.64108696120473
# (1, 2, 2, 12)
# SARIMAX (0, 0, 1) x (1, 2, 2, 12)12 : AIC Calculated =-339.61772870753725
# (2, 0, 0, 12)
# SARIMAX (0, 0, 1) x (2, 0, 0, 12)12 : AIC Calculated =-338.76180967527944
# (2, 0, 1, 12)
# SARIMAX (0, 0, 1) x (2, 0, 1, 12)12 : AIC Calculated =-373.0593879492398
# (2, 0, 2, 12)
# SARIMAX (0, 0, 1) x (2, 0, 2, 12)12 : AIC Calculated =-394.99197748756984
# (2, 1, 0, 12)
# SARIMAX (0, 0, 1) x (2, 1, 0, 12)12 : AIC Calculated =-470.30075894698297
# (2, 1, 1, 12)
# SARIMAX (0, 0, 1) x (2, 1, 1, 12)12 : AIC Calculated =-469.0763414552824
# (2, 1, 2, 12)
# SARIMAX (0, 0, 1) x (2, 1, 2, 12)12 : AIC Calculated =-466.16570353507154
# (2, 2, 0, 12)
# SARIMAX (0, 0, 1) x (2, 2, 0, 12)12 : AIC Calculated =-367.3176117543297
# (2, 2, 1, 12)
# SARIMAX (0, 0, 1) x (2, 2, 1, 12)12 : AIC Calculated =-373.0463975598889
# (2, 2, 2, 12)
# SARIMAX (0, 0, 1) x (2, 2, 2, 12)12 : AIC Calculated =-316.2748012773775
# (0, 0, 0, 12)
# SARIMAX (0, 0, 2) x (0, 0, 0, 12)12 : AIC Calculated =-345.28755367015833
# (0, 0, 1, 12)
# SARIMAX (0, 0, 2) x (0, 0, 1, 12)12 : AIC Calculated =-403.321167712836
# (0, 0, 2, 12)
# SARIMAX (0, 0, 2) x (0, 0, 2, 12)12 : AIC Calculated =-421.78788231152544
# (0, 1, 0, 12)
# SARIMAX (0, 0, 2) x (0, 1, 0, 12)12 : AIC Calculated =-435.06711131538475
# (0, 1, 1, 12)
# SARIMAX (0, 0, 2) x (0, 1, 1, 12)12 : AIC Calculated =-456.5393825580095
# (0, 1, 2, 12)
# SARIMAX (0, 0, 2) x (0, 1, 2, 12)12 : AIC Calculated =-464.62166243672186
# (0, 2, 0, 12)
# SARIMAX (0, 0, 2) x (0, 2, 0, 12)12 : AIC Calculated =-274.5182681529496
# (0, 2, 1, 12)
# SARIMAX (0, 0, 2) x (0, 2, 1, 12)12 : AIC Calculated =-272.51828840027736
# (0, 2, 2, 12)
# SARIMAX (0, 0, 2) x (0, 2, 2, 12)12 : AIC Calculated =-270.51828836873995
# (1, 0, 0, 12)
# SARIMAX (0, 0, 2) x (1, 0, 0, 12)12 : AIC Calculated =-456.22594949592406
# (1, 0, 1, 12)
# SARIMAX (0, 0, 2) x (1, 0, 1, 12)12 : AIC Calculated =-135.87025604739296
# (1, 0, 2, 12)
# SARIMAX (0, 0, 2) x (1, 0, 2, 12)12 : AIC Calculated =-384.3252069783487
# (1, 1, 0, 12)
# SARIMAX (0, 0, 2) x (1, 1, 0, 12)12 : AIC Calculated =-460.0838280829453
# (1, 1, 1, 12)
# SARIMAX (0, 0, 2) x (1, 1, 1, 12)12 : AIC Calculated =-465.04319369996585
# (1, 1, 2, 12)
# SARIMAX (0, 0, 2) x (1, 1, 2, 12)12 : AIC Calculated =-462.62124818089933
# (1, 2, 0, 12)
# SARIMAX (0, 0, 2) x (1, 2, 0, 12)12 : AIC Calculated =-325.6785456429003
# (1, 2, 1, 12)
# SARIMAX (0, 0, 2) x (1, 2, 1, 12)12 : AIC Calculated =-321.76119679072633
# (1, 2, 2, 12)
# SARIMAX (0, 0, 2) x (1, 2, 2, 12)12 : AIC Calculated =-319.1894881158104
# (2, 0, 0, 12)
# SARIMAX (0, 0, 2) x (2, 0, 0, 12)12 : AIC Calculated =-341.28755367015833
# (2, 0, 1, 12)
# SARIMAX (0, 0, 2) x (2, 0, 1, 12)12 : AIC Calculated =-387.7840299304248
# (2, 0, 2, 12)
# SARIMAX (0, 0, 2) x (2, 0, 2, 12)12 : AIC Calculated =-401.60243264873316
# (2, 1, 0, 12)
# SARIMAX (0, 0, 2) x (2, 1, 0, 12)12 : AIC Calculated =-468.1638000518238
# (2, 1, 1, 12)
# SARIMAX (0, 0, 2) x (2, 1, 1, 12)12 : AIC Calculated =-468.73175822072676
# (2, 1, 2, 12)
# SARIMAX (0, 0, 2) x (2, 1, 2, 12)12 : AIC Calculated =-463.4625477214001
# (2, 2, 0, 12)
# SARIMAX (0, 0, 2) x (2, 2, 0, 12)12 : AIC Calculated =-366.1817535587549
# (2, 2, 1, 12)
# SARIMAX (0, 0, 2) x (2, 2, 1, 12)12 : AIC Calculated =-363.033294567771
# (2, 2, 2, 12)
# SARIMAX (0, 0, 2) x (2, 2, 2, 12)12 : AIC Calculated =-311.3699281867258
# (0, 0, 0, 12)
# SARIMAX (0, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =-210.20926710856895
# (0, 0, 1, 12)
# SARIMAX (0, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =-288.85094145033463
# (0, 0, 2, 12)
# SARIMAX (0, 1, 0) x (0, 0, 2, 12)12 : AIC Calculated =-316.4328917710137
# (0, 1, 0, 12)
# SARIMAX (0, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =-376.6963716173734
# (0, 1, 1, 12)
# SARIMAX (0, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =-396.6292825776756
# (0, 1, 2, 12)
# SARIMAX (0, 1, 0) x (0, 1, 2, 12)12 : AIC Calculated =-400.35172649656135
# (0, 2, 0, 12)
# SARIMAX (0, 1, 0) x (0, 2, 0, 12)12 : AIC Calculated =-210.02714972401856
# (0, 2, 1, 12)
# SARIMAX (0, 1, 0) x (0, 2, 1, 12)12 : AIC Calculated =-208.02714972401856
# (0, 2, 2, 12)
# SARIMAX (0, 1, 0) x (0, 2, 2, 12)12 : AIC Calculated =-206.02714972401864
# (1, 0, 0, 12)
# SARIMAX (0, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =-388.19311691078144
# (1, 0, 1, 12)
# SARIMAX (0, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =-382.9365862624621
# (1, 0, 2, 12)
# SARIMAX (0, 1, 0) x (1, 0, 2, 12)12 : AIC Calculated =-368.9329185715893
# (1, 1, 0, 12)
# SARIMAX (0, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =-400.55040888610245
# (1, 1, 1, 12)
# SARIMAX (0, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =-399.119641574121
# (1, 1, 2, 12)
# SARIMAX (0, 1, 0) x (1, 1, 2, 12)12 : AIC Calculated =-395.1617200401014
# (1, 2, 0, 12)
# SARIMAX (0, 1, 0) x (1, 2, 0, 12)12 : AIC Calculated =-274.5672509515474
# (1, 2, 1, 12)
# SARIMAX (0, 1, 0) x (1, 2, 1, 12)12 : AIC Calculated =-267.42857292420086
# (1, 2, 2, 12)
# SARIMAX (0, 1, 0) x (1, 2, 2, 12)12 : AIC Calculated =-289.28149187713245
# (2, 0, 0, 12)
# SARIMAX (0, 1, 0) x (2, 0, 0, 12)12 : AIC Calculated =-395.55116971443215
# (2, 0, 1, 12)
# SARIMAX (0, 1, 0) x (2, 0, 1, 12)12 : AIC Calculated =-381.4019545150644
# (2, 0, 2, 12)
# SARIMAX (0, 1, 0) x (2, 0, 2, 12)12 : AIC Calculated =-378.09526815723524
# (2, 1, 0, 12)
# SARIMAX (0, 1, 0) x (2, 1, 0, 12)12 : AIC Calculated =-400.9825597852089
# (2, 1, 1, 12)
# SARIMAX (0, 1, 0) x (2, 1, 1, 12)12 : AIC Calculated =-405.5451670897332
# (2, 1, 2, 12)
# SARIMAX (0, 1, 0) x (2, 1, 2, 12)12 : AIC Calculated =-403.91811156036874
# (2, 2, 0, 12)
# SARIMAX (0, 1, 0) x (2, 2, 0, 12)12 : AIC Calculated =-317.27171896812155
# (2, 2, 1, 12)
# SARIMAX (0, 1, 0) x (2, 2, 1, 12)12 : AIC Calculated =-328.0183621944065
# (2, 2, 2, 12)
# SARIMAX (0, 1, 0) x (2, 2, 2, 12)12 : AIC Calculated =-305.0209398313417
# (0, 0, 0, 12)
# SARIMAX (0, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =-235.29045266180623
# (0, 0, 1, 12)
# SARIMAX (0, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =-339.90094395901804
# (0, 0, 2, 12)
# SARIMAX (0, 1, 1) x (0, 0, 2, 12)12 : AIC Calculated =-371.867575345896
# (0, 1, 0, 12)
# SARIMAX (0, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =-399.05216798553306
# (0, 1, 1, 12)
# SARIMAX (0, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =-419.53391483178666
# (0, 1, 2, 12)
# SARIMAX (0, 1, 1) x (0, 1, 2, 12)12 : AIC Calculated =-418.7357732479196
# (0, 2, 0, 12)
# SARIMAX (0, 1, 1) x (0, 2, 0, 12)12 : AIC Calculated =-231.05340757755278
# (0, 2, 1, 12)
# SARIMAX (0, 1, 1) x (0, 2, 1, 12)12 : AIC Calculated =-237.47932627581918
# (0, 2, 2, 12)
# SARIMAX (0, 1, 1) x (0, 2, 2, 12)12 : AIC Calculated =-235.53632640400963
# (1, 0, 0, 12)
# SARIMAX (0, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =-410.0243411269223
# (1, 0, 1, 12)
# SARIMAX (0, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =-292.47706053143787
# (1, 0, 2, 12)
# SARIMAX (0, 1, 1) x (1, 0, 2, 12)12 : AIC Calculated =-426.3531211161593
# (1, 1, 0, 12)
# SARIMAX (0, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =-424.46712019724066
# (1, 1, 1, 12)
# SARIMAX (0, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =-427.79833606537136
# (1, 1, 2, 12)
# SARIMAX (0, 1, 1) x (1, 1, 2, 12)12 : AIC Calculated =-425.5718215286621
# (1, 2, 0, 12)
# SARIMAX (0, 1, 1) x (1, 2, 0, 12)12 : AIC Calculated =-290.37017497011925
# (1, 2, 1, 12)
# SARIMAX (0, 1, 1) x (1, 2, 1, 12)12 : AIC Calculated =-330.61142968587336
# (1, 2, 2, 12)
# SARIMAX (0, 1, 1) x (1, 2, 2, 12)12 : AIC Calculated =-312.7196859306619
# (2, 0, 0, 12)
# SARIMAX (0, 1, 1) x (2, 0, 0, 12)12 : AIC Calculated =-359.12438399105304
# (2, 0, 1, 12)
# SARIMAX (0, 1, 1) x (2, 0, 1, 12)12 : AIC Calculated =-405.8051133531505
# (2, 0, 2, 12)
# SARIMAX (0, 1, 1) x (2, 0, 2, 12)12 : AIC Calculated =-405.1493570789372
# (2, 1, 0, 12)
# SARIMAX (0, 1, 1) x (2, 1, 0, 12)12 : AIC Calculated =-434.526943439093
# (2, 1, 1, 12)
# SARIMAX (0, 1, 1) x (2, 1, 1, 12)12 : AIC Calculated =-425.43986825291506
# (2, 1, 2, 12)
# SARIMAX (0, 1, 1) x (2, 1, 2, 12)12 : AIC Calculated =-410.85824208379466
# (2, 2, 0, 12)
# SARIMAX (0, 1, 1) x (2, 2, 0, 12)12 : AIC Calculated =-339.78281578296344
# (2, 2, 1, 12)
# SARIMAX (0, 1, 1) x (2, 2, 1, 12)12 : AIC Calculated =-344.6346708903863
# (2, 2, 2, 12)
# SARIMAX (0, 1, 1) x (2, 2, 2, 12)12 : AIC Calculated =-313.7335051670757
# (0, 0, 0, 12)
# SARIMAX (0, 1, 2) x (0, 0, 0, 12)12 : AIC Calculated =-244.51788623078147
# (0, 0, 1, 12)
# SARIMAX (0, 1, 2) x (0, 0, 1, 12)12 : AIC Calculated =-333.99467780474015
# (0, 0, 2, 12)
# SARIMAX (0, 1, 2) x (0, 0, 2, 12)12 : AIC Calculated =-324.43397722391205
# (0, 1, 0, 12)
# SARIMAX (0, 1, 2) x (0, 1, 0, 12)12 : AIC Calculated =-392.3108080533958
# (0, 1, 1, 12)
# SARIMAX (0, 1, 2) x (0, 1, 1, 12)12 : AIC Calculated =-420.0276987097282
# (0, 1, 2, 12)
# SARIMAX (0, 1, 2) x (0, 1, 2, 12)12 : AIC Calculated =-419.72363285820313
# (0, 2, 0, 12)
# SARIMAX (0, 1, 2) x (0, 2, 0, 12)12 : AIC Calculated =-227.02460427592834
# (0, 2, 1, 12)
# SARIMAX (0, 1, 2) x (0, 2, 1, 12)12 : AIC Calculated =-281.4880884399533
# (0, 2, 2, 12)
# SARIMAX (0, 1, 2) x (0, 2, 2, 12)12 : AIC Calculated =-283.6852133670614
# (1, 0, 0, 12)
# SARIMAX (0, 1, 2) x (1, 0, 0, 12)12 : AIC Calculated =-406.5365939929821
# (1, 0, 1, 12)
# SARIMAX (0, 1, 2) x (1, 0, 1, 12)12 : AIC Calculated =59.17280152983394
# (1, 0, 2, 12)
# SARIMAX (0, 1, 2) x (1, 0, 2, 12)12 : AIC Calculated =-289.4282555437052
# (1, 1, 0, 12)
# SARIMAX (0, 1, 2) x (1, 1, 0, 12)12 : AIC Calculated =-421.1445650308797
# (1, 1, 1, 12)
# SARIMAX (0, 1, 2) x (1, 1, 1, 12)12 : AIC Calculated =-420.1353905431547
# (1, 1, 2, 12)
# SARIMAX (0, 1, 2) x (1, 1, 2, 12)12 : AIC Calculated =-414.5575880551546
# (1, 2, 0, 12)
# SARIMAX (0, 1, 2) x (1, 2, 0, 12)12 : AIC Calculated =-285.7479351912212
# (1, 2, 1, 12)
# SARIMAX (0, 1, 2) x (1, 2, 1, 12)12 : AIC Calculated =-329.50687450656176
# (1, 2, 2, 12)
# SARIMAX (0, 1, 2) x (1, 2, 2, 12)12 : AIC Calculated =-313.3923216110867
# (2, 0, 0, 12)
# SARIMAX (0, 1, 2) x (2, 0, 0, 12)12 : AIC Calculated =-387.9902489145144
# (2, 0, 1, 12)
# SARIMAX (0, 1, 2) x (2, 0, 1, 12)12 : AIC Calculated =-6.3936094163480774
# (2, 0, 2, 12)
# SARIMAX (0, 1, 2) x (2, 0, 2, 12)12 : AIC Calculated =-368.20591801086016
# (2, 1, 0, 12)
# SARIMAX (0, 1, 2) x (2, 1, 0, 12)12 : AIC Calculated =-424.6346305044643
# (2, 1, 1, 12)
# SARIMAX (0, 1, 2) x (2, 1, 1, 12)12 : AIC Calculated =-427.4720530513383
# (2, 1, 2, 12)
# SARIMAX (0, 1, 2) x (2, 1, 2, 12)12 : AIC Calculated =-410.1374179076713
# (2, 2, 0, 12)
# SARIMAX (0, 1, 2) x (2, 2, 0, 12)12 : AIC Calculated =-332.26839383443945
# (2, 2, 1, 12)
# SARIMAX (0, 1, 2) x (2, 2, 1, 12)12 : AIC Calculated =-339.1294007574825
# (2, 2, 2, 12)
# SARIMAX (0, 1, 2) x (2, 2, 2, 12)12 : AIC Calculated =-314.89386451120316
# (0, 0, 0, 12)
# SARIMAX (0, 2, 0) x (0, 0, 0, 12)12 : AIC Calculated =-79.75949873929792
# (0, 0, 1, 12)
# SARIMAX (0, 2, 0) x (0, 0, 1, 12)12 : AIC Calculated =-141.68516167187738
# (0, 0, 2, 12)
# SARIMAX (0, 2, 0) x (0, 0, 2, 12)12 : AIC Calculated =-169.251754704422
# (0, 1, 0, 12)
# SARIMAX (0, 2, 0) x (0, 1, 0, 12)12 : AIC Calculated =-258.85725473528714
# (0, 1, 1, 12)
# SARIMAX (0, 2, 0) x (0, 1, 1, 12)12 : AIC Calculated =-274.93247095442155
# (0, 1, 2, 12)
# SARIMAX (0, 2, 0) x (0, 1, 2, 12)12 : AIC Calculated =-277.1486917402152
# (0, 2, 0, 12)
# SARIMAX (0, 2, 0) x (0, 2, 0, 12)12 : AIC Calculated =-104.26808915076629
# (0, 2, 1, 12)
# SARIMAX (0, 2, 0) x (0, 2, 1, 12)12 : AIC Calculated =-102.2687692749506
# (0, 2, 2, 12)
# SARIMAX (0, 2, 0) x (0, 2, 2, 12)12 : AIC Calculated =-100.26869307557975
# (1, 0, 0, 12)
# SARIMAX (0, 2, 0) x (1, 0, 0, 12)12 : AIC Calculated =-215.5901486951958
# (1, 0, 1, 12)
# SARIMAX (0, 2, 0) x (1, 0, 1, 12)12 : AIC Calculated =-202.42140106314622
# (1, 0, 2, 12)
# SARIMAX (0, 2, 0) x (1, 0, 2, 12)12 : AIC Calculated =-215.04646969467873
# (1, 1, 0, 12)
# SARIMAX (0, 2, 0) x (1, 1, 0, 12)12 : AIC Calculated =-283.88287528669395
# (1, 1, 1, 12)
# SARIMAX (0, 2, 0) x (1, 1, 1, 12)12 : AIC Calculated =-280.3852220781206
# (1, 1, 2, 12)
# SARIMAX (0, 2, 0) x (1, 1, 2, 12)12 : AIC Calculated =-278.1661687741608
# (1, 2, 0, 12)
# SARIMAX (0, 2, 0) x (1, 2, 0, 12)12 : AIC Calculated =-179.74842000461643
# (1, 2, 1, 12)
# SARIMAX (0, 2, 0) x (1, 2, 1, 12)12 : AIC Calculated =-216.29190053875578
# (1, 2, 2, 12)
# SARIMAX (0, 2, 0) x (1, 2, 2, 12)12 : AIC Calculated =-197.56562761250407
# (2, 0, 0, 12)
# SARIMAX (0, 2, 0) x (2, 0, 0, 12)12 : AIC Calculated =-239.13050140363856
# (2, 0, 1, 12)
# SARIMAX (0, 2, 0) x (2, 0, 1, 12)12 : AIC Calculated =-234.82537250388805
# (2, 0, 2, 12)
# SARIMAX (0, 2, 0) x (2, 0, 2, 12)12 : AIC Calculated =-237.616757310225
# (2, 1, 0, 12)
# SARIMAX (0, 2, 0) x (2, 1, 0, 12)12 : AIC Calculated =-281.72393499908753
# (2, 1, 1, 12)
# SARIMAX (0, 2, 0) x (2, 1, 1, 12)12 : AIC Calculated =-279.13872283357364
# (2, 1, 2, 12)
# SARIMAX (0, 2, 0) x (2, 1, 2, 12)12 : AIC Calculated =-278.1190339414335
# (2, 2, 0, 12)
# SARIMAX (0, 2, 0) x (2, 2, 0, 12)12 : AIC Calculated =-202.30352259751504
# (2, 2, 1, 12)
# SARIMAX (0, 2, 0) x (2, 2, 1, 12)12 : AIC Calculated =-222.95953640241038
# (2, 2, 2, 12)
# SARIMAX (0, 2, 0) x (2, 2, 2, 12)12 : AIC Calculated =-226.40895103717247
# (0, 0, 0, 12)
# SARIMAX (0, 2, 1) x (0, 0, 0, 12)12 : AIC Calculated =-146.69092808597975
# (0, 0, 1, 12)
# SARIMAX (0, 2, 1) x (0, 0, 1, 12)12 : AIC Calculated =-169.8464258008621
# (0, 0, 2, 12)
# SARIMAX (0, 2, 1) x (0, 0, 2, 12)12 : AIC Calculated =-232.77455679814943
# (0, 1, 0, 12)
# SARIMAX (0, 2, 1) x (0, 1, 0, 12)12 : AIC Calculated =-332.90558879169953
# (0, 1, 1, 12)
# SARIMAX (0, 2, 1) x (0, 1, 1, 12)12 : AIC Calculated =-353.215574768417
# (0, 1, 2, 12)
# SARIMAX (0, 2, 1) x (0, 1, 2, 12)12 : AIC Calculated =-353.2164306556191
# (0, 2, 0, 12)
# SARIMAX (0, 2, 1) x (0, 2, 0, 12)12 : AIC Calculated =-162.14537593867183
# (0, 2, 1, 12)
# SARIMAX (0, 2, 1) x (0, 2, 1, 12)12 : AIC Calculated =-160.14590992934654
# (0, 2, 2, 12)
# SARIMAX (0, 2, 1) x (0, 2, 2, 12)12 : AIC Calculated =-158.14577902795423
# (1, 0, 0, 12)
# SARIMAX (0, 2, 1) x (1, 0, 0, 12)12 : AIC Calculated =-253.63082073293242
# (1, 0, 1, 12)
# SARIMAX (0, 2, 1) x (1, 0, 1, 12)12 : AIC Calculated =-188.68249015325995
# (1, 0, 2, 12)
# SARIMAX (0, 2, 1) x (1, 0, 2, 12)12 : AIC Calculated =-187.16500443385584
# (1, 1, 0, 12)
# SARIMAX (0, 2, 1) x (1, 1, 0, 12)12 : AIC Calculated =-356.39723663979305
# (1, 1, 1, 12)
# SARIMAX (0, 2, 1) x (1, 1, 1, 12)12 : AIC Calculated =-353.4606267286211
# (1, 1, 2, 12)
# SARIMAX (0, 2, 1) x (1, 1, 2, 12)12 : AIC Calculated =-346.34835001394805
# (1, 2, 0, 12)
# SARIMAX (0, 2, 1) x (1, 2, 0, 12)12 : AIC Calculated =-205.0821516076969
# (1, 2, 1, 12)
# SARIMAX (0, 2, 1) x (1, 2, 1, 12)12 : AIC Calculated =-213.54054513545339
# (1, 2, 2, 12)
# SARIMAX (0, 2, 1) x (1, 2, 2, 12)12 : AIC Calculated =-195.66535085105008
# (2, 0, 0, 12)
# SARIMAX (0, 2, 1) x (2, 0, 0, 12)12 : AIC Calculated =-264.00844026618995
# (2, 0, 1, 12)
# SARIMAX (0, 2, 1) x (2, 0, 1, 12)12 : AIC Calculated =-178.10900517121834
# (2, 0, 2, 12)
# SARIMAX (0, 2, 1) x (2, 0, 2, 12)12 : AIC Calculated =-181.34711046709933
# (2, 1, 0, 12)
# SARIMAX (0, 2, 1) x (2, 1, 0, 12)12 : AIC Calculated =-355.3305366179844
# (2, 1, 1, 12)
# SARIMAX (0, 2, 1) x (2, 1, 1, 12)12 : AIC Calculated =-352.0545666404099
# (2, 1, 2, 12)
# SARIMAX (0, 2, 1) x (2, 1, 2, 12)12 : AIC Calculated =-343.8655680357751
# (2, 2, 0, 12)
# SARIMAX (0, 2, 1) x (2, 2, 0, 12)12 : AIC Calculated =-210.9369324124375
# (2, 2, 1, 12)
# SARIMAX (0, 2, 1) x (2, 2, 1, 12)12 : AIC Calculated =-209.5460560030253
# (2, 2, 2, 12)
# SARIMAX (0, 2, 1) x (2, 2, 2, 12)12 : AIC Calculated =-205.9112193094225
# (0, 0, 0, 12)
# SARIMAX (0, 2, 2) x (0, 0, 0, 12)12 : AIC Calculated =-146.15324694483928
# (0, 0, 1, 12)
# SARIMAX (0, 2, 2) x (0, 0, 1, 12)12 : AIC Calculated =-198.7071966714362
# (0, 0, 2, 12)
# SARIMAX (0, 2, 2) x (0, 0, 2, 12)12 : AIC Calculated =-243.64604945132726
# (0, 1, 0, 12)
# SARIMAX (0, 2, 2) x (0, 1, 0, 12)12 : AIC Calculated =-328.47466365608074
# (0, 1, 1, 12)
# SARIMAX (0, 2, 2) x (0, 1, 1, 12)12 : AIC Calculated =-349.1857613417824
# (0, 1, 2, 12)
# SARIMAX (0, 2, 2) x (0, 1, 2, 12)12 : AIC Calculated =-348.7882770473068
# (0, 2, 0, 12)
# SARIMAX (0, 2, 2) x (0, 2, 0, 12)12 : AIC Calculated =-158.47875163092834
# (0, 2, 1, 12)
# SARIMAX (0, 2, 2) x (0, 2, 1, 12)12 : AIC Calculated =-156.47919909135328
# (0, 2, 2, 12)
# SARIMAX (0, 2, 2) x (0, 2, 2, 12)12 : AIC Calculated =-154.47910447534016
# (1, 0, 0, 12)
# SARIMAX (0, 2, 2) x (1, 0, 0, 12)12 : AIC Calculated =-174.98656305049377
# (1, 0, 1, 12)
# SARIMAX (0, 2, 2) x (1, 0, 1, 12)12 : AIC Calculated =-184.82493898973803
# (1, 0, 2, 12)
# SARIMAX (0, 2, 2) x (1, 0, 2, 12)12 : AIC Calculated =-183.38308449260916
# (1, 1, 0, 12)
# SARIMAX (0, 2, 2) x (1, 1, 0, 12)12 : AIC Calculated =-351.50029734669374
# (1, 1, 1, 12)
# SARIMAX (0, 2, 2) x (1, 1, 1, 12)12 : AIC Calculated =-348.4832166732567
# (1, 1, 2, 12)
# SARIMAX (0, 2, 2) x (1, 1, 2, 12)12 : AIC Calculated =-342.16125333926294
# (1, 2, 0, 12)
# SARIMAX (0, 2, 2) x (1, 2, 0, 12)12 : AIC Calculated =-200.09672397822965
# (1, 2, 1, 12)
# SARIMAX (0, 2, 2) x (1, 2, 1, 12)12 : AIC Calculated =-209.08779077909554
# (1, 2, 2, 12)
# SARIMAX (0, 2, 2) x (1, 2, 2, 12)12 : AIC Calculated =-190.539034570746
# (2, 0, 0, 12)
# SARIMAX (0, 2, 2) x (2, 0, 0, 12)12 : AIC Calculated =-171.95681496420457
# (2, 0, 1, 12)
# SARIMAX (0, 2, 2) x (2, 0, 1, 12)12 : AIC Calculated =-174.06222382770537
# (2, 0, 2, 12)
# SARIMAX (0, 2, 2) x (2, 0, 2, 12)12 : AIC Calculated =-177.37337380093118
# (2, 1, 0, 12)
# SARIMAX (0, 2, 2) x (2, 1, 0, 12)12 : AIC Calculated =-350.61620828735477
# (2, 1, 1, 12)
# SARIMAX (0, 2, 2) x (2, 1, 1, 12)12 : AIC Calculated =-347.1709775857522
# (2, 1, 2, 12)
# SARIMAX (0, 2, 2) x (2, 1, 2, 12)12 : AIC Calculated =-339.72976402907466
# (2, 2, 0, 12)
# SARIMAX (0, 2, 2) x (2, 2, 0, 12)12 : AIC Calculated =-257.6551276206584
# (2, 2, 1, 12)
# SARIMAX (0, 2, 2) x (2, 2, 1, 12)12 : AIC Calculated =-204.98894542910529
# (2, 2, 2, 12)
# SARIMAX (0, 2, 2) x (2, 2, 2, 12)12 : AIC Calculated =-201.07767258987406
# (0, 0, 0, 12)
# SARIMAX (1, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =-342.8430498364541
# (0, 0, 1, 12)
# SARIMAX (1, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =-384.42001500341485
# (0, 0, 2, 12)
# SARIMAX (1, 0, 0) x (0, 0, 2, 12)12 : AIC Calculated =-417.1139046208958
# (0, 1, 0, 12)
# SARIMAX (1, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =-437.18204359920094
# (0, 1, 1, 12)
# SARIMAX (1, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =-460.11706012585535
# (0, 1, 2, 12)
# SARIMAX (1, 0, 0) x (0, 1, 2, 12)12 : AIC Calculated =-469.18602117237174
# (0, 2, 0, 12)
# SARIMAX (1, 0, 0) x (0, 2, 0, 12)12 : AIC Calculated =-276.2266002035791
# (0, 2, 1, 12)
# SARIMAX (1, 0, 0) x (0, 2, 1, 12)12 : AIC Calculated =-274.2266248210071
# (0, 2, 2, 12)
# SARIMAX (1, 0, 0) x (0, 2, 2, 12)12 : AIC Calculated =-272.226624867053
# (1, 0, 0, 12)
# SARIMAX (1, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =-452.9202183346039
# (1, 0, 1, 12)
# SARIMAX (1, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =-320.0740627525706
# (1, 0, 2, 12)
# SARIMAX (1, 0, 0) x (1, 0, 2, 12)12 : AIC Calculated =-470.0351255659988
# (1, 1, 0, 12)
# SARIMAX (1, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =-458.6771059297193
# (1, 1, 1, 12)
# SARIMAX (1, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =-467.0954313428225
# (1, 1, 2, 12)
# SARIMAX (1, 0, 0) x (1, 1, 2, 12)12 : AIC Calculated =-464.3021444258046
# (1, 2, 0, 12)
# SARIMAX (1, 0, 0) x (1, 2, 0, 12)12 : AIC Calculated =-323.9834496019331
# (1, 2, 1, 12)
# SARIMAX (1, 0, 0) x (1, 2, 1, 12)12 : AIC Calculated =-327.3396075482615
# (1, 2, 2, 12)
# SARIMAX (1, 0, 0) x (1, 2, 2, 12)12 : AIC Calculated =-321.22118582191047
# (2, 0, 0, 12)
# SARIMAX (1, 0, 0) x (2, 0, 0, 12)12 : AIC Calculated =-338.843051469491
# (2, 0, 1, 12)
# SARIMAX (1, 0, 0) x (2, 0, 1, 12)12 : AIC Calculated =-315.2660440516713
# (2, 0, 2, 12)
# SARIMAX (1, 0, 0) x (2, 0, 2, 12)12 : AIC Calculated =-329.64201151724575
# (2, 1, 0, 12)
# SARIMAX (1, 0, 0) x (2, 1, 0, 12)12 : AIC Calculated =-471.557205374323
# (2, 1, 1, 12)
# SARIMAX (1, 0, 0) x (2, 1, 1, 12)12 : AIC Calculated =-470.7886223277871
# (2, 1, 2, 12)
# SARIMAX (1, 0, 0) x (2, 1, 2, 12)12 : AIC Calculated =-465.99551546376705
# (2, 2, 0, 12)
# SARIMAX (1, 0, 0) x (2, 2, 0, 12)12 : AIC Calculated =-372.5405569927902
# (2, 2, 1, 12)
# SARIMAX (1, 0, 0) x (2, 2, 1, 12)12 : AIC Calculated =-373.16603021493427
# (2, 2, 2, 12)
# SARIMAX (1, 0, 0) x (2, 2, 2, 12)12 : AIC Calculated =-318.21662791308535
# (0, 0, 0, 12)
# SARIMAX (1, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =-324.3674074732603
# (0, 0, 1, 12)
# SARIMAX (1, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =-395.6254711736212
# (0, 0, 2, 12)
# SARIMAX (1, 0, 1) x (0, 0, 2, 12)12 : AIC Calculated =-413.79689742103477
# (0, 1, 0, 12)
# SARIMAX (1, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =-435.28088633663447
# (0, 1, 1, 12)
# SARIMAX (1, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =-457.74160153099297
# (0, 1, 2, 12)
# SARIMAX (1, 0, 1) x (0, 1, 2, 12)12 : AIC Calculated =-465.7751334525987
# (0, 2, 0, 12)
# SARIMAX (1, 0, 1) x (0, 2, 0, 12)12 : AIC Calculated =-274.9055901997365
# (0, 2, 1, 12)
# SARIMAX (1, 0, 1) x (0, 2, 1, 12)12 : AIC Calculated =-272.9055935695802
# (0, 2, 2, 12)
# SARIMAX (1, 0, 1) x (0, 2, 2, 12)12 : AIC Calculated =-270.9055936518011
# (1, 0, 0, 12)
# SARIMAX (1, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =-446.1837507697366
# (1, 0, 1, 12)
# SARIMAX (1, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =-303.68481164799186
# (1, 0, 2, 12)
# SARIMAX (1, 0, 1) x (1, 0, 2, 12)12 : AIC Calculated =-462.6566385554977
# (1, 1, 0, 12)
# SARIMAX (1, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =-463.94449270125347
# (1, 1, 1, 12)
# SARIMAX (1, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =-465.88896587093495
# (1, 1, 2, 12)
# SARIMAX (1, 0, 1) x (1, 1, 2, 12)12 : AIC Calculated =-453.36576745977425
# (1, 2, 0, 12)
# SARIMAX (1, 0, 1) x (1, 2, 0, 12)12 : AIC Calculated =-308.587192966977
# (1, 2, 1, 12)
# SARIMAX (1, 0, 1) x (1, 2, 1, 12)12 : AIC Calculated =-323.68902284304284
# (1, 2, 2, 12)
# SARIMAX (1, 0, 1) x (1, 2, 2, 12)12 : AIC Calculated =-305.23424183322527
# (2, 0, 0, 12)
# SARIMAX (1, 0, 1) x (2, 0, 0, 12)12 : AIC Calculated =-459.38924620741125
# (2, 0, 1, 12)
# SARIMAX (1, 0, 1) x (2, 0, 1, 12)12 : AIC Calculated =-467.21911256191606
# (2, 0, 2, 12)
# SARIMAX (1, 0, 1) x (2, 0, 2, 12)12 : AIC Calculated =-463.16669947332446
# (2, 1, 0, 12)
# SARIMAX (1, 0, 1) x (2, 1, 0, 12)12 : AIC Calculated =-468.44179007967125
# (2, 1, 1, 12)
# SARIMAX (1, 0, 1) x (2, 1, 1, 12)12 : AIC Calculated =-468.863883685544
# (2, 1, 2, 12)
# SARIMAX (1, 0, 1) x (2, 1, 2, 12)12 : AIC Calculated =-464.48264650504956
# (2, 2, 0, 12)
# SARIMAX (1, 0, 1) x (2, 2, 0, 12)12 : AIC Calculated =-318.76368479291585
# (2, 2, 1, 12)
# SARIMAX (1, 0, 1) x (2, 2, 1, 12)12 : AIC Calculated =-320.4630676382875
# (2, 2, 2, 12)
# SARIMAX (1, 0, 1) x (2, 2, 2, 12)12 : AIC Calculated =-313.21168339447763
# (0, 0, 0, 12)
# SARIMAX (1, 0, 2) x (0, 0, 0, 12)12 : AIC Calculated =-347.91396248600347
# (0, 0, 1, 12)
# SARIMAX (1, 0, 2) x (0, 0, 1, 12)12 : AIC Calculated =-409.31643328053764
# (0, 0, 2, 12)
# SARIMAX (1, 0, 2) x (0, 0, 2, 12)12 : AIC Calculated =-440.4060318151484
# (0, 1, 0, 12)
# SARIMAX (1, 0, 2) x (0, 1, 0, 12)12 : AIC Calculated =-433.1631588662499
# (0, 1, 1, 12)
# SARIMAX (1, 0, 2) x (0, 1, 1, 12)12 : AIC Calculated =-453.98062477201677
# (0, 1, 2, 12)
# SARIMAX (1, 0, 2) x (0, 1, 2, 12)12 : AIC Calculated =-454.0140284857404
# (0, 2, 0, 12)
# SARIMAX (1, 0, 2) x (0, 2, 0, 12)12 : AIC Calculated =-272.21827866251306
# (0, 2, 1, 12)
# SARIMAX (1, 0, 2) x (0, 2, 1, 12)12 : AIC Calculated =-270.43203126223443
# (0, 2, 2, 12)
# SARIMAX (1, 0, 2) x (0, 2, 2, 12)12 : AIC Calculated =-268.432415026749
# (1, 0, 0, 12)
# SARIMAX (1, 0, 2) x (1, 0, 0, 12)12 : AIC Calculated =-466.0134674833981
# (1, 0, 1, 12)
# SARIMAX (1, 0, 2) x (1, 0, 1, 12)12 : AIC Calculated =-159.0489917164168
# (1, 0, 2, 12)
# SARIMAX (1, 0, 2) x (1, 0, 2, 12)12 : AIC Calculated =-476.40892228728177
# (1, 1, 0, 12)
# SARIMAX (1, 0, 2) x (1, 1, 0, 12)12 : AIC Calculated =-452.8117623170058
# (1, 1, 1, 12)
# SARIMAX (1, 0, 2) x (1, 1, 1, 12)12 : AIC Calculated =-452.8322206941417
# (1, 1, 2, 12)
# SARIMAX (1, 0, 2) x (1, 1, 2, 12)12 : AIC Calculated =-449.6284152355076
# (1, 2, 0, 12)
# SARIMAX (1, 0, 2) x (1, 2, 0, 12)12 : AIC Calculated =-323.0656739544461
# (1, 2, 1, 12)
# SARIMAX (1, 0, 2) x (1, 2, 1, 12)12 : AIC Calculated =-326.64272626526747
# (1, 2, 2, 12)
# SARIMAX (1, 0, 2) x (1, 2, 2, 12)12 : AIC Calculated =-317.3023095168469
# (2, 0, 0, 12)
# SARIMAX (1, 0, 2) x (2, 0, 0, 12)12 : AIC Calculated =-430.9475196972181
# (2, 0, 1, 12)
# SARIMAX (1, 0, 2) x (2, 0, 1, 12)12 : AIC Calculated =-403.51281420238774
# (2, 0, 2, 12)
# SARIMAX (1, 0, 2) x (2, 0, 2, 12)12 : AIC Calculated =-410.1525268020558
# (2, 1, 0, 12)
# SARIMAX (1, 0, 2) x (2, 1, 0, 12)12 : AIC Calculated =-454.9048151268227
# (2, 1, 1, 12)
# SARIMAX (1, 0, 2) x (2, 1, 1, 12)12 : AIC Calculated =-454.2754298094717
# (2, 1, 2, 12)
# SARIMAX (1, 0, 2) x (2, 1, 2, 12)12 : AIC Calculated =-451.1065582996807
# (2, 2, 0, 12)
# SARIMAX (1, 0, 2) x (2, 2, 0, 12)12 : AIC Calculated =-365.92636296867715
# (2, 2, 1, 12)
# SARIMAX (1, 0, 2) x (2, 2, 1, 12)12 : AIC Calculated =-372.8868065140433
# (2, 2, 2, 12)
# SARIMAX (1, 0, 2) x (2, 2, 2, 12)12 : AIC Calculated =-376.9276150317055
# (0, 0, 0, 12)
# SARIMAX (1, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =-227.24860189734528
# (0, 0, 1, 12)
# SARIMAX (1, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =-316.47124194918933
# (0, 0, 2, 12)
# SARIMAX (1, 1, 0) x (0, 0, 2, 12)12 : AIC Calculated =-322.4167747740866
# (0, 1, 0, 12)
# SARIMAX (1, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =-387.9452375917078
# (0, 1, 1, 12)
# SARIMAX (1, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =-408.6041227188237
# (0, 1, 2, 12)
# SARIMAX (1, 1, 0) x (0, 1, 2, 12)12 : AIC Calculated =-408.5469617541663
# (0, 2, 0, 12)
# SARIMAX (1, 1, 0) x (0, 2, 0, 12)12 : AIC Calculated =-223.43420276883873
# (0, 2, 1, 12)
# SARIMAX (1, 1, 0) x (0, 2, 1, 12)12 : AIC Calculated =-305.1545427502277
# (0, 2, 2, 12)
# SARIMAX (1, 1, 0) x (0, 2, 2, 12)12 : AIC Calculated =-311.9081921273231
# (1, 0, 0, 12)
# SARIMAX (1, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =-380.93009814692454
# (1, 0, 1, 12)
# SARIMAX (1, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =-390.30862430528873
# (1, 0, 2, 12)
# SARIMAX (1, 1, 0) x (1, 0, 2, 12)12 : AIC Calculated =-394.79027542684094
# (1, 1, 0, 12)
# SARIMAX (1, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =-416.5343919210622
# (1, 1, 1, 12)
# SARIMAX (1, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =-414.9426427729496
# (1, 1, 2, 12)
# SARIMAX (1, 1, 0) x (1, 1, 2, 12)12 : AIC Calculated =-409.96990442955007
# (1, 2, 0, 12)
# SARIMAX (1, 1, 0) x (1, 2, 0, 12)12 : AIC Calculated =-278.4044038128919
# (1, 2, 1, 12)
# SARIMAX (1, 1, 0) x (1, 2, 1, 12)12 : AIC Calculated =-328.4690831167018
# (1, 2, 2, 12)
# SARIMAX (1, 1, 0) x (1, 2, 2, 12)12 : AIC Calculated =-268.5260298538137
# (2, 0, 0, 12)
# SARIMAX (1, 1, 0) x (2, 0, 0, 12)12 : AIC Calculated =-392.597341206299
# (2, 0, 1, 12)
# SARIMAX (1, 1, 0) x (2, 0, 1, 12)12 : AIC Calculated =-395.81775649540737
# (2, 0, 2, 12)
# SARIMAX (1, 1, 0) x (2, 0, 2, 12)12 : AIC Calculated =-391.53026935677326
# (2, 1, 0, 12)
# SARIMAX (1, 1, 0) x (2, 1, 0, 12)12 : AIC Calculated =-422.1333341285424
# (2, 1, 1, 12)
# SARIMAX (1, 1, 0) x (2, 1, 1, 12)12 : AIC Calculated =-418.8227644511303
# (2, 1, 2, 12)
# SARIMAX (1, 1, 0) x (2, 1, 2, 12)12 : AIC Calculated =-421.1588910435503
# (2, 2, 0, 12)
# SARIMAX (1, 1, 0) x (2, 2, 0, 12)12 : AIC Calculated =-324.858009756501
# (2, 2, 1, 12)
# SARIMAX (1, 1, 0) x (2, 2, 1, 12)12 : AIC Calculated =-331.61371853485457
# (2, 2, 2, 12)
# SARIMAX (1, 1, 0) x (2, 2, 2, 12)12 : AIC Calculated =-333.5643476651796
# (0, 0, 0, 12)
# SARIMAX (1, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =-219.29557045012484
# (0, 0, 1, 12)
# SARIMAX (1, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =-333.94256314944647
# (0, 0, 2, 12)
# SARIMAX (1, 1, 1) x (0, 0, 2, 12)12 : AIC Calculated =-299.3588934496023
# (0, 1, 0, 12)
# SARIMAX (1, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =-392.95607724435564
# (0, 1, 1, 12)
# SARIMAX (1, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =-419.6995640853563
# (0, 1, 2, 12)
# SARIMAX (1, 1, 1) x (0, 1, 2, 12)12 : AIC Calculated =-419.44246158625845
# (0, 2, 0, 12)
# SARIMAX (1, 1, 1) x (0, 2, 0, 12)12 : AIC Calculated =-240.82173406541853
# (0, 2, 1, 12)
# SARIMAX (1, 1, 1) x (0, 2, 1, 12)12 : AIC Calculated =-281.38051702601035
# (0, 2, 2, 12)
# SARIMAX (1, 1, 1) x (0, 2, 2, 12)12 : AIC Calculated =-233.8455735691736
# (1, 0, 0, 12)
# SARIMAX (1, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =-410.18545679407174
# (1, 0, 1, 12)
# SARIMAX (1, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =-292.74081074077475
# (1, 0, 2, 12)
# SARIMAX (1, 1, 1) x (1, 0, 2, 12)12 : AIC Calculated =-374.4508678453956
# (1, 1, 0, 12)
# SARIMAX (1, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =-415.4985024479498
# (1, 1, 1, 12)
# SARIMAX (1, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =-414.20799458052755
# (1, 1, 2, 12)
# SARIMAX (1, 1, 1) x (1, 1, 2, 12)12 : AIC Calculated =-414.2494562691517
# (1, 2, 0, 12)
# SARIMAX (1, 1, 1) x (1, 2, 0, 12)12 : AIC Calculated =-287.8036259746543
# (1, 2, 1, 12)
# SARIMAX (1, 1, 1) x (1, 2, 1, 12)12 : AIC Calculated =-329.35221275524896
# (1, 2, 2, 12)
# SARIMAX (1, 1, 1) x (1, 2, 2, 12)12 : AIC Calculated =-311.65565384383336
# (2, 0, 0, 12)
# SARIMAX (1, 1, 1) x (2, 0, 0, 12)12 : AIC Calculated =-408.07681241086925
# (2, 0, 1, 12)
# SARIMAX (1, 1, 1) x (2, 0, 1, 12)12 : AIC Calculated =-392.15874587757366
# (2, 0, 2, 12)
# SARIMAX (1, 1, 1) x (2, 0, 2, 12)12 : AIC Calculated =-355.87255262336987
# (2, 1, 0, 12)
# SARIMAX (1, 1, 1) x (2, 1, 0, 12)12 : AIC Calculated =-424.1986135462614
# (2, 1, 1, 12)
# SARIMAX (1, 1, 1) x (2, 1, 1, 12)12 : AIC Calculated =-422.45174477508374
# (2, 1, 2, 12)
# SARIMAX (1, 1, 1) x (2, 1, 2, 12)12 : AIC Calculated =-410.79934163360474
# (2, 2, 0, 12)
# SARIMAX (1, 1, 1) x (2, 2, 0, 12)12 : AIC Calculated =-334.8916125290205
# (2, 2, 1, 12)
# SARIMAX (1, 1, 1) x (2, 2, 1, 12)12 : AIC Calculated =-338.55303476309007
# (2, 2, 2, 12)
# SARIMAX (1, 1, 1) x (2, 2, 2, 12)12 : AIC Calculated =-345.1176655294861
# (0, 0, 0, 12)
# SARIMAX (1, 1, 2) x (0, 0, 0, 12)12 : AIC Calculated =-252.28399483899915
# (0, 0, 1, 12)
# SARIMAX (1, 1, 2) x (0, 0, 1, 12)12 : AIC Calculated =-323.1089146269786
# (0, 0, 2, 12)
# SARIMAX (1, 1, 2) x (0, 0, 2, 12)12 : AIC Calculated =-380.54044829379814
# (0, 1, 0, 12)
# SARIMAX (1, 1, 2) x (0, 1, 0, 12)12 : AIC Calculated =-389.7275436447592
# (0, 1, 1, 12)
# SARIMAX (1, 1, 2) x (0, 1, 1, 12)12 : AIC Calculated =-423.96958926768934
# (0, 1, 2, 12)
# SARIMAX (1, 1, 2) x (0, 1, 2, 12)12 : AIC Calculated =-411.2690428146974
# (0, 2, 0, 12)
# SARIMAX (1, 1, 2) x (0, 2, 0, 12)12 : AIC Calculated =-235.55427490884136
# (0, 2, 1, 12)
# SARIMAX (1, 1, 2) x (0, 2, 1, 12)12 : AIC Calculated =-276.8722595371076
# (0, 2, 2, 12)
# SARIMAX (1, 1, 2) x (0, 2, 2, 12)12 : AIC Calculated =-281.36591233990424
# (1, 0, 0, 12)
# SARIMAX (1, 1, 2) x (1, 0, 0, 12)12 : AIC Calculated =-409.48538875165536
# (1, 0, 1, 12)
# SARIMAX (1, 1, 2) x (1, 0, 1, 12)12 : AIC Calculated =-250.14643736334153
# (1, 0, 2, 12)
# SARIMAX (1, 1, 2) x (1, 0, 2, 12)12 : AIC Calculated =-390.394971566903
# (1, 1, 0, 12)
# SARIMAX (1, 1, 2) x (1, 1, 0, 12)12 : AIC Calculated =-412.81888710534787
# (1, 1, 1, 12)
# SARIMAX (1, 1, 2) x (1, 1, 1, 12)12 : AIC Calculated =-427.04034207832956
# (1, 1, 2, 12)
# SARIMAX (1, 1, 2) x (1, 1, 2, 12)12 : AIC Calculated =-407.1330883012306
# (1, 2, 0, 12)
# SARIMAX (1, 1, 2) x (1, 2, 0, 12)12 : AIC Calculated =-277.05275277106654
# (1, 2, 1, 12)
# SARIMAX (1, 1, 2) x (1, 2, 1, 12)12 : AIC Calculated =-316.9256659081761
# (1, 2, 2, 12)
# SARIMAX (1, 1, 2) x (1, 2, 2, 12)12 : AIC Calculated =-290.34211533716945
# (2, 0, 0, 12)
# SARIMAX (1, 1, 2) x (2, 0, 0, 12)12 : AIC Calculated =-383.6147910028502
# (2, 0, 1, 12)
# SARIMAX (1, 1, 2) x (2, 0, 1, 12)12 : AIC Calculated =-338.0849664720621
# (2, 0, 2, 12)
# SARIMAX (1, 1, 2) x (2, 0, 2, 12)12 : AIC Calculated =-360.4365458042495
# (2, 1, 0, 12)
# SARIMAX (1, 1, 2) x (2, 1, 0, 12)12 : AIC Calculated =-414.7069001996009
# (2, 1, 1, 12)
# SARIMAX (1, 1, 2) x (2, 1, 1, 12)12 : AIC Calculated =-427.43142846512546
# (2, 1, 2, 12)
# SARIMAX (1, 1, 2) x (2, 1, 2, 12)12 : AIC Calculated =-432.7915688298392
# (2, 2, 0, 12)
# SARIMAX (1, 1, 2) x (2, 2, 0, 12)12 : AIC Calculated =-311.0392942210249
# (2, 2, 1, 12)
# SARIMAX (1, 1, 2) x (2, 2, 1, 12)12 : AIC Calculated =-337.02828583371604
# (2, 2, 2, 12)
# SARIMAX (1, 1, 2) x (2, 2, 2, 12)12 : AIC Calculated =-307.42182379213756
# (0, 0, 0, 12)
# SARIMAX (1, 2, 0) x (0, 0, 0, 12)12 : AIC Calculated =-110.49692753880919
# (0, 0, 1, 12)
# SARIMAX (1, 2, 0) x (0, 0, 1, 12)12 : AIC Calculated =-174.65141645460415
# (0, 0, 2, 12)
# SARIMAX (1, 2, 0) x (0, 0, 2, 12)12 : AIC Calculated =-199.89325331226718
# (0, 1, 0, 12)
# SARIMAX (1, 2, 0) x (0, 1, 0, 12)12 : AIC Calculated =-301.1890248145178
# (0, 1, 1, 12)
# SARIMAX (1, 2, 0) x (0, 1, 1, 12)12 : AIC Calculated =-316.020970637523
# (0, 1, 2, 12)
# SARIMAX (1, 2, 0) x (0, 1, 2, 12)12 : AIC Calculated =-317.2043983590431
# (0, 2, 0, 12)
# SARIMAX (1, 2, 0) x (0, 2, 0, 12)12 : AIC Calculated =-142.71675912521133
# (0, 2, 1, 12)
# SARIMAX (1, 2, 0) x (0, 2, 1, 12)12 : AIC Calculated =-140.71720077697375
# (0, 2, 2, 12)
# SARIMAX (1, 2, 0) x (0, 2, 2, 12)12 : AIC Calculated =-138.71716537846126
# (1, 0, 0, 12)
# SARIMAX (1, 2, 0) x (1, 0, 0, 12)12 : AIC Calculated =-241.01466709498408
# (1, 0, 1, 12)
# SARIMAX (1, 2, 0) x (1, 0, 1, 12)12 : AIC Calculated =-259.48453176118437
# (1, 0, 2, 12)
# SARIMAX (1, 2, 0) x (1, 0, 2, 12)12 : AIC Calculated =-241.07329360742847
# (1, 1, 0, 12)
# SARIMAX (1, 2, 0) x (1, 1, 0, 12)12 : AIC Calculated =-325.0764354373492
# (1, 1, 1, 12)
# SARIMAX (1, 2, 0) x (1, 1, 1, 12)12 : AIC Calculated =-322.55734560968915
# (1, 1, 2, 12)
# SARIMAX (1, 2, 0) x (1, 1, 2, 12)12 : AIC Calculated =-320.14608828092685
# (1, 2, 0, 12)
# SARIMAX (1, 2, 0) x (1, 2, 0, 12)12 : AIC Calculated =-210.34794196274277
# (1, 2, 1, 12)
# SARIMAX (1, 2, 0) x (1, 2, 1, 12)12 : AIC Calculated =-246.6008253640536
# (1, 2, 2, 12)
# SARIMAX (1, 2, 0) x (1, 2, 2, 12)12 : AIC Calculated =-232.29412335698032
# (2, 0, 0, 12)
# SARIMAX (1, 2, 0) x (2, 0, 0, 12)12 : AIC Calculated =-223.47498001569357
# (2, 0, 1, 12)
# SARIMAX (1, 2, 0) x (2, 0, 1, 12)12 : AIC Calculated =-259.1121261434972
# (2, 0, 2, 12)
# SARIMAX (1, 2, 0) x (2, 0, 2, 12)12 : AIC Calculated =-239.61475508757246
# (2, 1, 0, 12)
# SARIMAX (1, 2, 0) x (2, 1, 0, 12)12 : AIC Calculated =-326.5243386678195
# (2, 1, 1, 12)
# SARIMAX (1, 2, 0) x (2, 1, 1, 12)12 : AIC Calculated =-324.4650012201286
# (2, 1, 2, 12)
# SARIMAX (1, 2, 0) x (2, 1, 2, 12)12 : AIC Calculated =-319.9819326496961
# (2, 2, 0, 12)
# SARIMAX (1, 2, 0) x (2, 2, 0, 12)12 : AIC Calculated =-246.37221842204372
# (2, 2, 1, 12)
# SARIMAX (1, 2, 0) x (2, 2, 1, 12)12 : AIC Calculated =-238.78396595770806
# (2, 2, 2, 12)
# SARIMAX (1, 2, 0) x (2, 2, 2, 12)12 : AIC Calculated =-214.0028948676559
# (0, 0, 0, 12)
# SARIMAX (1, 2, 1) x (0, 0, 0, 12)12 : AIC Calculated =-137.3967062318319
# (0, 0, 1, 12)
# SARIMAX (1, 2, 1) x (0, 0, 1, 12)12 : AIC Calculated =-206.42338735974695
# (0, 0, 2, 12)
# SARIMAX (1, 2, 1) x (0, 0, 2, 12)12 : AIC Calculated =-228.6209865794183
# (0, 1, 0, 12)
# SARIMAX (1, 2, 1) x (0, 1, 0, 12)12 : AIC Calculated =-329.0442754401611
# (0, 1, 1, 12)
# SARIMAX (1, 2, 1) x (0, 1, 1, 12)12 : AIC Calculated =-349.8729104924322
# (0, 1, 2, 12)
# SARIMAX (1, 2, 1) x (0, 1, 2, 12)12 : AIC Calculated =-349.6443119512488
# (0, 2, 0, 12)
# SARIMAX (1, 2, 1) x (0, 2, 0, 12)12 : AIC Calculated =-158.89331169821594
# (0, 2, 1, 12)
# SARIMAX (1, 2, 1) x (0, 2, 1, 12)12 : AIC Calculated =-156.8937994613927
# (0, 2, 2, 12)
# SARIMAX (1, 2, 1) x (0, 2, 2, 12)12 : AIC Calculated =-154.8936992998796
# (1, 0, 0, 12)
# SARIMAX (1, 2, 1) x (1, 0, 0, 12)12 : AIC Calculated =-278.05432281966864
# (1, 0, 1, 12)
# SARIMAX (1, 2, 1) x (1, 0, 1, 12)12 : AIC Calculated =-190.58417348617652
# (1, 0, 2, 12)
# SARIMAX (1, 2, 1) x (1, 0, 2, 12)12 : AIC Calculated =-188.80348329712245
# (1, 1, 0, 12)
# SARIMAX (1, 2, 1) x (1, 1, 0, 12)12 : AIC Calculated =-352.4041986158596
# (1, 1, 1, 12)
# SARIMAX (1, 2, 1) x (1, 1, 1, 12)12 : AIC Calculated =-349.401803151537
# (1, 1, 2, 12)
# SARIMAX (1, 2, 1) x (1, 1, 2, 12)12 : AIC Calculated =-342.873580988012
# (1, 2, 0, 12)
# SARIMAX (1, 2, 1) x (1, 2, 0, 12)12 : AIC Calculated =-225.03316698932102
# (1, 2, 1, 12)
# SARIMAX (1, 2, 1) x (1, 2, 1, 12)12 : AIC Calculated =-211.55602924897275
# (1, 2, 2, 12)
# SARIMAX (1, 2, 1) x (1, 2, 2, 12)12 : AIC Calculated =-215.1757423047008
# (2, 0, 0, 12)
# SARIMAX (1, 2, 1) x (2, 0, 0, 12)12 : AIC Calculated =-288.87600287615976
# (2, 0, 1, 12)
# SARIMAX (1, 2, 1) x (2, 0, 1, 12)12 : AIC Calculated =-246.07329557078754
# (2, 0, 2, 12)
# SARIMAX (1, 2, 1) x (2, 0, 2, 12)12 : AIC Calculated =-280.94159481030675
# (2, 1, 0, 12)
# SARIMAX (1, 2, 1) x (2, 1, 0, 12)12 : AIC Calculated =-351.47996042829453
# (2, 1, 1, 12)
# SARIMAX (1, 2, 1) x (2, 1, 1, 12)12 : AIC Calculated =-348.0767376864869
# (2, 1, 2, 12)
# SARIMAX (1, 2, 1) x (2, 1, 2, 12)12 : AIC Calculated =-340.447022149549
# (2, 2, 0, 12)
# SARIMAX (1, 2, 1) x (2, 2, 0, 12)12 : AIC Calculated =-257.3804985132935
# (2, 2, 1, 12)
# SARIMAX (1, 2, 1) x (2, 2, 1, 12)12 : AIC Calculated =-207.43890970699735
# (2, 2, 2, 12)
# SARIMAX (1, 2, 1) x (2, 2, 2, 12)12 : AIC Calculated =-254.06008520627375
# (0, 0, 0, 12)
# SARIMAX (1, 2, 2) x (0, 0, 0, 12)12 : AIC Calculated =-159.5542942156607
# (0, 0, 1, 12)
# SARIMAX (1, 2, 2) x (0, 0, 1, 12)12 : AIC Calculated =-207.93985226043645
# (0, 0, 2, 12)
# SARIMAX (1, 2, 2) x (0, 0, 2, 12)12 : AIC Calculated =-234.3431039080358
# (0, 1, 0, 12)
# SARIMAX (1, 2, 2) x (0, 1, 0, 12)12 : AIC Calculated =-327.061450049728
# (0, 1, 1, 12)
# SARIMAX (1, 2, 2) x (0, 1, 1, 12)12 : AIC Calculated =-347.25863052493617
# (0, 1, 2, 12)
# SARIMAX (1, 2, 2) x (0, 1, 2, 12)12 : AIC Calculated =-346.98965441986513
# (0, 2, 0, 12)
# SARIMAX (1, 2, 2) x (0, 2, 0, 12)12 : AIC Calculated =-157.8117416798745
# (0, 2, 1, 12)
# SARIMAX (1, 2, 2) x (0, 2, 1, 12)12 : AIC Calculated =-155.81205215761872
# (0, 2, 2, 12)
# SARIMAX (1, 2, 2) x (0, 2, 2, 12)12 : AIC Calculated =-153.8119947116966
# (1, 0, 0, 12)
# SARIMAX (1, 2, 2) x (1, 0, 0, 12)12 : AIC Calculated =-185.49084451620647
# (1, 0, 1, 12)
# SARIMAX (1, 2, 2) x (1, 0, 1, 12)12 : AIC Calculated =-196.81753478102019
# (1, 0, 2, 12)
# SARIMAX (1, 2, 2) x (1, 0, 2, 12)12 : AIC Calculated =-195.28967065249418
# (1, 1, 0, 12)
# SARIMAX (1, 2, 2) x (1, 1, 0, 12)12 : AIC Calculated =-349.6009399780953
# (1, 1, 1, 12)
# SARIMAX (1, 2, 2) x (1, 1, 1, 12)12 : AIC Calculated =-346.62512237576175
# (1, 1, 2, 12)
# SARIMAX (1, 2, 2) x (1, 1, 2, 12)12 : AIC Calculated =-340.3702308819713
# (1, 2, 0, 12)
# SARIMAX (1, 2, 2) x (1, 2, 0, 12)12 : AIC Calculated =-199.00528547499593
# (1, 2, 1, 12)
# SARIMAX (1, 2, 2) x (1, 2, 1, 12)12 : AIC Calculated =-208.41202076529993
# (1, 2, 2, 12)
# SARIMAX (1, 2, 2) x (1, 2, 2, 12)12 : AIC Calculated =-189.30155941656238
# (2, 0, 0, 12)
# SARIMAX (1, 2, 2) x (2, 0, 0, 12)12 : AIC Calculated =-183.79883721029003
# (2, 0, 1, 12)
# SARIMAX (1, 2, 2) x (2, 0, 1, 12)12 : AIC Calculated =-254.35742370333503
# (2, 0, 2, 12)
# SARIMAX (1, 2, 2) x (2, 0, 2, 12)12 : AIC Calculated =-189.56696212992216
# (2, 1, 0, 12)
# SARIMAX (1, 2, 2) x (2, 1, 0, 12)12 : AIC Calculated =-348.6642839320547
# (2, 1, 1, 12)
# SARIMAX (1, 2, 2) x (2, 1, 1, 12)12 : AIC Calculated =-352.1322729214362
# (2, 1, 2, 12)
# SARIMAX (1, 2, 2) x (2, 1, 2, 12)12 : AIC Calculated =-337.96240797372224
# (2, 2, 0, 12)
# SARIMAX (1, 2, 2) x (2, 2, 0, 12)12 : AIC Calculated =-205.41254503459442
# (2, 2, 1, 12)
# SARIMAX (1, 2, 2) x (2, 2, 1, 12)12 : AIC Calculated =-204.1659383775531
# (2, 2, 2, 12)
# SARIMAX (1, 2, 2) x (2, 2, 2, 12)12 : AIC Calculated =-200.03638550915272
# (0, 0, 0, 12)
# SARIMAX (2, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =-376.7624864716473
# (0, 0, 1, 12)
# SARIMAX (2, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =-401.9039623271554
# (0, 0, 2, 12)
# SARIMAX (2, 0, 0) x (0, 0, 2, 12)12 : AIC Calculated =-416.85424414020133
# (0, 1, 0, 12)
# SARIMAX (2, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =-435.2110750269999
# (0, 1, 1, 12)
# SARIMAX (2, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =-457.894518232903
# (0, 1, 2, 12)
# SARIMAX (2, 0, 0) x (0, 1, 2, 12)12 : AIC Calculated =-465.6154189903642
# (0, 2, 0, 12)
# SARIMAX (2, 0, 0) x (0, 2, 0, 12)12 : AIC Calculated =-274.55166116414057
# (0, 2, 1, 12)
# SARIMAX (2, 0, 0) x (0, 2, 1, 12)12 : AIC Calculated =-272.55167437910166
# (0, 2, 2, 12)
# SARIMAX (2, 0, 0) x (0, 2, 2, 12)12 : AIC Calculated =-270.5516738091802
# (1, 0, 0, 12)
# SARIMAX (2, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =-419.17714890153553
# (1, 0, 1, 12)
# SARIMAX (2, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =-149.0832889860934
# (1, 0, 2, 12)
# SARIMAX (2, 0, 0) x (1, 0, 2, 12)12 : AIC Calculated =-419.3593740012817
# (1, 1, 0, 12)
# SARIMAX (2, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =-456.55181028529125
# (1, 1, 1, 12)
# SARIMAX (2, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =-465.2766251655048
# (1, 1, 2, 12)
# SARIMAX (2, 0, 0) x (1, 1, 2, 12)12 : AIC Calculated =-462.5479301921331
# (1, 2, 0, 12)
# SARIMAX (2, 0, 0) x (1, 2, 0, 12)12 : AIC Calculated =-324.69460265465466
# (1, 2, 1, 12)
# SARIMAX (2, 0, 0) x (1, 2, 1, 12)12 : AIC Calculated =-324.97186346120617
# (1, 2, 2, 12)
# SARIMAX (2, 0, 0) x (1, 2, 2, 12)12 : AIC Calculated =-335.06567858829607
# (2, 0, 0, 12)
# SARIMAX (2, 0, 0) x (2, 0, 0, 12)12 : AIC Calculated =-387.2690089287952
# (2, 0, 1, 12)
# SARIMAX (2, 0, 0) x (2, 0, 1, 12)12 : AIC Calculated =-309.2126159735768
# (2, 0, 2, 12)
# SARIMAX (2, 0, 0) x (2, 0, 2, 12)12 : AIC Calculated =-323.66113480900384
# (2, 1, 0, 12)
# SARIMAX (2, 0, 0) x (2, 1, 0, 12)12 : AIC Calculated =-469.62494398329017
# (2, 1, 1, 12)
# SARIMAX (2, 0, 0) x (2, 1, 1, 12)12 : AIC Calculated =-466.3873718190782
# (2, 1, 2, 12)
# SARIMAX (2, 0, 0) x (2, 1, 2, 12)12 : AIC Calculated =-459.9646150153872
# (2, 2, 0, 12)
# SARIMAX (2, 0, 0) x (2, 2, 0, 12)12 : AIC Calculated =-367.00452934540317
# (2, 2, 1, 12)
# SARIMAX (2, 0, 0) x (2, 2, 1, 12)12 : AIC Calculated =-366.28546747166456
# (2, 2, 2, 12)
# SARIMAX (2, 0, 0) x (2, 2, 2, 12)12 : AIC Calculated =-315.4282531019413
# (0, 0, 0, 12)
# SARIMAX (2, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =-327.36303295419617
# (0, 0, 1, 12)
# SARIMAX (2, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =-344.5687616165869
# (0, 0, 2, 12)
# SARIMAX (2, 0, 1) x (0, 0, 2, 12)12 : AIC Calculated =-427.7339567175012
# (0, 1, 0, 12)
# SARIMAX (2, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =-431.3735514864541
# (0, 1, 1, 12)
# SARIMAX (2, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =-453.36068683522444
# (0, 1, 2, 12)
# SARIMAX (2, 0, 1) x (0, 1, 2, 12)12 : AIC Calculated =-460.42146803101605
# (0, 2, 0, 12)
# SARIMAX (2, 0, 1) x (0, 2, 0, 12)12 : AIC Calculated =-275.3363528437207
# (0, 2, 1, 12)
# SARIMAX (2, 0, 1) x (0, 2, 1, 12)12 : AIC Calculated =-273.3363550184273
# (0, 2, 2, 12)
# SARIMAX (2, 0, 1) x (0, 2, 2, 12)12 : AIC Calculated =-271.33635502835955
# (1, 0, 0, 12)
# SARIMAX (2, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =-293.72515738242527
# (1, 0, 1, 12)
# SARIMAX (2, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =-152.42374668766985
# (1, 0, 2, 12)
# SARIMAX (2, 0, 1) x (1, 0, 2, 12)12 : AIC Calculated =-274.9300679380715
# (1, 1, 0, 12)
# SARIMAX (2, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =-458.37591777541496
# (1, 1, 1, 12)
# SARIMAX (2, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =-462.6063604128062
# (1, 1, 2, 12)
# SARIMAX (2, 0, 1) x (1, 1, 2, 12)12 : AIC Calculated =-457.08116962962976
# (1, 2, 0, 12)
# SARIMAX (2, 0, 1) x (1, 2, 0, 12)12 : AIC Calculated =-308.1198139624862
# (1, 2, 1, 12)
# SARIMAX (2, 0, 1) x (1, 2, 1, 12)12 : AIC Calculated =-321.22107826708805
# (1, 2, 2, 12)
# SARIMAX (2, 0, 1) x (1, 2, 2, 12)12 : AIC Calculated =-304.79267446919937
# (2, 0, 0, 12)
# SARIMAX (2, 0, 1) x (2, 0, 0, 12)12 : AIC Calculated =-365.1904123203065
# (2, 0, 1, 12)
# SARIMAX (2, 0, 1) x (2, 0, 1, 12)12 : AIC Calculated =-256.78764905221374
# (2, 0, 2, 12)
# SARIMAX (2, 0, 1) x (2, 0, 2, 12)12 : AIC Calculated =-222.67322638289266
# (2, 1, 0, 12)
# SARIMAX (2, 0, 1) x (2, 1, 0, 12)12 : AIC Calculated =-466.6735206333942
# (2, 1, 1, 12)
# SARIMAX (2, 0, 1) x (2, 1, 1, 12)12 : AIC Calculated =-460.40862399749096
# (2, 1, 2, 12)
# SARIMAX (2, 0, 1) x (2, 1, 2, 12)12 : AIC Calculated =-457.8459703643174
# (2, 2, 0, 12)
# SARIMAX (2, 0, 1) x (2, 2, 0, 12)12 : AIC Calculated =-358.6629935810403
# (2, 2, 1, 12)
# SARIMAX (2, 0, 1) x (2, 2, 1, 12)12 : AIC Calculated =-318.1890526410604
# (2, 2, 2, 12)
# SARIMAX (2, 0, 1) x (2, 2, 2, 12)12 : AIC Calculated =-310.7240787905008
# (0, 0, 0, 12)
# SARIMAX (2, 0, 2) x (0, 0, 0, 12)12 : AIC Calculated =-263.28668134491113
# (0, 0, 1, 12)
# SARIMAX (2, 0, 2) x (0, 0, 1, 12)12 : AIC Calculated =-326.498150431486
# (0, 0, 2, 12)
# SARIMAX (2, 0, 2) x (0, 0, 2, 12)12 : AIC Calculated =-348.2265563342852
# (0, 1, 0, 12)
# SARIMAX (2, 0, 2) x (0, 1, 0, 12)12 : AIC Calculated =-431.39243745446345
# (0, 1, 1, 12)
# SARIMAX (2, 0, 2) x (0, 1, 1, 12)12 : AIC Calculated =-455.0539920397905
# (0, 1, 2, 12)
# SARIMAX (2, 0, 2) x (0, 1, 2, 12)12 : AIC Calculated =-449.86470231670796
# (0, 2, 0, 12)
# SARIMAX (2, 0, 2) x (0, 2, 0, 12)12 : AIC Calculated =-270.2188387408157
# (0, 2, 1, 12)
# SARIMAX (2, 0, 2) x (0, 2, 1, 12)12 : AIC Calculated =-268.3929406062354
# (0, 2, 2, 12)
# ...
# (1, 1, 0, 12)
# SARIMAX (2, 0, 2) x (1, 1, 0, 12)12 : AIC Calculated =-458.15201127545225
# (1, 1, 1, 12)
# SARIMAX (2, 0, 2) x (1, 1, 1, 12)12 : AIC Calculated =-458.4163088764096
# (1, 1, 2, 12)
# SARIMAX (2, 0, 2) x (1, 1, 2, 12)12 : AIC Calculated =-454.4045728018375
# (1, 2, 0, 12)
# SARIMAX (2, 0, 2) x (1, 2, 0, 12)12 : AIC Calculated =-318.33039036591356
# (1, 2, 1, 12)
# SARIMAX (2, 0, 2) x (1, 2, 1, 12)12 : AIC Calculated =-327.0849447893792
# (1, 2, 2, 12)
# SARIMAX (2, 0, 2) x (1, 2, 2, 12)12 : AIC Calculated =-315.35277588699785
# (2, 0, 0, 12)
# SARIMAX (2, 0, 2) x (2, 0, 0, 12)12 : AIC Calculated =-414.73154056949534
# (2, 0, 1, 12)
# SARIMAX (2, 0, 2) x (2, 0, 1, 12)12 : AIC Calculated =-417.50237310564626
# (2, 0, 2, 12)
# SARIMAX (2, 0, 2) x (2, 0, 2, 12)12 : AIC Calculated =-381.8549196472445
# (2, 1, 0, 12)
# SARIMAX (2, 0, 2) x (2, 1, 0, 12)12 : AIC Calculated =-461.75038778385476
# (2, 1, 1, 12)
# SARIMAX (2, 0, 2) x (2, 1, 1, 12)12 : AIC Calculated =-456.7167385301077
# (2, 1, 2, 12)
# SARIMAX (2, 0, 2) x (2, 1, 2, 12)12 : AIC Calculated =-455.84546565844437
# (2, 2, 0, 12)
# SARIMAX (2, 0, 2) x (2, 2, 0, 12)12 : AIC Calculated =-367.2365799602069
# (2, 2, 1, 12)
# SARIMAX (2, 0, 2) x (2, 2, 1, 12)12 : AIC Calculated =-370.93959722216266
# (2, 2, 2, 12)
# SARIMAX (2, 0, 2) x (2, 2, 2, 12)12 : AIC Calculated =-318.83743130976836
# (0, 0, 0, 12)
# SARIMAX (2, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =-285.3293435376553
# (0, 0, 1, 12)
# SARIMAX (2, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =-401.99741625042907
# (0, 0, 2, 12)
# SARIMAX (2, 1, 0) x (0, 0, 2, 12)12 : AIC Calculated =-422.65733849221124
# (0, 1, 0, 12)
# SARIMAX (2, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =-390.76131449011143
# (0, 1, 1, 12)
# SARIMAX (2, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =-425.8428004904904
# (0, 1, 2, 12)
# SARIMAX (2, 1, 0) x (0, 1, 2, 12)12 : AIC Calculated =-424.66467529501017
# (0, 2, 0, 12)
# SARIMAX (2, 1, 0) x (0, 2, 0, 12)12 : AIC Calculated =-223.74730381571342
# (0, 2, 1, 12)
# SARIMAX (2, 1, 0) x (0, 2, 1, 12)12 : AIC Calculated =-309.1051787401161
# (0, 2, 2, 12)
# SARIMAX (2, 1, 0) x (0, 2, 2, 12)12 : AIC Calculated =-219.7451591285258
# (1, 0, 0, 12)
# SARIMAX (2, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =-404.57078848875074
# (1, 0, 1, 12)
# SARIMAX (2, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =-352.44829982352604
# (1, 0, 2, 12)
# SARIMAX (2, 1, 0) x (1, 0, 2, 12)12 : AIC Calculated =-417.86715668673617
# (1, 1, 0, 12)
# SARIMAX (2, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =-415.3327575804441
# (1, 1, 1, 12)
# SARIMAX (2, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =-422.98806472995705
# (1, 1, 2, 12)
# SARIMAX (2, 1, 0) x (1, 1, 2, 12)12 : AIC Calculated =-426.45209809439467
# (1, 2, 0, 12)
# SARIMAX (2, 1, 0) x (1, 2, 0, 12)12 : AIC Calculated =-279.03291037761187
# (1, 2, 1, 12)
# SARIMAX (2, 1, 0) x (1, 2, 1, 12)12 : AIC Calculated =-332.8108418165079
# (1, 2, 2, 12)
# SARIMAX (2, 1, 0) x (1, 2, 2, 12)12 : AIC Calculated =-315.01849881456894
# (2, 0, 0, 12)
# SARIMAX (2, 1, 0) x (2, 0, 0, 12)12 : AIC Calculated =-420.4281544837154
# (2, 0, 1, 12)
# SARIMAX (2, 1, 0) x (2, 0, 1, 12)12 : AIC Calculated =-214.648933220235
# (2, 0, 2, 12)
# SARIMAX (2, 1, 0) x (2, 0, 2, 12)12 : AIC Calculated =-384.76202089977164
# (2, 1, 0, 12)
# SARIMAX (2, 1, 0) x (2, 1, 0, 12)12 : AIC Calculated =-417.59252637475925
# (2, 1, 1, 12)
# SARIMAX (2, 1, 0) x (2, 1, 1, 12)12 : AIC Calculated =-428.4339039521856
# (2, 1, 2, 12)
# SARIMAX (2, 1, 0) x (2, 1, 2, 12)12 : AIC Calculated =-432.33682764148705
# (2, 2, 0, 12)
# SARIMAX (2, 1, 0) x (2, 2, 0, 12)12 : AIC Calculated =-333.9630800937534
# (2, 2, 1, 12)
# SARIMAX (2, 1, 0) x (2, 2, 1, 12)12 : AIC Calculated =-335.8333943324488
# (2, 2, 2, 12)
# SARIMAX (2, 1, 0) x (2, 2, 2, 12)12 : AIC Calculated =-345.0846781209013
# (0, 0, 0, 12)
# SARIMAX (2, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =-380.3711465304206
# (0, 0, 1, 12)
# SARIMAX (2, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =-390.8996023878423
# (0, 0, 2, 12)
# SARIMAX (2, 1, 1) x (0, 0, 2, 12)12 : AIC Calculated =-406.6517036793234
# (0, 1, 0, 12)
# SARIMAX (2, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =-390.1645491410857
# (0, 1, 1, 12)
# SARIMAX (2, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =-417.60001463114196
# (0, 1, 2, 12)
# SARIMAX (2, 1, 1) x (0, 1, 2, 12)12 : AIC Calculated =-416.6221814109292
# (0, 2, 0, 12)
# SARIMAX (2, 1, 1) x (0, 2, 0, 12)12 : AIC Calculated =-228.05547675022086
# (0, 2, 1, 12)
# SARIMAX (2, 1, 1) x (0, 2, 1, 12)12 : AIC Calculated =-227.39050205383563
# (0, 2, 2, 12)
# SARIMAX (2, 1, 1) x (0, 2, 2, 12)12 : AIC Calculated =-225.41296218060268
# (1, 0, 0, 12)
# SARIMAX (2, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =-396.30571348243575
# (1, 0, 1, 12)
# SARIMAX (2, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =-126.25297328181372
# (1, 0, 2, 12)
# SARIMAX (2, 1, 1) x (1, 0, 2, 12)12 : AIC Calculated =-425.03915405154873
# (1, 1, 0, 12)
# SARIMAX (2, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =-430.91720350615674
# (1, 1, 1, 12)
# SARIMAX (2, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =-432.01883888630834
# (1, 1, 2, 12)
# SARIMAX (2, 1, 1) x (1, 1, 2, 12)12 : AIC Calculated =-407.4628249833929
# (1, 2, 0, 12)
# SARIMAX (2, 1, 1) x (1, 2, 0, 12)12 : AIC Calculated =-281.7164759736348
# (1, 2, 1, 12)
# SARIMAX (2, 1, 1) x (1, 2, 1, 12)12 : AIC Calculated =-330.1247406247828
# (1, 2, 2, 12)
# SARIMAX (2, 1, 1) x (1, 2, 2, 12)12 : AIC Calculated =-274.4287935590541
# (2, 0, 0, 12)
# SARIMAX (2, 1, 1) x (2, 0, 0, 12)12 : AIC Calculated =-387.0467481571237
# (2, 0, 1, 12)
# SARIMAX (2, 1, 1) x (2, 0, 1, 12)12 : AIC Calculated =-422.42211756091933
# (2, 0, 2, 12)
# SARIMAX (2, 1, 1) x (2, 0, 2, 12)12 : AIC Calculated =-390.34267821571524
# (2, 1, 0, 12)
# SARIMAX (2, 1, 1) x (2, 1, 0, 12)12 : AIC Calculated =-415.13464925734615
# (2, 1, 1, 12)
# SARIMAX (2, 1, 1) x (2, 1, 1, 12)12 : AIC Calculated =-413.4356509907051
# (2, 1, 2, 12)
# SARIMAX (2, 1, 1) x (2, 1, 2, 12)12 : AIC Calculated =-408.29501148433087
# (2, 2, 0, 12)
# SARIMAX (2, 1, 1) x (2, 2, 0, 12)12 : AIC Calculated =-318.6120087964353
# (2, 2, 1, 12)
# SARIMAX (2, 1, 1) x (2, 2, 1, 12)12 : AIC Calculated =-339.4119327838318
# (2, 2, 2, 12)
# SARIMAX (2, 1, 1) x (2, 2, 2, 12)12 : AIC Calculated =-342.3765752915754
# (0, 0, 0, 12)
# SARIMAX (2, 1, 2) x (0, 0, 0, 12)12 : AIC Calculated =-401.77858120062956
# (0, 0, 1, 12)
# SARIMAX (2, 1, 2) x (0, 0, 1, 12)12 : AIC Calculated =-424.49940530903064
# (0, 0, 2, 12)
# SARIMAX (2, 1, 2) x (0, 0, 2, 12)12 : AIC Calculated =-432.4984656413186
# (0, 1, 0, 12)
# SARIMAX (2, 1, 2) x (0, 1, 0, 12)12 : AIC Calculated =-387.5158026466711
# (0, 1, 1, 12)
# SARIMAX (2, 1, 2) x (0, 1, 1, 12)12 : AIC Calculated =-391.5508878626295
# (0, 1, 2, 12)
# SARIMAX (2, 1, 2) x (0, 1, 2, 12)12 : AIC Calculated =-396.5575079501302
# (0, 2, 0, 12)
# SARIMAX (2, 1, 2) x (0, 2, 0, 12)12 : AIC Calculated =-220.32810061493169
# (0, 2, 1, 12)
# SARIMAX (2, 1, 2) x (0, 2, 1, 12)12 : AIC Calculated =-274.83723313931995
# (0, 2, 2, 12)
# SARIMAX (2, 1, 2) x (0, 2, 2, 12)12 : AIC Calculated =-279.2830685552738
# (1, 0, 0, 12)
# SARIMAX (2, 1, 2) x (1, 0, 0, 12)12 : AIC Calculated =-391.55217634257986
# (1, 0, 1, 12)
# SARIMAX (2, 1, 2) x (1, 0, 1, 12)12 : AIC Calculated =-337.5919576365472
# (1, 0, 2, 12)
# SARIMAX (2, 1, 2) x (1, 0, 2, 12)12 : AIC Calculated =-424.01653534326647
# (1, 1, 0, 12)
# SARIMAX (2, 1, 2) x (1, 1, 0, 12)12 : AIC Calculated =-394.85438517749634
# (1, 1, 1, 12)
# SARIMAX (2, 1, 2) x (1, 1, 1, 12)12 : AIC Calculated =-393.4783698978779
# (1, 1, 2, 12)
# SARIMAX (2, 1, 2) x (1, 1, 2, 12)12 : AIC Calculated =-389.19947225050714
# (1, 2, 0, 12)
# SARIMAX (2, 1, 2) x (1, 2, 0, 12)12 : AIC Calculated =-264.74088855500383
# (1, 2, 1, 12)
# SARIMAX (2, 1, 2) x (1, 2, 1, 12)12 : AIC Calculated =-322.4626038182692
# (1, 2, 2, 12)
# SARIMAX (2, 1, 2) x (1, 2, 2, 12)12 : AIC Calculated =-288.50504986229663
# (2, 0, 0, 12)
# SARIMAX (2, 1, 2) x (2, 0, 0, 12)12 : AIC Calculated =-401.03361166793184
# (2, 0, 1, 12)
# SARIMAX (2, 1, 2) x (2, 0, 1, 12)12 : AIC Calculated =-393.15070903554505
# (2, 0, 2, 12)
# SARIMAX (2, 1, 2) x (2, 0, 2, 12)12 : AIC Calculated =-409.31665683072197
# (2, 1, 0, 12)
# SARIMAX (2, 1, 2) x (2, 1, 0, 12)12 : AIC Calculated =-424.42563104895373
# (2, 1, 1, 12)
# SARIMAX (2, 1, 2) x (2, 1, 1, 12)12 : AIC Calculated =-394.63019065234664
# (2, 1, 2, 12)
# SARIMAX (2, 1, 2) x (2, 1, 2, 12)12 : AIC Calculated =-428.92769865092396
# (2, 2, 0, 12)
# SARIMAX (2, 1, 2) x (2, 2, 0, 12)12 : AIC Calculated =-327.695858356469
# (2, 2, 1, 12)
# SARIMAX (2, 1, 2) x (2, 2, 1, 12)12 : AIC Calculated =-336.75888884131956
# (2, 2, 2, 12)
# SARIMAX (2, 1, 2) x (2, 2, 2, 12)12 : AIC Calculated =-347.6061118034618
# (0, 0, 0, 12)
# SARIMAX (2, 2, 0) x (0, 0, 0, 12)12 : AIC Calculated =-266.1842192078061
# (0, 0, 1, 12)
# SARIMAX (2, 2, 0) x (0, 0, 1, 12)12 : AIC Calculated =-270.16017252922904
# (0, 0, 2, 12)
# SARIMAX (2, 2, 0) x (0, 0, 2, 12)12 : AIC Calculated =-299.1664016034998
# (0, 1, 0, 12)
# SARIMAX (2, 2, 0) x (0, 1, 0, 12)12 : AIC Calculated =-317.4564033780212
# (0, 1, 1, 12)
# SARIMAX (2, 2, 0) x (0, 1, 1, 12)12 : AIC Calculated =-347.38485942230557
# (0, 1, 2, 12)
# SARIMAX (2, 2, 0) x (0, 1, 2, 12)12 : AIC Calculated =-354.254827165327
# (0, 2, 0, 12)
# SARIMAX (2, 2, 0) x (0, 2, 0, 12)12 : AIC Calculated =-150.4370214097978
# (0, 2, 1, 12)
# SARIMAX (2, 2, 0) x (0, 2, 1, 12)12 : AIC Calculated =-148.43739139189455
# (0, 2, 2, 12)
# SARIMAX (2, 2, 0) x (0, 2, 2, 12)12 : AIC Calculated =-146.43735279681596
# (1, 0, 0, 12)
# SARIMAX (2, 2, 0) x (1, 0, 0, 12)12 : AIC Calculated =-290.9451820433489
# (1, 0, 1, 12)
# SARIMAX (2, 2, 0) x (1, 0, 1, 12)12 : AIC Calculated =-246.88798113866244
# (1, 0, 2, 12)
# SARIMAX (2, 2, 0) x (1, 0, 2, 12)12 : AIC Calculated =-319.7130650404223
# (1, 1, 0, 12)
# SARIMAX (2, 2, 0) x (1, 1, 0, 12)12 : AIC Calculated =-344.49609389001967
# (1, 1, 1, 12)
# SARIMAX (2, 2, 0) x (1, 1, 1, 12)12 : AIC Calculated =-360.75481412375296
# (1, 1, 2, 12)
# SARIMAX (2, 2, 0) x (1, 1, 2, 12)12 : AIC Calculated =-334.4274699435929
# (1, 2, 0, 12)
# SARIMAX (2, 2, 0) x (1, 2, 0, 12)12 : AIC Calculated =-220.71988011096775
# (1, 2, 1, 12)
# SARIMAX (2, 2, 0) x (1, 2, 1, 12)12 : AIC Calculated =-205.67215382975792
# (1, 2, 2, 12)
# SARIMAX (2, 2, 0) x (1, 2, 2, 12)12 : AIC Calculated =-250.7896011317281
# (2, 0, 0, 12)
# SARIMAX (2, 2, 0) x (2, 0, 0, 12)12 : AIC Calculated =-266.4081638640023
# (2, 0, 1, 12)
# SARIMAX (2, 2, 0) x (2, 0, 1, 12)12 : AIC Calculated =-251.72951732165427
# (2, 0, 2, 12)
# SARIMAX (2, 2, 0) x (2, 0, 2, 12)12 : AIC Calculated =-257.24822792920367
# (2, 1, 0, 12)
# SARIMAX (2, 2, 0) x (2, 1, 0, 12)12 : AIC Calculated =-357.2630160022942
# (2, 1, 1, 12)
# SARIMAX (2, 2, 0) x (2, 1, 1, 12)12 : AIC Calculated =-362.8360682103538
# (2, 1, 2, 12)
# SARIMAX (2, 2, 0) x (2, 1, 2, 12)12 : AIC Calculated =-360.0724712000166
# (2, 2, 0, 12)
# SARIMAX (2, 2, 0) x (2, 2, 0, 12)12 : AIC Calculated =-271.60484081687645
# (2, 2, 1, 12)
# SARIMAX (2, 2, 0) x (2, 2, 1, 12)12 : AIC Calculated =-275.23253503276163
# (2, 2, 2, 12)
# SARIMAX (2, 2, 0) x (2, 2, 2, 12)12 : AIC Calculated =-275.19220149341135
# (0, 0, 0, 12)
# SARIMAX (2, 2, 1) x (0, 0, 0, 12)12 : AIC Calculated =-267.87700102291626
# (0, 0, 1, 12)
# SARIMAX (2, 2, 1) x (0, 0, 1, 12)12 : AIC Calculated =-294.49939613103993
# (0, 0, 2, 12)
# SARIMAX (2, 2, 1) x (0, 0, 2, 12)12 : AIC Calculated =-299.30211484906704
# (0, 1, 0, 12)
# SARIMAX (2, 2, 1) x (0, 1, 0, 12)12 : AIC Calculated =-325.6076864290979
# (0, 1, 1, 12)
# SARIMAX (2, 2, 1) x (0, 1, 1, 12)12 : AIC Calculated =-347.8198827609308
# (0, 1, 2, 12)
# SARIMAX (2, 2, 1) x (0, 1, 2, 12)12 : AIC Calculated =-347.22282631683345
# (0, 2, 0, 12)
# SARIMAX (2, 2, 1) x (0, 2, 0, 12)12 : AIC Calculated =-158.72891728065912
# (0, 2, 1, 12)
# SARIMAX (2, 2, 1) x (0, 2, 1, 12)12 : AIC Calculated =-156.72946076148943
# (0, 2, 2, 12)
# SARIMAX (2, 2, 1) x (0, 2, 2, 12)12 : AIC Calculated =-154.72933986001672
# (1, 0, 0, 12)
# SARIMAX (2, 2, 1) x (1, 0, 0, 12)12 : AIC Calculated =-266.4951746459344
# (1, 0, 1, 12)
# SARIMAX (2, 2, 1) x (1, 0, 1, 12)12 : AIC Calculated =-297.02708119587163
# (1, 0, 2, 12)
# SARIMAX (2, 2, 1) x (1, 0, 2, 12)12 : AIC Calculated =-316.8849225804439
# (1, 1, 0, 12)
# SARIMAX (2, 2, 1) x (1, 1, 0, 12)12 : AIC Calculated =-350.0527539440887
# (1, 1, 1, 12)
# SARIMAX (2, 2, 1) x (1, 1, 1, 12)12 : AIC Calculated =-346.89064953244304
# (1, 1, 2, 12)
# SARIMAX (2, 2, 1) x (1, 1, 2, 12)12 : AIC Calculated =-344.30063887956044
# (1, 2, 0, 12)
# SARIMAX (2, 2, 1) x (1, 2, 0, 12)12 : AIC Calculated =-200.66208711759433
# (1, 2, 1, 12)
# SARIMAX (2, 2, 1) x (1, 2, 1, 12)12 : AIC Calculated =-210.0005697966113
# (1, 2, 2, 12)
# SARIMAX (2, 2, 1) x (1, 2, 2, 12)12 : AIC Calculated =-191.03209954894209
# (2, 0, 0, 12)
# SARIMAX (2, 2, 1) x (2, 0, 0, 12)12 : AIC Calculated =-284.2036376803478
# (2, 0, 1, 12)
# SARIMAX (2, 2, 1) x (2, 0, 1, 12)12 : AIC Calculated =-299.1760460231071
# (2, 0, 2, 12)
# SARIMAX (2, 2, 1) x (2, 0, 2, 12)12 : AIC Calculated =-253.83743687542682
# (2, 1, 0, 12)
# SARIMAX (2, 2, 1) x (2, 1, 0, 12)12 : AIC Calculated =-349.2509625853103
# (2, 1, 1, 12)
# SARIMAX (2, 2, 1) x (2, 1, 1, 12)12 : AIC Calculated =-345.59895509867715
# (2, 1, 2, 12)
# SARIMAX (2, 2, 1) x (2, 1, 2, 12)12 : AIC Calculated =-337.87233279542943
# (2, 2, 0, 12)
# SARIMAX (2, 2, 1) x (2, 2, 0, 12)12 : AIC Calculated =-207.25888738151664
# (2, 2, 1, 12)
# SARIMAX (2, 2, 1) x (2, 2, 1, 12)12 : AIC Calculated =-205.98924895582115
# (2, 2, 2, 12)
# SARIMAX (2, 2, 1) x (2, 2, 2, 12)12 : AIC Calculated =-201.80525364099896
# (0, 0, 0, 12)
# SARIMAX (2, 2, 2) x (0, 0, 0, 12)12 : AIC Calculated =-276.26755718582393
# (0, 0, 1, 12)
# SARIMAX (2, 2, 2) x (0, 0, 1, 12)12 : AIC Calculated =-280.9007217995133
# (0, 0, 2, 12)
# SARIMAX (2, 2, 2) x (0, 0, 2, 12)12 : AIC Calculated =-299.2678336338935
# (0, 1, 0, 12)
# SARIMAX (2, 2, 2) x (0, 1, 0, 12)12 : AIC Calculated =-323.62077340699693
# (0, 1, 1, 12)
# SARIMAX (2, 2, 2) x (0, 1, 1, 12)12 : AIC Calculated =-361.12869883031715
# (0, 1, 2, 12)
# SARIMAX (2, 2, 2) x (0, 1, 2, 12)12 : AIC Calculated =-345.3443144537989
# (0, 2, 0, 12)
# SARIMAX (2, 2, 2) x (0, 2, 0, 12)12 : AIC Calculated =-158.02683207229316
# (0, 2, 1, 12)
# SARIMAX (2, 2, 2) x (0, 2, 1, 12)12 : AIC Calculated =-204.89669053392112
# (0, 2, 2, 12)
# SARIMAX (2, 2, 2) x (0, 2, 2, 12)12 : AIC Calculated =-218.9710236250715
# (1, 0, 0, 12)
# SARIMAX (2, 2, 2) x (1, 0, 0, 12)12 : AIC Calculated =-269.0154978933633
# (1, 0, 1, 12)
# SARIMAX (2, 2, 2) x (1, 0, 1, 12)12 : AIC Calculated =-304.58171464763853
# (1, 0, 2, 12)
# SARIMAX (2, 2, 2) x (1, 0, 2, 12)12 : AIC Calculated =-301.16390304364825
# (1, 1, 0, 12)
# SARIMAX (2, 2, 2) x (1, 1, 0, 12)12 : AIC Calculated =-354.88246556131094
# (1, 1, 1, 12)
# SARIMAX (2, 2, 2) x (1, 1, 1, 12)12 : AIC Calculated =-351.1042104639836
# (1, 1, 2, 12)
# SARIMAX (2, 2, 2) x (1, 1, 2, 12)12 : AIC Calculated =-338.4995230156427
# (1, 2, 0, 12)
# SARIMAX (2, 2, 2) x (1, 2, 0, 12)12 : AIC Calculated =-221.3270345811767
# (1, 2, 1, 12)
# SARIMAX (2, 2, 2) x (1, 2, 1, 12)12 : AIC Calculated =-184.16636906230346
# (1, 2, 2, 12)
# SARIMAX (2, 2, 2) x (1, 2, 2, 12)12 : AIC Calculated =-208.67635157103493
# (2, 0, 0, 12)
# SARIMAX (2, 2, 2) x (2, 0, 0, 12)12 : AIC Calculated =-295.5142726083043
# (2, 0, 1, 12)
# SARIMAX (2, 2, 2) x (2, 0, 1, 12)12 : AIC Calculated =-305.95452971553743
# (2, 0, 2, 12)
# SARIMAX (2, 2, 2) x (2, 0, 2, 12)12 : AIC Calculated =-269.2394799514273
# (2, 1, 0, 12)
# SARIMAX (2, 2, 2) x (2, 1, 0, 12)12 : AIC Calculated =-354.67740076208713
# (2, 1, 1, 12)
# SARIMAX (2, 2, 2) x (2, 1, 1, 12)12 : AIC Calculated =-343.75908103690784
# (2, 1, 2, 12)
# SARIMAX (2, 2, 2) x (2, 1, 2, 12)12 : AIC Calculated =-340.15604577136673
# (2, 2, 0, 12)
# SARIMAX (2, 2, 2) x (2, 2, 0, 12)12 : AIC Calculated =-270.22327337594675
# (2, 2, 1, 12)
# SARIMAX (2, 2, 2) x (2, 2, 1, 12)12 : AIC Calculated =-281.01081811044963
# (2, 2, 2, 12)
# SARIMAX (2, 2, 2) x (2, 2, 2, 12)12 : AIC Calculated =-271.70995034746534
#            pdq           pdqs         aic
# 11   (0, 0, 0)  (1, 0, 2, 12) -438.004881
# 21   (0, 0, 0)  (2, 1, 0, 12) -432.735197
# 9    (0, 0, 0)  (1, 0, 0, 12) -431.877853
# 264  (1, 0, 0)  (2, 1, 0, 12) -431.197978
# 48   (0, 0, 1)  (2, 1, 0, 12) -429.941532
# 12   (0, 0, 0)  (1, 1, 0, 12) -429.258915
# 248  (1, 0, 0)  (0, 1, 2, 12) -428.826794
# 32   (0, 0, 1)  (0, 1, 2, 12) -428.696081
# 13   (0, 0, 0)  (1, 1, 1, 12) -428.307717
# 5    (0, 0, 0)  (0, 1, 2, 12) -428.264130

# %%
model= SARIMAX(train, 
 exog=train_exog,
 order=(1,0,0),
 seasonal_order=(2,1,0,12),              
 enforce_invertibility=True, enforce_stationarity=True,
              trend = 't')

results = model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  144
# Model:             SARIMAX(1, 0, 0)x(2, 1, 0, 12)   Log Likelihood                 249.779
# Date:                            Fri, 09 Jul 2021   AIC                           -471.557
# Time:                                    15:45:47   BIC                           -431.198
# Sample:                                01-01-2004   HQIC                          -455.157
#                                      - 12-01-2015
# Covariance Type:                              opg
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# drift        -4.021e-05      0.000     -0.082      0.934      -0.001       0.001
# indice_pimpf     0.0511      0.033      1.560      0.119      -0.013       0.115
# ipca            -0.0013      0.031     -0.042      0.967      -0.063       0.060
# taxa_selic       0.0962      0.044      2.202      0.028       0.011       0.182
# taxa_cambio      0.0451      0.040      1.131      0.258      -0.033       0.123
# ibcbr            0.0953      0.122      0.781      0.435      -0.144       0.334
# tjlp            -0.0773      0.043     -1.802      0.071      -0.161       0.007
# pib_mensal       0.4185      0.483      0.867      0.386      -0.528       1.365
# preco_brent      0.0732      0.029      2.538      0.011       0.017       0.130
# desembolso      -0.0102      0.039     -0.264      0.792      -0.086       0.066
# ar.L1            0.1198      0.113      1.062      0.288      -0.101       0.341
# ar.S.L12        -0.5726      0.108     -5.304      0.000      -0.784      -0.361
# ar.S.L24        -0.2662      0.109     -2.435      0.015      -0.480      -0.052
# sigma2           0.0013      0.000      7.790      0.000       0.001       0.002
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.46   Jarque-Bera (JB):               105.44
# Prob(Q):                              0.50   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.86   Skew:                             1.29
# Prob(H) (two-sided):                  0.04   Kurtosis:                         6.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#Faz a previsão no mesmo tamanho que a base de teste
yhat = results.predict(start = 0, end= len(test), exog=test_exog)
yhat = np.array(yhat[1:])
yhat = pd.Series(yhat, index = test_exog.index)
#Obtém o intervalo de confiança 
conf_int = results.predict(start = 0, end= len(test), return_conf_int=True, alpha = 0.05, exog=test_exog)
# conf_int = np.array(conf_int[1:])

# %%
test_inv = scaler_in.inverse_transform(pd.DataFrame(test))
yhat_inv = scaler_in.inverse_transform(pd.DataFrame(yhat))

#Plota o resultado do modelo
plt.plot(test_inv, label='Valor Esperado')
plt.plot(yhat_inv, color='red', label='SARIMAX')
# plt.fill_between(test.index, conf_int[1][:,0], conf_int[1][:,1], color='k', alpha=.08)
plt.title('Teste AUTO-ARIMA - MAPE: %.4f' % mape(yhat_inv,test_inv))
plt.grid(True,axis='y')
plt.legend(loc='upper left')

# %%
#Plotagem dos resíduos e densidade dos resíduos
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,4))
residuals = pd.DataFrame(results.resid)
residuals.plot(ax=ax2, title='Resíduos', label=None)
residuals.plot(ax=ax1,kind='kde', title='Densidade dos resíduos')
plt.xticks(rotation='vertical')
plt.show()

# %%
#Plota o diagnóstico do modelo 
results.plot_diagnostics()
plt.plot()
# Out:
# []

# %% [markdown]
# ## 2.3 Validando a predição

# %%
validacao_cluster2 = pd.Series(validacao_cluster2['arrecadacao'].values, index=validacao_cluster2.index)
validacao_cluster2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\desenvolvimento\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'arrecadacao'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-8d708609e790> in <module>
# ----> 1 validacao_cluster2 = pd.Series(validacao_cluster2['arrecadacao'].values, index=validacao_cluster2.index)
#       2 validacao_cluster2.head()
#
# C:\desenvolvimento\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# C:\desenvolvimento\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# C:\desenvolvimento\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'arrecadacao'

# %%
validacao_cluster2.head()
# Out:
# mes
# 2020-01-01 00:00:00    1.000000
# 2020-02-01 00:00:00    0.425313
# 2020-03-01 00:00:00    0.301380
# 2020-04-01 00:00:00    0.336552
# 2020-05-01 00:00:00    0.034691
# dtype: float64

# %%
#Faz a previsão no mesmo tamanho que a base de teste
yhat = results.predict(start = 0, end= len(validacao_cluster2), exog=validacao_cluster2_exog)
yhat = np.array(yhat[1:])
yhat = pd.Series(yhat, index = validacao_cluster2.index)
#Obtém o intervalo de confiança 
conf_int = results.predict(end=len(validacao_cluster2), return_conf_int=True, alpha = 0.05, exog=validacao_cluster2_exog)

# %%
valid_inv = scaler_valid.inverse_transform(pd.DataFrame(validacao_cluster2))
yhat_inv = scaler_valid.inverse_transform(pd.DataFrame(yhat))

#Plota o resultado do modelo
plt.plot(valid_inv, label='Valor Esperado')
plt.plot(yhat_inv, color='red', label='SARIMAX')
# plt.fill_between(validacao_cluster2.index, conf_int[1][:,0], conf_int[1][:,1], color='k', alpha=.08)
# plt.fill_between(validacao_cluster2.index, conf_int[0], conf_int[1], color='k', alpha=.08)
plt.title('Teste AUTO-ARIMA - MAPE: %.4f' % mape(yhat_inv,valid_inv))
plt.grid(True,axis='y')
plt.legend(loc='upper left')
