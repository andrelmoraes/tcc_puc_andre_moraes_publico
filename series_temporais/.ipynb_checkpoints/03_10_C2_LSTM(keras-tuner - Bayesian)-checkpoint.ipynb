# %% [markdown]
# # Modelo LSTM para predição
#
# ---
#
#
# ___

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import math
import requests
import json
import os
import statsmodels.api as sm
import tensorflow as tf
from pandas import concat

from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore")

from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)

import math

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
import keras_tuner as kt
from tensorflow.keras import initializers
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## 1. Importando os datasets

# %%
dataset_cluster2_series = pd.read_csv("datasets//dataset_cluster2_series.csv", header=0, index_col=0)
dataset_cluster2_validacao = pd.read_csv("datasets//dataset_cluster2_validation.csv", header=0, index_col=0)

dataset_cluster2_series = dataset_cluster2_series.append(dataset_cluster2_validacao)

# %%
dataset_cluster2_series.head()
# Out:
#                      indice_pimpf  ipca  taxa_selic  taxa_cambio   ibcbr  \
# mes
# 2004-01-01 00:00:00         104.0  0.76       16.32       136.19   98.59
# 2004-02-01 00:00:00         103.1  0.61       16.30       139.84   99.45
# 2004-03-01 00:00:00         113.0  0.47       16.19       138.89  111.98
# 2004-04-01 00:00:00         107.8  0.37       15.96       138.85  107.36
# 2004-05-01 00:00:00         108.9  0.51       15.77       148.25  106.03
#
#                       tjlp  pib_mensal  preco_brent  desembolso       debitos  \
# mes
# 2004-01-01 00:00:00  10.00   1735331.5        31.18      1107.0  7.309702e+08
# 2004-02-01 00:00:00  10.00   1746819.2        30.87      2559.0  4.150874e+09
# 2004-03-01 00:00:00  10.00   1765492.2        33.80      4302.0  3.778614e+09
# 2004-04-01 00:00:00   9.75   1781058.0        33.36      5474.0  4.927327e+09
# 2004-05-01 00:00:00   9.75   1800951.1        37.92      5976.0  2.175496e+09
#
#                       arrecadacao
# mes
# 2004-01-01 00:00:00  6.709728e+09
# 2004-02-01 00:00:00  5.844144e+09
# 2004-03-01 00:00:00  5.757594e+09
# 2004-04-01 00:00:00  7.872113e+09
# 2004-05-01 00:00:00  7.156122e+09

# %% [markdown]
# ## 2. Preparando o dataset para a rede neural LSTM

# %%
np.random.seed(10)

# %%
serie_cluster2 = np.array(dataset_cluster2_series)

# %%
print(serie_cluster2)
# Out:
# [[1.04000000e+02 7.60000000e-01 1.63200000e+01 ... 1.10700000e+03
#   7.30970152e+08 6.70972820e+09]
#  [1.03100000e+02 6.10000000e-01 1.63000000e+01 ... 2.55900000e+03
#   4.15087444e+09 5.84414384e+09]
#  [1.13000000e+02 4.70000000e-01 1.61900000e+01 ... 4.30200000e+03
#   3.77861435e+09 5.75759405e+09]
#  ...
#  [1.01200000e+02 8.60000000e-01 1.90000000e+00 ... 8.31900000e+03
#   2.68586194e+10 3.26409023e+10]
#  [1.04100000e+02 8.90000000e-01 1.90000000e+00 ... 9.33800000e+03
#   2.20785725e+10 2.66353020e+10]
#  [1.10200000e+02 1.35000000e+00 1.90000000e+00 ... 1.26730000e+04
#   1.85607303e+10 2.91025891e+10]]

# %% [markdown]
# ### 2.1 Convertendo o array em um modelo de dados 3D para entrada na rede LSTM
#
# ---
# Créditos: https://machinelearningmastery.com/convert-time-series-supervised-learning-problem-python/
#
# Para fazer a predição, utilizei os 12 primeiros meses para predizer o seguinte. Com isso, o dataset perde 12 meses, uma vez que os 11 primeiros meses não possuem 12 meses anteriores e o último mês não possui valor conhecido da arrecadação do mês subsequente.
#
# ___

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
 
raw = DataFrame()
raw['ob1'] = [x for x in range(10)]
raw['ob2'] = [x for x in range(50, 60)]
# values = raw.values
values = pd.DataFrame(serie_cluster2).values
serie_cluster2_prepared = series_to_supervised(values,12)
print(serie_cluster2_prepared)
# Out:
#      var1(t-12)  var2(t-12)  var3(t-12)  var4(t-12)  var5(t-12)  var6(t-12)  \
# 12        104.0        0.76       16.32      136.19       98.59       10.00
# 13        103.1        0.61       16.30      139.84       99.45       10.00
# 14        113.0        0.47       16.19      138.89      111.98       10.00
# 15        107.8        0.37       15.96      138.85      107.36        9.75
# 16        108.9        0.51       15.77      148.25      106.03        9.75
# ..          ...         ...         ...         ...         ...         ...
# 199        97.9        0.11        5.90      114.23      141.78        5.95
# 200       101.7       -0.04        5.71      117.25      138.26        5.95
# 201       102.5        0.10        5.38      116.42      142.80        5.57
# 202        99.4        0.51        4.90      117.74      138.83        5.57
# 203       100.6        1.15        4.59      114.94      137.50        5.57
#
#      var7(t-12)  var8(t-12)  var9(t-12)   var10(t-12)  ...  var2(t)  var3(t)  \
# 12    1735331.5       31.18      1107.0  7.309702e+08  ...     0.58    17.93
# 13    1746819.2       30.87      2559.0  4.150874e+09  ...     0.59    18.47
# 14    1765492.2       33.80      4302.0  3.778614e+09  ...     0.61    18.97
# 15    1781058.0       33.36      5474.0  4.927327e+09  ...     0.87    19.32
# 16    1800951.1       37.92      5976.0  2.175496e+09  ...     0.49    19.61
# ..          ...         ...         ...           ...  ...      ...      ...
# 199   7259724.1       59.25      5751.0  1.614003e+10  ...     0.24     1.94
# 200   7305486.4       62.33      6270.0  1.398523e+10  ...     0.64     1.90
# 201   7343681.6       59.37      6678.0  1.771015e+10  ...     0.86     1.90
# 202   7374387.3       62.74      7202.0  1.508082e+10  ...     0.89     1.90
# 203   7407023.6       65.85      8737.0  1.526310e+10  ...     1.35     1.90
#
#      var4(t)  var5(t)  var6(t)    var7(t)  var8(t)  var9(t)      var10(t)  \
# 12    123.29   103.52     9.75  1976732.7    44.28   2089.0  2.991476e+09
# 13    118.92   104.00     9.75  1994573.0    45.56   3051.0  1.883603e+09
# 14    124.02   115.42     9.75  2012678.1    53.08   4797.0  2.541729e+09
# 15    118.03   112.35     9.75  2032903.2    51.86   5966.0  2.865775e+09
# 16    111.59   110.86     9.75  2050901.0    48.67   7363.0  2.254300e+09
# ..       ...      ...      ...        ...      ...      ...           ...
# 199   153.47   135.52     4.91  7348772.7    44.26   7081.0  1.898179e+10
# 200   150.84   137.10     4.91  7367379.0    41.09   7525.0  1.518463e+10
# 201   155.93   139.73     4.55  7386165.6    40.47   8319.0  2.685862e+10
# 202   149.31   138.11     4.55  7417829.9    43.23   9338.0  2.207857e+10
# 203   139.66   139.41     4.55  7447858.3    49.87  12673.0  1.856073e+10
#
#          var11(t)
# 12   9.171569e+09
# 13   6.970914e+09
# 14   7.356128e+09
# 15   9.611372e+09
# 16   7.820801e+09
# ..            ...
# 199  2.206463e+10
# 200  2.362301e+10
# 201  3.264090e+10
# 202  2.663530e+10
# 203  2.910259e+10
#
# [192 rows x 143 columns]

# %%
serie_cluster2_prepared.head(20)
# Out:
#     var1(t-12)  var2(t-12)  var3(t-12)  var4(t-12)  var5(t-12)  var6(t-12)  \
# 12       104.0        0.76       16.32      136.19       98.59       10.00
# 13       103.1        0.61       16.30      139.84       99.45       10.00
# 14       113.0        0.47       16.19      138.89      111.98       10.00
# 15       107.8        0.37       15.96      138.85      107.36        9.75
# 16       108.9        0.51       15.77      148.25      106.03        9.75
# 17       113.1        0.71       15.80      149.04      107.00        9.75
# 18       110.9        0.91       15.77      143.11      111.47        9.75
# 19       113.2        0.69       15.86      140.62      110.65        9.75
# 20       107.6        0.33       16.09      135.23      109.21        9.75
# 21       103.8        0.44       16.41      133.55      108.89        9.75
# 22       108.6        0.69       16.96      129.60      109.59        9.75
# 23       108.9        0.86       17.50      124.90      107.56        9.75
# 24       105.4        0.58       17.93      123.29      103.52        9.75
# 25       103.3        0.59       18.47      118.92      104.00        9.75
# 26       101.0        0.61       18.97      124.02      115.42        9.75
# 27       105.4        0.87       19.32      118.03      112.35        9.75
# 28       104.9        0.49       19.61      111.59      110.86        9.75
# 29       105.6       -0.02       19.75      109.88      111.50        9.75
# 30        99.9        0.25       19.72      108.29      113.15        9.75
# 31       103.5        0.17       19.75      108.07      115.15        9.75
#
#     var7(t-12)  var8(t-12)  var9(t-12)   var10(t-12)  ...  var2(t)  var3(t)  \
# 12   1735331.5       31.18      1107.0  7.309702e+08  ...     0.58    17.93
# 13   1746819.2       30.87      2559.0  4.150874e+09  ...     0.59    18.47
# 14   1765492.2       33.80      4302.0  3.778614e+09  ...     0.61    18.97
# 15   1781058.0       33.36      5474.0  4.927327e+09  ...     0.87    19.32
# 16   1800951.1       37.92      5976.0  2.175496e+09  ...     0.49    19.61
# 17   1828299.9       35.19      7338.0  2.078371e+09  ...    -0.02    19.75
# 18   1853700.2       38.37      8251.0  2.531327e+09  ...     0.25    19.72
# 19   1878059.7       43.03      8887.0  1.900320e+09  ...     0.17    19.75
# 20   1894202.4       43.38      9562.0  2.038177e+09  ...     0.35    19.61
# 21   1909813.0       49.82     11099.0  2.499241e+09  ...     0.75    19.25
# 22   1933090.2       43.05     12842.0  2.125699e+09  ...     0.55    18.87
# 23   1957751.2       39.64     15526.0  2.509620e+09  ...     0.36    18.24
# 24   1976732.7       44.28      2089.0  2.991476e+09  ...     0.59    17.65
# 25   1994573.0       45.56      3051.0  1.883603e+09  ...     0.41    17.28
# 26   2012678.1       53.08      4797.0  2.541729e+09  ...     0.43    16.74
# 27   2032903.2       51.86      5966.0  2.865775e+09  ...     0.21    16.19
# 28   2050901.0       48.67      7363.0  2.254300e+09  ...     0.10    15.70
# 29   2066440.6       54.31     10274.0  2.480066e+09  ...    -0.21    15.18
# 30   2079143.4       57.58     11523.0  3.324323e+09  ...     0.19    14.98
# 31   2097211.1       64.09     13512.0  2.183455e+09  ...     0.05    14.66
#
#     var4(t)  var5(t)  var6(t)    var7(t)  var8(t)  var9(t)      var10(t)  \
# 12   123.29   103.52     9.75  1976732.7    44.28   2089.0  2.991476e+09
# 13   118.92   104.00     9.75  1994573.0    45.56   3051.0  1.883603e+09
# 14   124.02   115.42     9.75  2012678.1    53.08   4797.0  2.541729e+09
# 15   118.03   112.35     9.75  2032903.2    51.86   5966.0  2.865775e+09
# 16   111.59   110.86     9.75  2050901.0    48.67   7363.0  2.254300e+09
# 17   109.88   111.50     9.75  2066440.6    54.31  10274.0  2.480066e+09
# 18   108.29   113.15     9.75  2079143.4    57.58  11523.0  3.324323e+09
# 19   108.07   115.15     9.75  2097211.1    64.09  13512.0  2.183455e+09
# 20   105.95   110.95     9.75  2114047.4    62.98  14681.0  2.431267e+09
# 21   103.63   111.33     9.75  2132693.9    58.52  15620.0  2.936053e+09
# 22   100.17   111.73     9.75  2150566.9    55.54  19479.0  2.416446e+09
# 23   102.76   111.25     9.75  2170584.5    56.75  23033.0  2.971299e+09
# 24   102.41   108.55     9.00  2192609.2    63.57    634.0  2.550452e+09
# 25    97.17   107.80     9.00  2210389.7    59.92   1299.0  4.975512e+08
# 26    96.84   119.09     9.00  2225144.4    62.25   2385.0  6.269752e+08
# 27    96.43   112.61     8.15  2232996.0    70.44   4695.0  7.948851e+08
# 28    99.03   117.19     8.15  2253373.6    70.19   6089.0  5.167224e+08
# 29   102.64   114.40     8.15  2271563.6    68.86   8477.0  4.700171e+08
# 30   100.05   119.41     7.50  2294464.3    73.90  10937.0  5.264375e+08
# 31    98.67   121.06     7.50  2317035.7    73.61  13812.0  5.503546e+08
#
#         var11(t)
# 12  9.171569e+09
# 13  6.970914e+09
# 14  7.356128e+09
# 15  9.611372e+09
# 16  7.820801e+09
# 17  7.480434e+09
# 18  8.976327e+09
# 19  7.829660e+09
# 20  8.007889e+09
# 21  1.055516e+10
# 22  8.605337e+09
# 23  9.034477e+09
# 24  9.406722e+09
# 25  7.451865e+09
# 26  7.624398e+09
# 27  1.094221e+10
# 28  8.144582e+09
# 29  9.264326e+09
# 30  1.056097e+10
# 31  9.445102e+09
#
# [20 rows x 143 columns]

# %% [markdown]
# ### 2.3 Dividindo o dataset em sets de treino, teste e predição

# %%
# Divide em conjuntos de treino e teste e predição
values = serie_cluster2_prepared.values
# Base de treino com 144 meses
periodo_treino = 144
train = values[:periodo_treino, :]
test = values[periodo_treino:180, :]
predict = values[180:, :]

# %%
# Divide em entradas e saídas
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
predict_X, predict_y = predict[:, :-1], predict[:, -1]

# %% [markdown]
# ### Normalizando os datasets

# %%
## Normalizando os datasets

scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))
scaler_predict_X = MinMaxScaler(feature_range=(0, 1))
scaler_predict_y = MinMaxScaler(feature_range=(0, 1))


train_X = scaler_X.fit_transform(train_X)
test_X = scaler_X.fit_transform(test_X)

train_y = scaler_y.fit_transform(train_y.reshape(-1,1))
test_y = scaler_y.fit_transform(test_y.reshape(-1,1))

predict_X = scaler_predict_X.fit_transform(predict_X)
predict_y = scaler_predict_y.fit_transform(predict_y.reshape(-1,1))

# %%
# Reformata o array 3D 
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
predict_X = predict_X.reshape((predict_X.shape[0], 1, predict_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape,predict_X.shape, predict_y.shape)
# Out:
# (144, 1, 142) (144, 1) (36, 1, 142) (36, 1) (12, 1, 142) (12, 1)

# %% [markdown]
# ## 3. Implementando o modelo LSTM

# %%
#Função para calculo do MAPE - Mean Absolute Percentage Error, que será  utilizado como medida de erro do modelo

def calculo_mape(y_pred,y_true):

    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
train_X.shape
# Out:
# (144, 1, 142)

# %%
def model_builder(hp):
    
    
    model = keras.Sequential()
    
    # Define o número de perceptrons da camada inicial
    # Choose an optimal value between 1-100
    
    hp_units = hp.Int('units', min_value=1, max_value=100, step=1)
    model.add(keras.layers.LSTM(units=hp_units, input_shape=(train_X.shape[1], train_X.shape[2])))
     
    model.add(keras.layers.Dense(1))

    # Tune the learning rate for the optimizer
    # Choose an optimal value from 0.01, 0.001, or 0.0001
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss='mean_squared_error',
                metrics=[keras.metrics.MeanSquaredError()])

    return model

# %%
tuner = kt.Hyperband(model_builder,
                     objective= 'val_loss',
                     max_epochs=50,
                     factor=3,
                     directory='hypertuner',
                     project_name='lstm_keras1')

# %%
# Reexecutar se necessário. Projeto treino 12 disponível no repositório

tuner.search(train_X, train_y, epochs=50, validation_data=(test_X, test_y))
best_hps = tuner.get_best_hyperparameters()[0]
# Out:
# Trial 128 Complete [00h 00m 04s]
# val_loss: 0.015054110437631607
#
# Best val_loss So Far: 0.009761402383446693
# Total elapsed time: 00h 05m 30s
# INFO:tensorflow:Oracle triggered exit

# %%
print(f"""
A busca de hiperparâmentro foi finalizad. O número ótimo de perceptron na camada LSTM é
{best_hps.get('units')} e a melhor taxa de aprendizado do otimizador é {best_hps.get('learning_rate')}.
""")
#
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 291 and the optimal learning rate for the optimizer
# is 0.001.

# %%
model = tuner.hypermodel.build(best_hps)

history = model.fit(train_X, train_y, epochs=50, batch_size=32, 
                    validation_data=(test_X, test_y),  verbose=1, shuffle=False)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 2s 80ms/step - loss: 0.0408 - mean_squared_error: 0.0408 - val_loss: 0.0860 - val_mean_squared_error: 0.0860
# Epoch 2/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0849 - mean_squared_error: 0.0849 - val_loss: 0.0728 - val_mean_squared_error: 0.0728
# Epoch 3/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0382 - val_mean_squared_error: 0.0382
# Epoch 4/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0356 - mean_squared_error: 0.0356 - val_loss: 0.0309 - val_mean_squared_error: 0.0309
# Epoch 5/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.0446 - val_mean_squared_error: 0.0446
# Epoch 6/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0247 - val_mean_squared_error: 0.0247
# Epoch 7/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0257 - val_mean_squared_error: 0.0257
# Epoch 8/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0305 - val_mean_squared_error: 0.0305
# Epoch 9/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0224 - val_mean_squared_error: 0.0224
# Epoch 10/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# Epoch 11/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0249 - val_mean_squared_error: 0.0249
# Epoch 12/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 13/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0216 - val_mean_squared_error: 0.0216
# Epoch 14/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 15/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0191 - val_mean_squared_error: 0.0191
# Epoch 16/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0180 - val_mean_squared_error: 0.0180
# Epoch 17/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0180 - val_mean_squared_error: 0.0180
# Epoch 18/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 19/50
# 5/5 [==============================] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.00 - 0s 11ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# Epoch 20/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0145 - val_mean_squared_error: 0.0145
# Epoch 21/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 22/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 23/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 24/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0134 - val_mean_squared_error: 0.0134
# Epoch 25/50
# 5/5 [==============================] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.00 - 0s 11ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 26/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# Epoch 27/50
# 5/5 [==============================] - ETA: 0s - loss: 0.0024 - mean_squared_error: 0.00 - 0s 10ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 28/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0129 - val_mean_squared_error: 0.0129
# Epoch 29/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0477 - val_mean_squared_error: 0.0477
# Epoch 30/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0085 - val_mean_squared_error: 0.0085
# Epoch 31/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# Epoch 32/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0465 - val_mean_squared_error: 0.0465
# Epoch 33/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 34/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0293 - val_mean_squared_error: 0.0293
# Epoch 35/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0122 - val_mean_squared_error: 0.0122
# Epoch 36/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0192 - val_mean_squared_error: 0.0192
# Epoch 37/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0317 - val_mean_squared_error: 0.0317
# Epoch 38/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0090 - val_mean_squared_error: 0.0090
# Epoch 39/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0322 - val_mean_squared_error: 0.0322
# Epoch 40/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
# Epoch 41/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0151 - val_mean_squared_error: 0.0151
# Epoch 42/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# Epoch 43/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0140 - val_mean_squared_error: 0.0140
# Epoch 44/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0180 - val_mean_squared_error: 0.0180
# Epoch 45/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0181 - val_mean_squared_error: 0.0181
# Epoch 46/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0153 - val_mean_squared_error: 0.0153
# Epoch 47/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 48/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
# Epoch 49/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
# Epoch 50/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0171 - val_mean_squared_error: 0.0171

# %%
# plot history
plt.figure(figsize=(12,4))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()

# %%
plot_model(model, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 1, 291)            505176
# _________________________________________________________________
# dense (Dense)                (None, 1, 1)              292
# =================================================================
# Total params: 505,468
# Trainable params: 505,468
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 4. Fazendo a validação para o período de 2017 a 2019

# %%
# Realizando a predição


yhat = model.predict(test_X)
test_X_final = test_X.reshape(test_X.shape[0], test_X.shape[2])

# invertendo a normalização para apresentar a previsão

yhat_reshaped = yhat.reshape(len(yhat),1)
inv_yhat = np.concatenate((yhat_reshaped, test_X_final[:, :-1]), axis=1)

inv_yhat = inv_yhat[:,0]

test_y_final = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y_final, test_X_final[:, 1:]), axis=1)

inv_y = inv_y[:,0]


# Calculando RMSE
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))


print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.131

# %%
test_y_inv = scaler_y.inverse_transform(test_y_final)
yhat_final_inv = scaler_y.inverse_transform(yhat_reshaped)

df_data = pd.date_range('2017-01','2020-01', freq = 'm')

# Plota o valor observado vs previsto. 

plt.figure(figsize=(15,6))
plt.plot(test_y_inv, label='Observado')
plt.plot(yhat_final_inv, label='Previsto LSTM')
plt.legend()
plt.title('Validação LSTM 2018 - 2019 - MAPE: %.4f' % calculo_mape(yhat_final_inv, test_y_inv))
plt.xticks(np.arange(len(test_y_inv)),df_data.strftime('%m/%Y'), rotation='vertical')
plt.grid(True,axis='y')
plt.show()

# %%
## Formatação das tabelas

pd.set_option('max_columns', None)
pd.options.display.float_format = '{:,.2%}'.format

# %%
variacao_percentual = pd.DataFrame(((yhat_final_inv/test_y_inv)-1) ,columns=['variacao'])

# %%
set_alerta_negativo = pd.DataFrame()
set_normal= pd.DataFrame()
set_alerta_positivo = pd.DataFrame()

# %%
for i in range (len(variacao_percentual)):
    if variacao_percentual.iloc[i].values[0] > 0.05:
        set_alerta_negativo = set_alerta_negativo.append(variacao_percentual[i:i+1])
    elif variacao_percentual.iloc[i].values[0] < -0.05:
        set_alerta_positivo = set_alerta_positivo.append(variacao_percentual[i:i+1])
    else:
        set_normal = set_normal.append(variacao_percentual[i:i+1])

# %%
df_data = pd.date_range('2017-01','2020-01', freq = 'm')

#Plota o resultado do modelo
fig, ax = plt.subplots(figsize=(15,6))
ax.set_ylabel('Variação %')

plt.plot(variacao_percentual * 100, 'o', color='white')

if len(set_alerta_negativo) > 0:
    plt.plot(set_alerta_negativo * 100, 'o', color='red',  label='Arrecadaçao < Previsão Crítico')

if len(set_normal) > 0:
    plt.plot(set_normal * 100, 'o', color='green',  label='Períodos Normais')

if len(set_alerta_positivo) > 0:
    plt.plot(set_alerta_positivo * 100, 'o', color='blue',  label='Arrecadação > Previsão Crítico')

plt.title('Variação entre valores previstos e observados - LSTM' )
plt.grid(True,axis='y')
ax.set_xticks(range(0,36))
plt.xticks(ax.get_xticks(), df_data.strftime('%m/%Y'), rotation='vertical')
plt.legend(loc='upper right')

# %% [markdown]
# # 5. Predição para 2020

# %%
# Realizando a predição


yhat = model.predict(predict_X)
predict_X_final = predict_X.reshape(predict_X.shape[0], predict_X.shape[2])

# Invertendo a escala para apresentar a previsão

yhat_reshaped = yhat.reshape(len(yhat),1)
inv_yhat = np.concatenate((yhat_reshaped, predict_X_final[:, :-1]), axis=1)

inv_yhat = inv_yhat[:,0]
predict_y_final = predict_y.reshape((len(predict_y), 1))
inv_y = np.concatenate((predict_y_final, predict_X_final[:, 1:]), axis=1)

inv_y = inv_y[:,0]

# Calculando o RMSE
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))

print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.183

# %%
predict_y_inv = scaler_predict_y.inverse_transform(predict_y_final)
yhat_final_inv = scaler_predict_y.inverse_transform(yhat_reshaped)

df_data = pd.date_range('2020-01','2021-01', freq = 'm')

# Plota o valor observado vs previsto. 

plt.figure(figsize=(15,6))
plt.plot(predict_y_inv, label='Observado')
plt.plot(yhat_final_inv, label='Previsto LSTM')
plt.legend()
plt.title('Previsão LSTM 2020 - MAPE: %.4f' % calculo_mape(yhat_final_inv[0], predict_y_inv))
plt.xticks(np.arange(len(predict_y_inv)),df_data.strftime('%m/%Y'), rotation='vertical')
plt.grid(True,axis='y')
plt.show()

# %%
## Formatação das tabelas

pd.set_option('max_columns', None)
pd.options.display.float_format = '{:,.2%}'.format

# %%
variacao_percentual = pd.DataFrame(((yhat_final_inv/predict_y_inv)-1) ,columns=['variacao'])

# %%
set_alerta_negativo = pd.DataFrame()
set_normal= pd.DataFrame()
set_alerta_positivo = pd.DataFrame()

# %%
for i in range (len(variacao_percentual)):
    if variacao_percentual.iloc[i].values[0] > 0.05:
        set_alerta_negativo = set_alerta_negativo.append(variacao_percentual[i:i+1])
    elif variacao_percentual.iloc[i].values[0] < -0.05:
        set_alerta_positivo = set_alerta_positivo.append(variacao_percentual[i:i+1])
    else:
        set_normal = set_normal.append(variacao_percentual[i:i+1])

# %%
df_data = pd.date_range('2020-01','2021-01', freq = 'm')

#Plota o resultado do modelo
fig, ax = plt.subplots(figsize=(12,6))
ax.set_ylabel('Variação %')

plt.plot(variacao_percentual * 100, 'o', color='white')

if len(set_alerta_negativo) > 0:
    plt.plot(set_alerta_negativo * 100, 'o', color='red',  label='Arrecadaçao < Previsão Crítico')

if len(set_normal) > 0:
    plt.plot(set_normal * 100, 'o', color='green',  label='Períodos Normais')

if len(set_alerta_positivo) > 0:
    plt.plot(set_alerta_positivo * 100, 'o', color='blue',  label='Arrecadação > Previsão Crítico')

plt.title('Variação entre valores previstos e observados - LSTM' )
plt.grid(True,axis='y')
ax.set_xticks(range(0,12))
plt.xticks(ax.get_xticks(), df_data.strftime('%m/%Y'), rotation='vertical')
plt.legend(loc='upper right')
