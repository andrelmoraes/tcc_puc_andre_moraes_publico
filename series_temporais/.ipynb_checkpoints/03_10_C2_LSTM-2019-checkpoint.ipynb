# %% [markdown]
# # Modelo LSTM para predição
#
# ---
#
#
# ___

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import math
import requests
import json
import os
import statsmodels.api as sm
import tensorflow as tf
from pandas import concat

from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore")

from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)

import math

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras import initializers
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## 1. Importando os datasets

# %%
dataset_cluster2_series = pd.read_csv("datasets//dataset_cluster2_series.csv", header=0, index_col=0)
# dataset_cluster2_validacao = pd.read_csv("datasets//dataset_cluster2_validation.csv", header=0, index_col=0)

# %%
dataset_cluster2_series.head()
# Out:
#                      indice_pimpf  ipca  taxa_selic  taxa_cambio   ibcbr  \
# mes
# 2004-01-01 00:00:00         104.0  0.76       16.32       136.19   98.59
# 2004-02-01 00:00:00         103.1  0.61       16.30       139.84   99.45
# 2004-03-01 00:00:00         113.0  0.47       16.19       138.89  111.98
# 2004-04-01 00:00:00         107.8  0.37       15.96       138.85  107.36
# 2004-05-01 00:00:00         108.9  0.51       15.77       148.25  106.03
#
#                       tjlp  pib_mensal  preco_brent  desembolso       debitos  \
# mes
# 2004-01-01 00:00:00  10.00   1735331.5        31.18      1107.0  7.309702e+08
# 2004-02-01 00:00:00  10.00   1746819.2        30.87      2559.0  4.150874e+09
# 2004-03-01 00:00:00  10.00   1765492.2        33.80      4302.0  3.778614e+09
# 2004-04-01 00:00:00   9.75   1781058.0        33.36      5474.0  4.927327e+09
# 2004-05-01 00:00:00   9.75   1800951.1        37.92      5976.0  2.175496e+09
#
#                       arrecadacao
# mes
# 2004-01-01 00:00:00  6.709728e+09
# 2004-02-01 00:00:00  5.844144e+09
# 2004-03-01 00:00:00  5.757594e+09
# 2004-04-01 00:00:00  7.872113e+09
# 2004-05-01 00:00:00  7.156122e+09

# %%
# dataset_cluster2_validacao.head()

# %% [markdown]
# ## 2. Preparando o dataset para a rede neural LSTM

# %%
np.random.seed(10)

# %%
serie_cluster2 = np.array(dataset_cluster2_series)

# %%
print(serie_cluster2)
# Out:
# [[1.04000000e+02 7.60000000e-01 1.63200000e+01 ... 1.10700000e+03
#   7.30970152e+08 6.70972820e+09]
#  [1.03100000e+02 6.10000000e-01 1.63000000e+01 ... 2.55900000e+03
#   4.15087444e+09 5.84414384e+09]
#  [1.13000000e+02 4.70000000e-01 1.61900000e+01 ... 4.30200000e+03
#   3.77861435e+09 5.75759405e+09]
#  ...
#  [1.02500000e+02 1.00000000e-01 5.38000000e+00 ... 6.67800000e+03
#   1.77101458e+10 3.04153471e+10]
#  [9.94000000e+01 5.10000000e-01 4.90000000e+00 ... 7.20200000e+03
#   1.50808227e+10 2.43810682e+10]
#  [1.00600000e+02 1.15000000e+00 4.59000000e+00 ... 8.73700000e+03
#   1.52630951e+10 2.67613395e+10]]

# %%
# validacao_cluster2 = np.array(dataset_cluster2_validacao)

# %%
# print(validacao_cluster2)

# %%
# np.random.seed(10)

# %% [markdown]
# ### 2.1 Normalizando a escala do dataset

# %%
## Criando um scaler para o campo de saída


scaler_in = MinMaxScaler(feature_range=(0, 1))
scaler_out = MinMaxScaler(feature_range=(0, 1))

serie_cluster2 = scaler_in.fit_transform(serie_cluster2)
# validacao_cluster2 = scaler_out.fit_transform(validacao_cluster2)

# O scaler_out foi criado para estabelecer a escala da saída separadamente, buscando evitar alguma distorção na
# inversão dos valores previstos pelo modelo.

arrecadacao = np.array(dataset_cluster2_series['arrecadacao'])
arrecadacao = arrecadacao.reshape(-1,1)
arrecadacao = scaler_out.fit_transform(arrecadacao)

# %%
print(serie_cluster2)
# Out:
# [[0.58379888 0.63870968 0.7737467  ... 0.00919914 0.03545049 0.03258086]
#  [0.55865922 0.54193548 0.77242744 ... 0.02809186 0.20436445 0.00296163]
#  [0.83519553 0.4516129  0.7651715  ... 0.05077093 0.18597799 0.        ]
#  ...
#  [0.54189944 0.21290323 0.05211082 ... 0.08168629 0.8740762  0.84375793]
#  [0.45530726 0.47741935 0.02044855 ... 0.08850433 0.74421019 0.63727234]
#  [0.48882682 0.89032258 0.         ... 0.108477   0.75321288 0.71872229]]

# %%
# print(validacao_cluster2)

# %% [markdown]
# ### 2.2 Convertendo o array em um modelo de dados 3D para entrada na rede LSTM
#
# ---
# Créditos: https://machinelearningmastery.com/convert-time-series-supervised-learning-problem-python/
#
# Para fazer a predição, utilizei os 12 primeiros meses para predizer o seguinte. Com isso, o dataset perde 12 meses, uma vez que os 11 primeiros meses não possuem 12 meses anteriores e o último mês não possui valor conhecido da arrecadação do mês subsequente.
#
# ___

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
 
raw = DataFrame()
raw['ob1'] = [x for x in range(10)]
raw['ob2'] = [x for x in range(50, 60)]
# values = raw.values
values = pd.DataFrame(serie_cluster2).values
serie_cluster2_prepared = series_to_supervised(values,12)
print(serie_cluster2_prepared)
# Out:
#      var1(t-12)  var2(t-12)  var3(t-12)  var4(t-12)  var5(t-12)  var6(t-12)  \
# 12     0.583799    0.638710    0.773747    0.853109    0.000000       1.000
# 13     0.558659    0.541935    0.772427    0.894833    0.016063       1.000
# 14     0.835196    0.451613    0.765172    0.883973    0.250093       1.000
# 15     0.689944    0.387097    0.750000    0.883516    0.163803       0.950
# 16     0.720670    0.477419    0.737467    0.990969    0.138962       0.950
# ..          ...         ...         ...         ...         ...         ...
# 187    0.522346    0.090323    0.119393    0.593850    0.836384       0.312
# 188    0.399441    0.458065    0.119393    0.651120    0.695181       0.312
# 189    0.483240    0.438710    0.119393    0.533265    0.769145       0.396
# 190    0.427374    0.012903    0.119393    0.535894    0.728614       0.396
# 191    0.326816    0.245161    0.119393    0.563443    0.704894       0.396
#
#      var7(t-12)  var8(t-12)  var9(t-12)  var10(t-12)  ...   var2(t)   var3(t)  \
# 12     0.000000    0.003687    0.009199     0.035450  ...  0.522581  0.879947
# 13     0.002025    0.000679    0.028092     0.204364  ...  0.529032  0.915567
# 14     0.005318    0.029106    0.050771     0.185978  ...  0.541935  0.948549
# 15     0.008062    0.024837    0.066020     0.242715  ...  0.709677  0.971636
# 16     0.011570    0.069079    0.072552     0.106798  ...  0.464516  0.990765
# ..          ...         ...         ...          ...  ...       ...       ...
# 187    0.904759    0.410692    0.083846     0.703861  ...  0.219355  0.086412
# 188    0.911073    0.466285    0.098302     0.790300  ...  0.122581  0.073879
# 189    0.919707    0.481906    0.116557     0.870167  ...  0.212903  0.052111
# 190    0.925625    0.333463    0.132340     0.782660  ...  0.477419  0.020449
# 191    0.928966    0.248957    0.152560     0.745149  ...  0.890323  0.000000
#
#       var4(t)   var5(t)  var6(t)   var7(t)   var8(t)   var9(t)  var10(t)  \
# 12   0.705647  0.092081    0.950  0.042562  0.130785  0.021976  0.147100
# 13   0.655693  0.101046    0.950  0.045708  0.143204  0.034494  0.092381
# 14   0.713992  0.314344    0.950  0.048900  0.216164  0.057212  0.124886
# 15   0.645519  0.257004    0.950  0.052466  0.204327  0.072422  0.140892
# 16   0.571902  0.229174    0.950  0.055639  0.173377  0.090599  0.110690
# ..        ...       ...      ...       ...       ...       ...       ...
# 187  0.602080  0.806687    0.190  0.974029  0.276026  0.069625  0.796526
# 188  0.636603  0.740941    0.190  0.982098  0.305909  0.076378  0.690097
# 189  0.627115  0.825738    0.114  0.988832  0.277190  0.081686  0.874076
# 190  0.642204  0.751588    0.114  0.994246  0.309886  0.088504  0.744210
# 191  0.610197  0.726746    0.114  1.000000  0.340060  0.108477  0.753213
#
#      var11(t)
# 12   0.116822
# 13   0.041518
# 14   0.054700
# 15   0.131872
# 16   0.070600
# ..        ...
# 187  0.696519
# 188  0.612143
# 189  0.843758
# 190  0.637272
# 191  0.718722
#
# [180 rows x 143 columns]

# %%
serie_cluster2_prepared.head(20)
# Out:
#     var1(t-12)  var2(t-12)  var3(t-12)  var4(t-12)  var5(t-12)  var6(t-12)  \
# 12    0.583799    0.638710    0.773747    0.853109    0.000000        1.00
# 13    0.558659    0.541935    0.772427    0.894833    0.016063        1.00
# 14    0.835196    0.451613    0.765172    0.883973    0.250093        1.00
# 15    0.689944    0.387097    0.750000    0.883516    0.163803        0.95
# 16    0.720670    0.477419    0.737467    0.990969    0.138962        0.95
# 17    0.837989    0.606452    0.739446    1.000000    0.157079        0.95
# 18    0.776536    0.735484    0.737467    0.932213    0.240568        0.95
# 19    0.840782    0.593548    0.743404    0.903749    0.225252        0.95
# 20    0.684358    0.361290    0.758575    0.842135    0.198356        0.95
# 21    0.578212    0.432258    0.779683    0.822931    0.192380        0.95
# 22    0.712291    0.593548    0.815963    0.777778    0.205454        0.95
# 23    0.720670    0.703226    0.851583    0.724051    0.167538        0.95
# 24    0.622905    0.522581    0.879947    0.705647    0.092081        0.95
# 25    0.564246    0.529032    0.915567    0.655693    0.101046        0.95
# 26    0.500000    0.541935    0.948549    0.713992    0.314344        0.95
# 27    0.622905    0.709677    0.971636    0.645519    0.257004        0.95
# 28    0.608939    0.464516    0.990765    0.571902    0.229174        0.95
# 29    0.628492    0.135484    1.000000    0.552355    0.241128        0.95
# 30    0.469274    0.309677    0.998021    0.534179    0.271946        0.95
# 31    0.569832    0.258065    1.000000    0.531664    0.309301        0.95
#
#     var7(t-12)  var8(t-12)  var9(t-12)  var10(t-12)  ...   var2(t)   var3(t)  \
# 12    0.000000    0.003687    0.009199     0.035450  ...  0.522581  0.879947
# 13    0.002025    0.000679    0.028092     0.204364  ...  0.529032  0.915567
# 14    0.005318    0.029106    0.050771     0.185978  ...  0.541935  0.948549
# 15    0.008062    0.024837    0.066020     0.242715  ...  0.709677  0.971636
# 16    0.011570    0.069079    0.072552     0.106798  ...  0.464516  0.990765
# 17    0.016392    0.042592    0.090274     0.102001  ...  0.135484  1.000000
# 18    0.020870    0.073445    0.102153     0.124373  ...  0.309677  0.998021
# 19    0.025165    0.118657    0.110429     0.093206  ...  0.258065  1.000000
# 20    0.028011    0.122053    0.119212     0.100015  ...  0.374194  0.990765
# 21    0.030764    0.184535    0.139210     0.122788  ...  0.632258  0.967018
# 22    0.034868    0.118851    0.161889     0.104338  ...  0.503226  0.941953
# 23    0.039216    0.085767    0.196812     0.123301  ...  0.380645  0.900396
# 24    0.042562    0.130785    0.021976     0.147100  ...  0.529032  0.861478
# 25    0.045708    0.143204    0.034494     0.092381  ...  0.412903  0.837071
# 26    0.048900    0.216164    0.057212     0.124886  ...  0.425806  0.801451
# 27    0.052466    0.204327    0.072422     0.140892  ...  0.283871  0.765172
# 28    0.055639    0.173377    0.090599     0.110690  ...  0.212903  0.732850
# 29    0.058379    0.228097    0.128476     0.121841  ...  0.012903  0.698549
# 30    0.060619    0.259823    0.144727     0.163540  ...  0.270968  0.685356
# 31    0.063805    0.322984    0.170607     0.107191  ...  0.180645  0.664248
#
#      var4(t)   var5(t)  var6(t)   var7(t)   var8(t)   var9(t)  var10(t)  \
# 12  0.705647  0.092081     0.95  0.042562  0.130785  0.021976  0.147100
# 13  0.655693  0.101046     0.95  0.045708  0.143204  0.034494  0.092381
# 14  0.713992  0.314344     0.95  0.048900  0.216164  0.057212  0.124886
# 15  0.645519  0.257004     0.95  0.052466  0.204327  0.072422  0.140892
# 16  0.571902  0.229174     0.95  0.055639  0.173377  0.090599  0.110690
# 17  0.552355  0.241128     0.95  0.058379  0.228097  0.128476  0.121841
# 18  0.534179  0.271946     0.95  0.060619  0.259823  0.144727  0.163540
# 19  0.531664  0.309301     0.95  0.063805  0.322984  0.170607  0.107191
# 20  0.507430  0.230855     0.95  0.066773  0.312215  0.185817  0.119431
# 21  0.480910  0.237953     0.95  0.070061  0.268943  0.198035  0.144363
# 22  0.441358  0.245424     0.95  0.073212  0.240031  0.248247  0.118699
# 23  0.470965  0.236459     0.95  0.076741  0.251771  0.294490  0.146104
# 24  0.466964  0.186029     0.80  0.080625  0.317939  0.003045  0.125317
# 25  0.407064  0.172021     0.80  0.083760  0.282526  0.011697  0.023922
# 26  0.403292  0.382891     0.80  0.086361  0.305132  0.025828  0.030314
# 27  0.398605  0.261860     0.63  0.087745  0.384593  0.055884  0.038607
# 28  0.428326  0.347404     0.63  0.091338  0.382167  0.074023  0.024868
# 29  0.469593  0.295293     0.63  0.094545  0.369264  0.105094  0.022562
# 30  0.439986  0.388868     0.50  0.098583  0.418162  0.137102  0.025348
# 31  0.424211  0.419686     0.50  0.102563  0.415349  0.174510  0.026530
#
#     var11(t)
# 12  0.116822
# 13  0.041518
# 14  0.054700
# 15  0.131872
# 16  0.070600
# 17  0.058953
# 18  0.110141
# 19  0.070904
# 20  0.077002
# 21  0.164167
# 22  0.097446
# 23  0.112131
# 24  0.124869
# 25  0.057976
# 26  0.063880
# 27  0.177411
# 28  0.081680
# 29  0.119996
# 30  0.164366
# 31  0.126182
#
# [20 rows x 143 columns]

# %% [markdown]
# ### 2.3 Dividindo o dataset em sets de treino e teste

# %%
# Divide em conjuntos de treino e teste
values = serie_cluster2_prepared.values
# Base de treino com 156 meses
periodo_treino = 168
train = values[:periodo_treino, :]
test = values[periodo_treino:, :]

# %%
# Divide em entradas e saídas
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# Reformata o array 3D 
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (168, 1, 142) (168,) (12, 1, 142) (12,)

# %% [markdown]
# ## 3. Implementando o modelo LSTM

# %%
#Função para calculo do MAPE - Mean Absolute Percentage Error, que será  utilizado como medida de erro do modelo

def calculo_mape(y_pred,y_true):

    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
train_X.shape
# Out:
# (168, 1, 142)

# %%
initializer = tf.keras.initializers.GlorotNormal(seed=11)

model = Sequential()

model.add(LSTM(142, return_sequences = True, kernel_initializer=initializer, # use_bias=True, 
               input_shape=(train_X.shape[1], train_X.shape[2])))
# O método Dropout é utilizado para reduzir o overfitting

model.add(Dropout(0.2))

model.add(LSTM(142, return_sequences = True, kernel_initializer=initializer))
model.add(Dropout(0.2))

model.add(LSTM(142, return_sequences = True, kernel_initializer=initializer))
model.add(Dropout(0.2))

model.add(LSTM(142, return_sequences = True, kernel_initializer=initializer))
model.add(Dropout(0.2))



model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='Adam')
# fit network
history = model.fit(train_X, train_y, epochs=185, batch_size=64, 
                    validation_data=(test_X, test_y),  verbose=1, shuffle=False)
# Out:
# Epoch 1/185
# 3/3 [==============================] - 4s 390ms/step - loss: 0.1155 - val_loss: 0.5035
# Epoch 2/185
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0985 - val_loss: 0.4419
# Epoch 3/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0694 - val_loss: 0.3240
# Epoch 4/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0280 - val_loss: 0.1385
# Epoch 5/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0216 - val_loss: 0.0555
# Epoch 6/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0404 - val_loss: 0.0948
# Epoch 7/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0254 - val_loss: 0.1564
# Epoch 8/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0229 - val_loss: 0.1782
# Epoch 9/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0200 - val_loss: 0.1591
# Epoch 10/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0165 - val_loss: 0.1167
# Epoch 11/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0138 - val_loss: 0.0749
# Epoch 12/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0159 - val_loss: 0.0597
# Epoch 13/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0150 - val_loss: 0.0688
# Epoch 14/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0122 - val_loss: 0.0807
# Epoch 15/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0116 - val_loss: 0.0758
# Epoch 16/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0098 - val_loss: 0.0543
# Epoch 17/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0078 - val_loss: 0.0351
# Epoch 18/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0102 - val_loss: 0.0323
# Epoch 19/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 0.0353
# Epoch 20/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0087 - val_loss: 0.0321
# Epoch 21/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 0.0239
# Epoch 22/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0091 - val_loss: 0.0210
# Epoch 23/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0079 - val_loss: 0.0245
# Epoch 24/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0074 - val_loss: 0.0257
# Epoch 25/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 0.0217
# Epoch 26/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0072 - val_loss: 0.0192
# Epoch 27/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0067 - val_loss: 0.0190
# Epoch 28/185
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0061 - val_loss: 0.0189
# Epoch 29/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0056 - val_loss: 0.0164
# Epoch 30/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0058 - val_loss: 0.0150
# Epoch 31/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0062 - val_loss: 0.0144
# Epoch 32/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0055 - val_loss: 0.0136
# Epoch 33/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0059 - val_loss: 0.0129
# Epoch 34/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0056 - val_loss: 0.0126
# Epoch 35/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0053 - val_loss: 0.0123
# Epoch 36/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0054 - val_loss: 0.0114
# Epoch 37/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0064 - val_loss: 0.0118
# Epoch 38/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0047 - val_loss: 0.0114
# Epoch 39/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0061 - val_loss: 0.0097
# Epoch 40/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0054 - val_loss: 0.0142
# Epoch 41/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0048 - val_loss: 0.0095
# Epoch 42/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0059 - val_loss: 0.0090
# Epoch 43/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0112
# Epoch 44/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0083
# Epoch 45/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0046 - val_loss: 0.0085
# Epoch 46/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0084
# Epoch 47/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0051 - val_loss: 0.0067
# Epoch 48/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0047 - val_loss: 0.0077
# Epoch 49/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0038 - val_loss: 0.0065
# Epoch 50/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0039 - val_loss: 0.0057
# Epoch 51/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0036 - val_loss: 0.0061
# Epoch 52/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0035 - val_loss: 0.0049
# Epoch 53/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0035 - val_loss: 0.0045
# Epoch 54/185
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0051
# Epoch 55/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0027 - val_loss: 0.0040
# Epoch 56/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 57/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 58/185
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 59/185
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0033 - val_loss: 0.0042
# Epoch 60/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0027 - val_loss: 0.0035
# Epoch 61/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 62/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 63/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 64/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 65/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0037
# Epoch 66/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 0.0033
# Epoch 67/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0040
# Epoch 68/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0033
# Epoch 69/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0035 - val_loss: 0.0060
# Epoch 70/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0053
# Epoch 71/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0042 - val_loss: 0.0032
# Epoch 72/185
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0035 - val_loss: 0.0127
# Epoch 73/185
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0030 - val_loss: 0.0034
# Epoch 74/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0039 - val_loss: 0.0035
# Epoch 75/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0031 - val_loss: 0.0069
# Epoch 76/185
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0028 - val_loss: 0.0045
# Epoch 77/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 78/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0085
# Epoch 79/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0041
# Epoch 80/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0035 - val_loss: 0.0051
# Epoch 81/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0039 - val_loss: 0.0108
# Epoch 82/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 83/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 84/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0093
# Epoch 85/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 86/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0030
# Epoch 87/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0027 - val_loss: 0.0045
# Epoch 88/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0033
# Epoch 89/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 90/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 0.0033
# Epoch 91/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0035
# Epoch 92/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0022 - val_loss: 0.0037
# Epoch 93/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 94/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 0.0034
# Epoch 95/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 96/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 97/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 98/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 0.0044
# Epoch 99/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0022 - val_loss: 0.0032
# Epoch 100/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0021 - val_loss: 0.0035
# Epoch 101/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0058
# Epoch 102/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 0.0035
# Epoch 103/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 0.0042
# Epoch 104/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 0.0039
# Epoch 105/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 106/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0020 - val_loss: 0.0034
# Epoch 107/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 108/185
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 109/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 0.0042
# Epoch 110/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0018 - val_loss: 0.0040
# Epoch 111/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 112/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 113/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0041
# Epoch 114/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 115/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 0.0040
# Epoch 116/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0018 - val_loss: 0.0055
# Epoch 117/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 118/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0049
# Epoch 119/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0017 - val_loss: 0.0060
# Epoch 120/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 121/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 0.0034
# Epoch 122/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 123/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0035
# Epoch 124/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 0.0037
# Epoch 125/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 0.0037
# Epoch 126/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0047
# Epoch 127/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 128/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0017 - val_loss: 0.0039
# Epoch 129/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 130/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0036
# Epoch 131/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 132/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 133/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0021 - val_loss: 0.0049
# Epoch 134/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 135/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0037
# Epoch 136/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 137/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 138/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 0.0038
# Epoch 139/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 140/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 0.0040
# Epoch 141/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0040
# Epoch 142/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.0031
# Epoch 143/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0063
# Epoch 144/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 145/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0062
# Epoch 146/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 147/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0032 - val_loss: 0.0039
# Epoch 148/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0034 - val_loss: 0.0097
# Epoch 149/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 0.0033
# Epoch 150/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 151/185
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 0.0034
# Epoch 152/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 153/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 154/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0038
# Epoch 155/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 156/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 0.0043
# Epoch 157/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0025 - val_loss: 0.0044
# Epoch 158/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 159/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 0.0045
# Epoch 160/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 161/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 162/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 163/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 164/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0038
# Epoch 165/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0018 - val_loss: 0.0034
# Epoch 166/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 167/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 0.0037
# Epoch 168/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 169/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0047
# Epoch 170/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0035
# Epoch 171/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0049
# Epoch 172/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0017 - val_loss: 0.0036
# Epoch 173/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 174/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 0.0043
# Epoch 175/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.0032
# Epoch 176/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.0048
# Epoch 177/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 178/185
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 0.0036
# Epoch 179/185
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 180/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 181/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0066
# Epoch 182/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0028
# Epoch 183/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 0.0047
# Epoch 184/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0070
# Epoch 185/185
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0035

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()

# %%
plot_model(model, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 1, 142)            161880
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1, 142)            0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 1, 142)            161880
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1, 142)            0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 1, 142)            161880
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1, 142)            0
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 1, 142)            161880
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1, 142)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1, 1)              143
# =================================================================
# Total params: 647,663
# Trainable params: 647,663
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 4. Fazendo a previsão para 2019

# %%
# Realizando a predição


yhat = model.predict(test_X)
test_X_final = test_X.reshape(test_X.shape[0], test_X.shape[2])

# Invertendo a escala para apresentar a previsão

inv_yhat = np.concatenate((np.squeeze(yhat, axis=(2,)), test_X_final[:, :-1]), axis=1)


inv_yhat = inv_yhat[:,0]
test_y_final = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y_final, test_X_final[:, 1:]), axis=1)

inv_y = inv_y[:,0]

# Calculando o RMSE e o MAPE
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))

mape = calculo_mape(inv_yhat, inv_y)
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.059

# %%
test_y_inv = scaler_out.inverse_transform(test_y_final)
yhat_final_inv = scaler_out.inverse_transform(np.squeeze(yhat, axis=(2,)))


df_data = pd.date_range('2019-01','2020-01', freq = 'm')

# Plota o valor observado vs previsto. 

plt.figure(figsize=(10,10))
plt.plot(test_y_inv, label='Observado')
plt.plot(yhat_final_inv, label='Previsto LSTM')
plt.legend()
plt.title('Teste LSTM - MAPE: %.4f' % mape)
plt.xticks(np.arange(len(test_y_inv)),df_data.strftime('%m/%Y'), rotation='vertical')
plt.grid(True,axis='y')
plt.show()

# %%
## Formatação das tabelas

pd.set_option('max_columns', None)
pd.options.display.float_format = '{:,.2%}'.format

# %%
variacao_percentual = pd.DataFrame(((yhat_final_inv/test_y_inv)-1) ,columns=['variacao'])

# %%
set_alerta_negativo = pd.DataFrame()
set_normal= pd.DataFrame()
set_alerta_positivo = pd.DataFrame()

# %%
variacao_percentual
# Out:
#     variacao
# 0     -9.05%
# 1     -0.07%
# 2     -0.74%
# 3     -6.37%
# 4     -2.46%
# 5     -1.25%
# 6     -7.22%
# 7     -6.15%
# 8      4.20%
# 9      6.31%
# 10    -0.12%
# 11   -10.70%

# %%
for i in range (len(variacao_percentual)):
    if variacao_percentual.iloc[i].values[0] > 0.05:
        set_alerta_negativo = set_alerta_negativo.append(variacao_percentual[i:i+1])
    elif variacao_percentual.iloc[i].values[0] < -0.05:
        set_alerta_positivo = set_alerta_positivo.append(variacao_percentual[i:i+1])
    else:
        set_normal = set_normal.append(variacao_percentual[i:i+1])

# %%
df_data = pd.date_range('2019-01','2020-01', freq = 'm')

#Plota o resultado do modelo
fig, ax = plt.subplots(figsize=(12,6))
ax.set_ylabel('Variação %')

plt.plot(variacao_percentual * 100, 'o', color='white')

if len(set_alerta_negativo) > 0:
    plt.plot(set_alerta_negativo * 100, 'o', color='red',  label='Arrecadaçao < Previsão Crítico')

if len(set_normal) > 0:
    plt.plot(set_normal * 100, 'o', color='green',  label='Períodos Normais')

if len(set_alerta_positivo) > 0:
    plt.plot(set_alerta_positivo * 100, 'o', color='blue',  label='Arrecadação > Previsão Crítico')

plt.title('Variação entre valores previstos e observados - LSTM' )
plt.grid(True,axis='y')
ax.set_xticks(range(0,12))
plt.xticks(ax.get_xticks(), df_data.strftime('%m/%Y'), rotation='vertical')
plt.legend(loc='upper left')

# %%
print(test_y_inv - yhat_final_inv)
# Out:
# [[ 3.16688624e+09]
#  [ 1.41865834e+07]
#  [ 1.67171327e+08]
#  [ 1.95929801e+09]
#  [ 5.72091658e+08]
#  [ 3.02178746e+08]
#  [ 2.40184379e+09]
#  [ 1.60500745e+09]
#  [-9.92201979e+08]
#  [-1.91889062e+09]
#  [ 2.99775592e+07]
#  [ 2.86410204e+09]]
