# %% [markdown]
# # Modelo LSTM para predição
#
# ---
#
#
# ___

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import math
import requests
import json
import os
import statsmodels.api as sm
import tensorflow as tf
from pandas import concat

from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore")

from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)

import math

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.utils import plot_model
from tensorflow.keras import initializers
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## 1. Importando os datasets

# %%
dataset_cluster2_series = pd.read_csv("datasets//dataset_cluster2_series.csv", header=0, index_col=0)
dataset_cluster2_validacao = pd.read_csv("datasets//dataset_cluster2_validation.csv", header=0, index_col=0)

dataset_cluster2_series = dataset_cluster2_series.append(dataset_cluster2_validacao)

# %%
dataset_cluster2_series.tail(20)
# Out:
#                      indice_pimpf    ipca  taxa_selic  taxa_cambio      ibcbr  \
# mes
# 2019-05-01 00:00:00    11,170.00%  13.00%     640.00%   11,378.00% 13,925.00%
# 2019-06-01 00:00:00     9,550.00%   1.00%     640.00%   10,982.00% 13,500.00%
# 2019-07-01 00:00:00     9,840.00%  19.00%     640.00%   10,751.00% 14,294.00%
# 2019-08-01 00:00:00     9,790.00%  11.00%     590.00%   11,423.00% 14,178.00%
# 2019-09-01 00:00:00    10,170.00%  -4.00%     571.00%   11,725.00% 13,826.00%
# 2019-10-01 00:00:00    10,250.00%  10.00%     538.00%   11,642.00% 14,280.00%
# 2019-11-01 00:00:00     9,940.00%  51.00%     490.00%   11,774.00% 13,883.00%
# 2019-12-01 00:00:00    10,060.00% 115.00%     459.00%   11,494.00% 13,750.00%
# 2020-01-01 00:00:00    10,150.00%  21.00%     440.00%   11,616.00% 13,360.00%
# 2020-02-01 00:00:00     9,960.00%  25.00%     419.00%   12,184.00% 13,465.00%
# 2020-03-01 00:00:00     9,570.00%   7.00%     395.00%   13,652.00% 13,670.00%
# 2020-04-01 00:00:00     6,820.00% -31.00%     365.00%   14,797.00% 11,915.00%
# 2020-05-01 00:00:00     7,620.00% -38.00%     301.00%   15,750.00% 11,978.00%
# 2020-06-01 00:00:00     9,030.00%  26.00%     258.00%   14,532.00% 12,615.00%
# 2020-07-01 00:00:00     9,680.00%  36.00%     215.00%   14,827.00% 13,585.00%
# 2020-08-01 00:00:00     9,750.00%  24.00%     194.00%   15,347.00% 13,552.00%
# 2020-09-01 00:00:00    10,490.00%  64.00%     190.00%   15,084.00% 13,710.00%
# 2020-10-01 00:00:00    10,120.00%  86.00%     190.00%   15,593.00% 13,973.00%
# 2020-11-01 00:00:00    10,410.00%  89.00%     190.00%   14,931.00% 13,811.00%
# 2020-12-01 00:00:00    11,020.00% 135.00%     190.00%   13,966.00% 13,941.00%
#
#                        tjlp      pib_mensal  preco_brent    desembolso  \
# mes
# 2019-05-01 00:00:00 626.00% 717,645,130.00%    7,053.00%   374,600.00%
# 2019-06-01 00:00:00 626.00% 718,982,060.00%    6,330.00%   475,500.00%
# 2019-07-01 00:00:00 595.00% 723,139,130.00%    6,400.00%   526,400.00%
# 2019-08-01 00:00:00 595.00% 725,972,410.00%    5,925.00%   575,100.00%
# 2019-09-01 00:00:00 595.00% 730,548,640.00%    6,233.00%   627,000.00%
# 2019-10-01 00:00:00 557.00% 734,368,160.00%    5,937.00%   667,800.00%
# 2019-11-01 00:00:00 557.00% 737,438,730.00%    6,274.00%   720,200.00%
# 2019-12-01 00:00:00 557.00% 740,702,360.00%    6,585.00%   873,700.00%
# 2020-01-01 00:00:00 509.00% 743,582,620.00%    6,360.00%    25,700.00%
# 2020-02-01 00:00:00 509.00% 746,382,690.00%    5,500.00%    79,200.00%
# 2020-03-01 00:00:00 509.00% 748,525,310.00%    3,298.00%   129,400.00%
# 2020-04-01 00:00:00 494.00% 742,287,450.00%    2,334.00%   225,400.00%
# 2020-05-01 00:00:00 494.00% 736,519,370.00%    3,102.00%   307,800.00%
# 2020-06-01 00:00:00 494.00% 735,964,660.00%    3,993.00%   428,300.00%
# 2020-07-01 00:00:00 491.00% 734,928,000.00%    4,281.00%   488,300.00%
# 2020-08-01 00:00:00 491.00% 734,877,270.00%    4,426.00%   708,100.00%
# 2020-09-01 00:00:00 491.00% 736,737,900.00%    4,109.00%   752,500.00%
# 2020-10-01 00:00:00 455.00% 738,616,560.00%    4,047.00%   831,900.00%
# 2020-11-01 00:00:00 455.00% 741,782,990.00%    4,323.00%   933,800.00%
# 2020-12-01 00:00:00 455.00% 744,785,830.00%    4,987.00% 1,267,300.00%
#
#                                   debitos           arrecadacao
# mes
# 2019-05-01 00:00:00 1,296,586,763,818.00% 2,321,507,252,208.00%
# 2019-06-01 00:00:00 1,354,677,910,552.00% 2,417,659,948,167.00%
# 2019-07-01 00:00:00 2,005,272,531,636.00% 3,327,619,745,494.00%
# 2019-08-01 00:00:00 1,614,002,852,447.00% 2,611,246,293,953.00%
# 2019-09-01 00:00:00 1,398,522,648,866.00% 2,364,669,824,500.00%
# 2019-10-01 00:00:00 1,771,014,576,850.00% 3,041,534,707,938.00%
# 2019-11-01 00:00:00 1,508,082,272,157.00% 2,438,106,824,724.00%
# 2019-12-01 00:00:00 1,526,309,505,212.00% 2,676,133,954,809.00%
# 2020-01-01 00:00:00 2,095,456,278,073.00% 3,553,139,259,557.00%
# 2020-02-01 00:00:00 1,304,137,222,695.00% 2,220,378,196,464.00%
# 2020-03-01 00:00:00 1,587,917,302,121.00% 1,932,961,820,373.00%
# 2020-04-01 00:00:00 1,198,778,951,814.00% 2,014,531,351,334.00%
# 2020-05-01 00:00:00   576,918,631,419.00% 1,314,480,910,607.00%
# 2020-06-01 00:00:00   626,614,141,201.00% 1,234,029,528,765.00%
# 2020-07-01 00:00:00 1,784,355,238,097.00% 1,983,441,389,924.00%
# 2020-08-01 00:00:00 1,898,178,527,422.00% 2,206,462,826,029.00%
# 2020-09-01 00:00:00 1,518,463,120,765.00% 2,362,300,686,814.00%
# 2020-10-01 00:00:00 2,685,861,935,147.00% 3,264,090,234,746.00%
# 2020-11-01 00:00:00 2,207,857,247,919.00% 2,663,530,200,567.00%
# 2020-12-01 00:00:00 1,856,073,025,572.00% 2,910,258,905,908.00%

# %%
dataset_cluster2_validacao.head(20)
# Out:
#                      indice_pimpf    ipca  taxa_selic  taxa_cambio      ibcbr  \
# mes
# 2020-01-01 00:00:00    10,150.00%  21.00%     440.00%   11,616.00% 13,360.00%
# 2020-02-01 00:00:00     9,960.00%  25.00%     419.00%   12,184.00% 13,465.00%
# 2020-03-01 00:00:00     9,570.00%   7.00%     395.00%   13,652.00% 13,670.00%
# 2020-04-01 00:00:00     6,820.00% -31.00%     365.00%   14,797.00% 11,915.00%
# 2020-05-01 00:00:00     7,620.00% -38.00%     301.00%   15,750.00% 11,978.00%
# 2020-06-01 00:00:00     9,030.00%  26.00%     258.00%   14,532.00% 12,615.00%
# 2020-07-01 00:00:00     9,680.00%  36.00%     215.00%   14,827.00% 13,585.00%
# 2020-08-01 00:00:00     9,750.00%  24.00%     194.00%   15,347.00% 13,552.00%
# 2020-09-01 00:00:00    10,490.00%  64.00%     190.00%   15,084.00% 13,710.00%
# 2020-10-01 00:00:00    10,120.00%  86.00%     190.00%   15,593.00% 13,973.00%
# 2020-11-01 00:00:00    10,410.00%  89.00%     190.00%   14,931.00% 13,811.00%
# 2020-12-01 00:00:00    11,020.00% 135.00%     190.00%   13,966.00% 13,941.00%
#
#                        tjlp      pib_mensal  preco_brent    desembolso  \
# mes
# 2020-01-01 00:00:00 509.00% 743,582,620.00%    6,360.00%    25,700.00%
# 2020-02-01 00:00:00 509.00% 746,382,690.00%    5,500.00%    79,200.00%
# 2020-03-01 00:00:00 509.00% 748,525,310.00%    3,298.00%   129,400.00%
# 2020-04-01 00:00:00 494.00% 742,287,450.00%    2,334.00%   225,400.00%
# 2020-05-01 00:00:00 494.00% 736,519,370.00%    3,102.00%   307,800.00%
# 2020-06-01 00:00:00 494.00% 735,964,660.00%    3,993.00%   428,300.00%
# 2020-07-01 00:00:00 491.00% 734,928,000.00%    4,281.00%   488,300.00%
# 2020-08-01 00:00:00 491.00% 734,877,270.00%    4,426.00%   708,100.00%
# 2020-09-01 00:00:00 491.00% 736,737,900.00%    4,109.00%   752,500.00%
# 2020-10-01 00:00:00 455.00% 738,616,560.00%    4,047.00%   831,900.00%
# 2020-11-01 00:00:00 455.00% 741,782,990.00%    4,323.00%   933,800.00%
# 2020-12-01 00:00:00 455.00% 744,785,830.00%    4,987.00% 1,267,300.00%
#
#                                   debitos           arrecadacao
# mes
# 2020-01-01 00:00:00 2,095,456,278,073.00% 3,553,139,259,557.00%
# 2020-02-01 00:00:00 1,304,137,222,695.00% 2,220,378,196,464.00%
# 2020-03-01 00:00:00 1,587,917,302,121.00% 1,932,961,820,373.00%
# 2020-04-01 00:00:00 1,198,778,951,814.00% 2,014,531,351,334.00%
# 2020-05-01 00:00:00   576,918,631,419.00% 1,314,480,910,607.00%
# 2020-06-01 00:00:00   626,614,141,201.00% 1,234,029,528,765.00%
# 2020-07-01 00:00:00 1,784,355,238,097.00% 1,983,441,389,924.00%
# 2020-08-01 00:00:00 1,898,178,527,422.00% 2,206,462,826,029.00%
# 2020-09-01 00:00:00 1,518,463,120,765.00% 2,362,300,686,814.00%
# 2020-10-01 00:00:00 2,685,861,935,147.00% 3,264,090,234,746.00%
# 2020-11-01 00:00:00 2,207,857,247,919.00% 2,663,530,200,567.00%
# 2020-12-01 00:00:00 1,856,073,025,572.00% 2,910,258,905,908.00%

# %% [markdown]
# ## 2. Preparando o dataset para a rede neural LSTM

# %%
np.random.seed(10)

# %%
serie_cluster2 = np.array(dataset_cluster2_series)

# %%
print(serie_cluster2)
# Out:
# [[1.04000000e+02 7.60000000e-01 1.63200000e+01 ... 1.10700000e+03
#   7.30970152e+08 6.70972820e+09]
#  [1.03100000e+02 6.10000000e-01 1.63000000e+01 ... 2.55900000e+03
#   4.15087444e+09 5.84414384e+09]
#  [1.13000000e+02 4.70000000e-01 1.61900000e+01 ... 4.30200000e+03
#   3.77861435e+09 5.75759405e+09]
#  ...
#  [1.01200000e+02 8.60000000e-01 1.90000000e+00 ... 8.31900000e+03
#   2.68586194e+10 3.26409023e+10]
#  [1.04100000e+02 8.90000000e-01 1.90000000e+00 ... 9.33800000e+03
#   2.20785725e+10 2.66353020e+10]
#  [1.10200000e+02 1.35000000e+00 1.90000000e+00 ... 1.26730000e+04
#   1.85607303e+10 2.91025891e+10]]

# %%
validacao_cluster2 = np.array(dataset_cluster2_validacao)

# %%
print(validacao_cluster2)
# Out:
# [[ 1.01500000e+02  2.10000000e-01  4.40000000e+00  1.16160000e+02
#    1.33600000e+02  5.09000000e+00  7.43582620e+06  6.36000000e+01
#    2.57000000e+02  2.09545628e+10  3.55313926e+10]
#  [ 9.96000000e+01  2.50000000e-01  4.19000000e+00  1.21840000e+02
#    1.34650000e+02  5.09000000e+00  7.46382690e+06  5.50000000e+01
#    7.92000000e+02  1.30413722e+10  2.22037820e+10]
#  [ 9.57000000e+01  7.00000000e-02  3.95000000e+00  1.36520000e+02
#    1.36700000e+02  5.09000000e+00  7.48525310e+06  3.29800000e+01
#    1.29400000e+03  1.58791730e+10  1.93296182e+10]
#  [ 6.82000000e+01 -3.10000000e-01  3.65000000e+00  1.47970000e+02
#    1.19150000e+02  4.94000000e+00  7.42287450e+06  2.33400000e+01
#    2.25400000e+03  1.19877895e+10  2.01453135e+10]
#  [ 7.62000000e+01 -3.80000000e-01  3.01000000e+00  1.57500000e+02
#    1.19780000e+02  4.94000000e+00  7.36519370e+06  3.10200000e+01
#    3.07800000e+03  5.76918631e+09  1.31448091e+10]
#  [ 9.03000000e+01  2.60000000e-01  2.58000000e+00  1.45320000e+02
#    1.26150000e+02  4.94000000e+00  7.35964660e+06  3.99300000e+01
#    4.28300000e+03  6.26614141e+09  1.23402953e+10]
#  [ 9.68000000e+01  3.60000000e-01  2.15000000e+00  1.48270000e+02
#    1.35850000e+02  4.91000000e+00  7.34928000e+06  4.28100000e+01
#    4.88300000e+03  1.78435524e+10  1.98344139e+10]
#  [ 9.75000000e+01  2.40000000e-01  1.94000000e+00  1.53470000e+02
#    1.35520000e+02  4.91000000e+00  7.34877270e+06  4.42600000e+01
#    7.08100000e+03  1.89817853e+10  2.20646283e+10]
#  [ 1.04900000e+02  6.40000000e-01  1.90000000e+00  1.50840000e+02
#    1.37100000e+02  4.91000000e+00  7.36737900e+06  4.10900000e+01
#    7.52500000e+03  1.51846312e+10  2.36230069e+10]
#  [ 1.01200000e+02  8.60000000e-01  1.90000000e+00  1.55930000e+02
#    1.39730000e+02  4.55000000e+00  7.38616560e+06  4.04700000e+01
#    8.31900000e+03  2.68586194e+10  3.26409023e+10]
#  [ 1.04100000e+02  8.90000000e-01  1.90000000e+00  1.49310000e+02
#    1.38110000e+02  4.55000000e+00  7.41782990e+06  4.32300000e+01
#    9.33800000e+03  2.20785725e+10  2.66353020e+10]
#  [ 1.10200000e+02  1.35000000e+00  1.90000000e+00  1.39660000e+02
#    1.39410000e+02  4.55000000e+00  7.44785830e+06  4.98700000e+01
#    1.26730000e+04  1.85607303e+10  2.91025891e+10]]

# %%
# np.random.seed(10)

# %% [markdown]
# ### 2.1 Normalizando a escala do dataset

# %%
## Criando um scaler para o campo de saída


scaler_in = MinMaxScaler(feature_range=(0, 1))
scaler_out = MinMaxScaler(feature_range=(0, 1))

serie_cluster2 = scaler_in.fit_transform(serie_cluster2)
validacao_cluster2 = scaler_out.fit_transform(validacao_cluster2)



# Criando um scaler específico para a 

arrecadacao = np.array(dataset_cluster2_series['arrecadacao'])

arrecadacao = arrecadacao.reshape(-1,1)

arrecadacao = scaler_out.fit_transform(arrecadacao)

# %%
print(serie_cluster2)
# Out:
# [[0.7061144  0.65895954 0.80784314 ... 0.01103925 0.02673628 0.03197893]
#  [0.68836292 0.57225434 0.80672269 ... 0.02989688 0.15412886 0.00290691]
#  [0.88362919 0.49132948 0.80056022 ... 0.05253383 0.14026205 0.        ]
#  ...
#  [0.65088757 0.71676301 0.         ... 0.10470402 1.         0.90291832]
#  [0.70808679 0.73410405 0.         ... 0.11793813 0.82194165 0.70121076]
#  [0.82840237 1.         0.         ... 0.16125094 0.69090084 0.78407849]]

# %%
print(validacao_cluster2)
# Out:
# [[0.79285714 0.34104046 1.         0.         0.702138   1.
#   0.63784617 1.         0.         0.72004669 1.        ]
#  [0.74761905 0.36416185 0.916      0.13739719 0.75315841 1.
#   0.84300896 0.78638847 0.04308956 0.34482605 0.4253135 ]
#  [0.6547619  0.26011561 0.82       0.49250121 0.85276968 1.
#   1.         0.23944362 0.08352126 0.47938637 0.30137957]
#  [0.         0.04046243 0.7        0.76947267 0.         0.72222222
#   0.54294829 0.         0.16084085 0.2948682  0.33655235]
#  [0.19047619 0.         0.444      1.         0.03061224 0.72222222
#   0.12031764 0.19076006 0.22720683 0.         0.03469063]
#  [0.52619048 0.3699422  0.272      0.7053701  0.34013605 0.72222222
#   0.07967371 0.41207154 0.32425902 0.02356418 0.        ]
#  [0.68095238 0.42774566 0.1        0.77672956 0.81146744 0.66666667
#   0.00371702 0.48360656 0.37258376 0.57253156 0.32314636]
#  [0.69761905 0.3583815  0.016      0.90251572 0.79543246 0.66666667
#   0.         0.51962245 0.5496134  0.62650328 0.41931319]
#  [0.87380952 0.58959538 0.         0.83889695 0.87220603 0.66666667
#   0.13632947 0.44088425 0.58537371 0.4464532  0.48651047]
#  [0.78571429 0.71676301 0.         0.96202225 1.         0.
#   0.27398    0.42548435 0.64932345 1.         0.87536207]
#  [0.8547619  0.73410405 0.         0.80188679 0.9212828  0.
#   0.50598621 0.49403875 0.73139497 0.77334398 0.61640062]
#  [1.         1.         0.         0.5684567  0.98445092 0.
#   0.72600608 0.65896672 1.         0.60653807 0.72279002]]

# %% [markdown]
# ### 2.2 Convertendo o array em um modelo de dados 3D para entrada na rede LSTM
#
# ---
# Créditos: https://machinelearningmastery.com/convert-time-series-supervised-learning-problem-python/
#
# Para fazer a predição, utilizei os 12 primeiros meses para predizer o seguinte. Com isso, o dataset perde 12 meses, uma vez que os 11 primeiros meses não possuem 12 meses anteriores e o último mês não possui valor conhecido da arrecadação do mês subsequente.
#
# ___

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
 
raw = DataFrame()
raw['ob1'] = [x for x in range(10)]
raw['ob2'] = [x for x in range(50, 60)]
# values = raw.values
values = pd.DataFrame(serie_cluster2).values
serie_cluster2_prepared = series_to_supervised(values,12)
print(serie_cluster2_prepared)
# Out:
#      var1(t-12)  var2(t-12)  var3(t-12)  var4(t-12)  var5(t-12)  var6(t-12)  \
# 12       70.61%      65.90%      80.78%      77.79%       0.00%     100.00%
# 13       68.84%      57.23%      80.67%      81.59%       1.61%     100.00%
# 14       88.36%      49.13%      80.06%      80.60%      25.01%     100.00%
# 15       78.11%      43.35%      78.77%      80.56%      16.38%      95.41%
# 16       80.28%      51.45%      77.70%      90.36%      13.90%      95.41%
# ..          ...         ...         ...         ...         ...         ...
# 199      58.58%      28.32%      22.41%      54.90%      80.67%      25.69%
# 200      66.07%      19.65%      21.34%      58.05%      74.09%      25.69%
# 201      67.65%      27.75%      19.50%      57.18%      82.57%      18.72%
# 202      61.54%      51.45%      16.81%      58.56%      75.16%      18.72%
# 203      63.91%      88.44%      15.07%      55.64%      72.67%      18.72%
#
#      var7(t-12)  var8(t-12)  var9(t-12)  var10(t-12)  var11(t-12)  var1(t-11)  \
# 12        0.00%       7.09%       1.10%        2.67%        3.20%      68.84%
# 13        0.20%       6.81%       2.99%       15.41%        0.29%      88.36%
# 14        0.52%       9.46%       5.25%       14.03%        0.00%      78.11%
# 15        0.80%       9.07%       6.78%       18.31%        7.10%      80.28%
# 16        1.14%      13.19%       7.43%        8.05%        4.70%      88.56%
# ..          ...         ...         ...          ...          ...         ...
# 199      96.08%      32.49%       7.14%       60.07%       68.37%      66.07%
# 200      96.87%      35.28%       7.81%       52.05%       60.08%      67.65%
# 201      97.54%      32.60%       8.34%       65.92%       82.82%      61.54%
# 202      98.07%      35.65%       9.02%       56.13%       62.55%      63.91%
# 203      98.64%      38.46%      11.01%       56.81%       70.54%      65.68%
#
#      var2(t-11)  var3(t-11)  var4(t-11)  var5(t-11)  var6(t-11)  var7(t-11)  \
# 12       57.23%      80.67%      81.59%       1.61%     100.00%       0.20%
# 13       49.13%      80.06%      80.60%      25.01%     100.00%       0.52%
# 14       43.35%      78.77%      80.56%      16.38%      95.41%       0.80%
# 15       51.45%      77.70%      90.36%      13.90%      95.41%       1.14%
# 16       63.01%      77.87%      91.18%      15.71%      95.41%       1.62%
# ..          ...         ...         ...         ...         ...         ...
# 199      19.65%      21.34%      58.05%      74.09%      25.69%      96.87%
# 200      27.75%      19.50%      57.18%      82.57%      18.72%      97.54%
# 201      51.45%      16.81%      58.56%      75.16%      18.72%      98.07%
# 202      88.44%      15.07%      55.64%      72.67%      18.72%      98.64%
# 203      34.10%      14.01%      56.91%      65.39%       9.91%      99.14%
#
#      var8(t-11)  var9(t-11)  var10(t-11)  var11(t-11)  var1(t-10)  var2(t-10)  \
# 12        6.81%       2.99%       15.41%        0.29%      88.36%      49.13%
# 13        9.46%       5.25%       14.03%        0.00%      78.11%      43.35%
# 14        9.07%       6.78%       18.31%        7.10%      80.28%      51.45%
# 15       13.19%       7.43%        8.05%        4.70%      88.56%      63.01%
# 16       10.72%       9.20%        7.69%        4.34%      84.22%      74.57%
# ..          ...         ...          ...          ...         ...         ...
# 199      35.28%       7.81%       52.05%       60.08%      67.65%      27.75%
# 200      32.60%       8.34%       65.92%       82.82%      61.54%      51.45%
# 201      35.65%       9.02%       56.13%       62.55%      63.91%      88.44%
# 202      38.46%      11.01%       56.81%       70.54%      65.68%      34.10%
# 203      36.42%       0.00%       78.01%      100.00%      61.93%      36.42%
#
#      var3(t-10)  var4(t-10)  var5(t-10)  var6(t-10)  var7(t-10)  var8(t-10)  \
# 12       80.06%      80.60%      25.01%     100.00%       0.52%       9.46%
# 13       78.77%      80.56%      16.38%      95.41%       0.80%       9.07%
# 14       77.70%      90.36%      13.90%      95.41%       1.14%      13.19%
# 15       77.87%      91.18%      15.71%      95.41%       1.62%      10.72%
# 16       77.70%      85.00%      24.06%      95.41%       2.06%      13.60%
# ..          ...         ...         ...         ...         ...         ...
# 199      19.50%      57.18%      82.57%      18.72%      97.54%      32.60%
# 200      16.81%      58.56%      75.16%      18.72%      98.07%      35.65%
# 201      15.07%      55.64%      72.67%      18.72%      98.64%      38.46%
# 202      14.01%      56.91%      65.39%       9.91%      99.14%      36.42%
# 203      12.83%      62.83%      67.35%       9.91%      99.63%      28.64%
#
#      var9(t-10)  var10(t-10)  var11(t-10)  var1(t-9)  var2(t-9)  var3(t-9)  \
# 12        5.25%       14.03%        0.00%     78.11%     43.35%     78.77%
# 13        6.78%       18.31%        7.10%     80.28%     51.45%     77.70%
# 14        7.43%        8.05%        4.70%     88.56%     63.01%     77.87%
# 15        9.20%        7.69%        4.34%     84.22%     74.57%     77.70%
# 16       10.38%        9.38%        9.04%     88.76%     61.85%     78.21%
# ..          ...          ...          ...        ...        ...        ...
# 199       8.34%       65.92%       82.82%     61.54%     51.45%     16.81%
# 200       9.02%       56.13%       62.55%     63.91%     88.44%     15.07%
# 201      11.01%       56.81%       70.54%     65.68%     34.10%     14.01%
# 202       0.00%       78.01%      100.00%     61.93%     36.42%     12.83%
# 203       0.69%       48.53%       55.24%     54.24%     26.01%     11.48%
#
#      var4(t-9)  var5(t-9)  var6(t-9)  var7(t-9)  var8(t-9)  var9(t-9)  \
# 12      80.56%     16.38%     95.41%      0.80%      9.07%      6.78%
# 13      90.36%     13.90%     95.41%      1.14%     13.19%      7.43%
# 14      91.18%     15.71%     95.41%      1.62%     10.72%      9.20%
# 15      85.00%     24.06%     95.41%      2.06%     13.60%     10.38%
# 16      82.41%     22.53%     95.41%      2.48%     17.81%     11.21%
# ..         ...        ...        ...        ...        ...        ...
# 199     58.56%     75.16%     18.72%     98.07%     35.65%      9.02%
# 200     55.64%     72.67%     18.72%     98.64%     38.46%     11.01%
# 201     56.91%     65.39%      9.91%     99.14%     36.42%      0.00%
# 202     62.83%     67.35%      9.91%     99.63%     28.64%      0.69%
# 203     78.13%     71.18%      9.91%    100.00%      8.72%      1.35%
#
#      var10(t-9)  var11(t-9)  var1(t-8)  var2(t-8)  var3(t-8)  var4(t-8)  \
# 12       18.31%       7.10%     80.28%     51.45%     77.70%     90.36%
# 13        8.05%       4.70%     88.56%     63.01%     77.87%     91.18%
# 14        7.69%       4.34%     84.22%     74.57%     77.70%     85.00%
# 15        9.38%       9.04%     88.76%     61.85%     78.21%     82.41%
# 16        7.03%       4.51%     77.71%     41.04%     79.50%     76.79%
# ..          ...         ...        ...        ...        ...        ...
# 199      56.13%      62.55%     63.91%     88.44%     15.07%     55.64%
# 200      56.81%      70.54%     65.68%     34.10%     14.01%     56.91%
# 201      78.01%     100.00%     61.93%     36.42%     12.83%     62.83%
# 202      48.53%      55.24%     54.24%     26.01%     11.48%     78.13%
# 203      59.10%      45.58%      0.00%      4.05%      9.80%     90.07%
#
#      var5(t-8)  var6(t-8)  var7(t-8)  var8(t-8)  var9(t-8)  var10(t-8)  \
# 12      13.90%     95.41%      1.14%     13.19%      7.43%       8.05%
# 13      15.71%     95.41%      1.62%     10.72%      9.20%       7.69%
# 14      24.06%     95.41%      2.06%     13.60%     10.38%       9.38%
# 15      22.53%     95.41%      2.48%     17.81%     11.21%       7.03%
# 16      19.84%     95.41%      2.76%     18.13%     12.08%       7.54%
# ..         ...        ...        ...        ...        ...         ...
# 199     72.67%     18.72%     98.64%     38.46%     11.01%      56.81%
# 200     65.39%      9.91%     99.14%     36.42%      0.00%      78.01%
# 201     67.35%      9.91%     99.63%     28.64%      0.69%      48.53%
# 202     71.18%      9.91%    100.00%      8.72%      1.35%      59.10%
# 203     38.40%      7.16%     98.92%      0.00%      2.59%      44.61%
#
#      var11(t-8)  var1(t-7)  var2(t-7)  var3(t-7)  var4(t-7)  var5(t-7)  \
# 12        4.70%     88.56%     63.01%     77.87%     91.18%     15.71%
# 13        4.34%     84.22%     74.57%     77.70%     85.00%     24.06%
# 14        9.04%     88.76%     61.85%     78.21%     82.41%     22.53%
# 15        4.51%     77.71%     41.04%     79.50%     76.79%     19.84%
# 16        6.55%     70.22%     47.40%     81.29%     75.04%     19.24%
# ..          ...        ...        ...        ...        ...        ...
# 199      70.54%     65.68%     34.10%     14.01%     56.91%     65.39%
# 200     100.00%     61.93%     36.42%     12.83%     62.83%     67.35%
# 201      55.24%     54.24%     26.01%     11.48%     78.13%     71.18%
# 202      45.58%      0.00%      4.05%      9.80%     90.07%     38.40%
# 203      48.32%     15.78%      0.00%      6.22%    100.00%     39.58%
#
#      var6(t-7)  var7(t-7)  var8(t-7)  var9(t-7)  var10(t-7)  var11(t-7)  \
# 12      95.41%      1.62%     10.72%      9.20%       7.69%       4.34%
# 13      95.41%      2.06%     13.60%     10.38%       9.38%       9.04%
# 14      95.41%      2.48%     17.81%     11.21%       7.03%       4.51%
# 15      95.41%      2.76%     18.13%     12.08%       7.54%       6.55%
# 16      95.41%      3.03%     23.96%     14.08%       9.26%      10.18%
# ..         ...        ...        ...        ...         ...         ...
# 199      9.91%     99.14%     36.42%      0.00%      78.01%     100.00%
# 200      9.91%     99.63%     28.64%      0.69%      48.53%      55.24%
# 201      9.91%    100.00%      8.72%      1.35%      59.10%      45.58%
# 202      7.16%     98.92%      0.00%      2.59%      44.61%      48.32%
# 203      7.16%     97.91%      6.95%      3.66%      21.44%      24.81%
#
#      var1(t-6)  var2(t-6)  var3(t-6)  var4(t-6)  var5(t-6)  var6(t-6)  \
# 12      84.22%     74.57%     77.70%     85.00%     24.06%     95.41%
# 13      88.76%     61.85%     78.21%     82.41%     22.53%     95.41%
# 14      77.71%     41.04%     79.50%     76.79%     19.84%     95.41%
# 15      70.22%     47.40%     81.29%     75.04%     19.24%     95.41%
# 16      79.68%     61.85%     84.37%     70.92%     20.55%     95.41%
# ..         ...        ...        ...        ...        ...        ...
# 199     61.93%     36.42%     12.83%     62.83%     67.35%      9.91%
# 200     54.24%     26.01%     11.48%     78.13%     71.18%      9.91%
# 201      0.00%      4.05%      9.80%     90.07%     38.40%      7.16%
# 202     15.78%      0.00%      6.22%    100.00%     39.58%      7.16%
# 203     43.59%     36.99%      3.81%     87.30%     51.48%      7.16%
#
#      var7(t-6)  var8(t-6)  var9(t-6)  var10(t-6)  var11(t-6)  var1(t-5)  \
# 12       2.06%     13.60%     10.38%       9.38%       9.04%     88.76%
# 13       2.48%     17.81%     11.21%       7.03%       4.51%     77.71%
# 14       2.76%     18.13%     12.08%       7.54%       6.55%     70.22%
# 15       3.03%     23.96%     14.08%       9.26%      10.18%     79.68%
# 16       3.44%     17.83%     16.34%       7.87%       3.65%     80.28%
# ..         ...        ...        ...         ...         ...        ...
# 199     99.63%     28.64%      0.69%      48.53%      55.24%     54.24%
# 200    100.00%      8.72%      1.35%      59.10%      45.58%      0.00%
# 201     98.92%      0.00%      2.59%      44.61%      48.32%     15.78%
# 202     97.91%      6.95%      3.66%      21.44%      24.81%     43.59%
# 203     97.82%     15.01%      5.23%      23.29%      22.11%     56.41%
#
#      var2(t-5)  var3(t-5)  var4(t-5)  var5(t-5)  var6(t-5)  var7(t-5)  \
# 12      61.85%     78.21%     82.41%     22.53%     95.41%      2.48%
# 13      41.04%     79.50%     76.79%     19.84%     95.41%      2.76%
# 14      47.40%     81.29%     75.04%     19.24%     95.41%      3.03%
# 15      61.85%     84.37%     70.92%     20.55%     95.41%      3.44%
# 16      71.68%     87.39%     66.02%     16.75%     95.41%      3.87%
# ..         ...        ...        ...        ...        ...        ...
# 199     26.01%     11.48%     78.13%     71.18%      9.91%    100.00%
# 200      4.05%      9.80%     90.07%     38.40%      7.16%     98.92%
# 201      0.00%      6.22%    100.00%     39.58%      7.16%     97.91%
# 202     36.99%      3.81%     87.30%     51.48%      7.16%     97.82%
# 203     42.77%      1.40%     90.38%     69.59%      6.61%     97.64%
#
#      var8(t-5)  var9(t-5)  var10(t-5)  var11(t-5)  var1(t-4)  var2(t-4)  \
# 12      17.81%     11.21%       7.03%       4.51%     77.71%     41.04%
# 13      18.13%     12.08%       7.54%       6.55%     70.22%     47.40%
# 14      23.96%     14.08%       9.26%      10.18%     79.68%     61.85%
# 15      17.83%     16.34%       7.87%       3.65%     80.28%     71.68%
# 16      14.75%     19.83%       9.30%       7.27%     73.37%     55.49%
# ..         ...        ...         ...         ...        ...        ...
# 199      8.72%      1.35%      59.10%      45.58%      0.00%      4.05%
# 200      0.00%      2.59%      44.61%      48.32%     15.78%      0.00%
# 201      6.95%      3.66%      21.44%      24.81%     43.59%     36.99%
# 202     15.01%      5.23%      23.29%      22.11%     56.41%     42.77%
# 203     17.62%      6.01%      66.42%      47.28%     57.79%     35.84%
#
#      var3(t-4)  var4(t-4)  var5(t-4)  var6(t-4)  var7(t-4)  var8(t-4)  \
# 12      79.50%     76.79%     19.84%     95.41%      2.76%     18.13%
# 13      81.29%     75.04%     19.24%     95.41%      3.03%     23.96%
# 14      84.37%     70.92%     20.55%     95.41%      3.44%     17.83%
# 15      87.39%     66.02%     16.75%     95.41%      3.87%     14.75%
# 16      89.80%     64.34%      9.21%     95.41%      4.20%     18.95%
# ..         ...        ...        ...        ...        ...        ...
# 199      9.80%     90.07%     38.40%      7.16%     98.92%      0.00%
# 200      6.22%    100.00%     39.58%      7.16%     97.91%      6.95%
# 201      3.81%     87.30%     51.48%      7.16%     97.82%     15.01%
# 202      1.40%     90.38%     69.59%      6.61%     97.64%     17.62%
# 203      0.22%     95.80%     68.98%      6.61%     97.63%     18.93%
#
#      var9(t-4)  var10(t-4)  var11(t-4)  var1(t-3)  var2(t-3)  var3(t-3)  \
# 12      12.08%       7.54%       6.55%     70.22%     47.40%     81.29%
# 13      14.08%       9.26%      10.18%     79.68%     61.85%     84.37%
# 14      16.34%       7.87%       3.65%     80.28%     71.68%     87.39%
# 15      19.83%       9.30%       7.27%     73.37%     55.49%     89.80%
# 16       2.38%      11.09%      11.47%     69.23%     56.07%     92.83%
# ..         ...         ...         ...        ...        ...        ...
# 199      2.59%      44.61%      48.32%     15.78%      0.00%      6.22%
# 200      3.66%      21.44%      24.81%     43.59%     36.99%      3.81%
# 201      5.23%      23.29%      22.11%     56.41%     42.77%      1.40%
# 202      6.01%      66.42%      47.28%     57.79%     35.84%      0.22%
# 203      8.86%      70.66%      54.77%     72.39%     58.96%      0.00%
#
#      var4(t-3)  var5(t-3)  var6(t-3)  var7(t-3)  var8(t-3)  var9(t-3)  \
# 12      75.04%     19.24%     95.41%      3.03%     23.96%     14.08%
# 13      70.92%     20.55%     95.41%      3.44%     17.83%     16.34%
# 14      66.02%     16.75%     95.41%      3.87%     14.75%     19.83%
# 15      64.34%      9.21%     95.41%      4.20%     18.95%      2.38%
# 16      59.79%     10.10%     95.41%      4.51%     20.10%      3.63%
# ..         ...        ...        ...        ...        ...        ...
# 199    100.00%     39.58%      7.16%     97.91%      6.95%      3.66%
# 200     87.30%     51.48%      7.16%     97.82%     15.01%      5.23%
# 201     90.38%     69.59%      6.61%     97.64%     17.62%      6.01%
# 202     95.80%     68.98%      6.61%     97.63%     18.93%      8.86%
# 203     93.06%     71.93%      6.61%     97.95%     16.06%      9.44%
#
#      var10(t-3)  var11(t-3)  var1(t-2)  var2(t-2)  var3(t-2)  var4(t-2)  \
# 12        9.26%      10.18%     79.68%     61.85%     84.37%     70.92%
# 13        7.87%       3.65%     80.28%     71.68%     87.39%     66.02%
# 14        9.30%       7.27%     73.37%     55.49%     89.80%     64.34%
# 15       11.09%      11.47%     69.23%     56.07%     92.83%     59.79%
# 16        6.97%       4.08%     64.69%     57.23%     95.63%     65.10%
# ..          ...         ...        ...        ...        ...        ...
# 199      21.44%      24.81%     43.59%     36.99%      3.81%     87.30%
# 200      23.29%      22.11%     56.41%     42.77%      1.40%     90.38%
# 201      66.42%      47.28%     57.79%     35.84%      0.22%     95.80%
# 202      70.66%      54.77%     72.39%     58.96%      0.00%     93.06%
# 203      56.51%      60.00%     65.09%     71.68%      0.00%     98.36%
#
#      var5(t-2)  var6(t-2)  var7(t-2)  var8(t-2)  var9(t-2)  var10(t-2)  \
# 12      20.55%     95.41%      3.44%     17.83%     16.34%       7.87%
# 13      16.75%     95.41%      3.87%     14.75%     19.83%       9.30%
# 14       9.21%     95.41%      4.20%     18.95%      2.38%      11.09%
# 15      10.10%     95.41%      4.51%     20.10%      3.63%       6.97%
# 16      31.43%     95.41%      4.82%     26.91%      5.90%       9.42%
# ..         ...        ...        ...        ...        ...         ...
# 199     51.48%      7.16%     97.82%     15.01%      5.23%      23.29%
# 200     69.59%      6.61%     97.64%     17.62%      6.01%      66.42%
# 201     68.98%      6.61%     97.63%     18.93%      8.86%      70.66%
# 202     71.93%      6.61%     97.95%     16.06%      9.44%      56.51%
# 203     76.84%      0.00%     98.28%     15.50%     10.47%     100.00%
#
#      var11(t-2)  var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  \
# 12        3.65%     80.28%     71.68%     87.39%     66.02%     16.75%
# 13        7.27%     73.37%     55.49%     89.80%     64.34%      9.21%
# 14       11.47%     69.23%     56.07%     92.83%     59.79%     10.10%
# 15        4.08%     64.69%     57.23%     95.63%     65.10%     31.43%
# 16        5.37%     73.37%     72.25%     97.59%     58.86%     25.70%
# ..          ...        ...        ...        ...        ...        ...
# 199      22.11%     56.41%     42.77%      1.40%     90.38%     69.59%
# 200      47.28%     57.79%     35.84%      0.22%     95.80%     68.98%
# 201      54.77%     72.39%     58.96%      0.00%     93.06%     71.93%
# 202      60.00%     65.09%     71.68%      0.00%     98.36%     76.84%
# 203      90.29%     70.81%     73.41%      0.00%     91.46%     73.81%
#
#      var6(t-1)  var7(t-1)  var8(t-1)  var9(t-1)  var10(t-1)  var11(t-1)  \
# 12      95.41%      3.87%     14.75%     19.83%       9.30%       7.27%
# 13      95.41%      4.20%     18.95%      2.38%      11.09%      11.47%
# 14      95.41%      4.51%     20.10%      3.63%       6.97%       4.08%
# 15      95.41%      4.82%     26.91%      5.90%       9.42%       5.37%
# 16      95.41%      5.18%     25.80%      7.41%      10.63%      12.94%
# ..         ...        ...        ...        ...         ...         ...
# 199      6.61%     97.64%     17.62%      6.01%      66.42%      47.28%
# 200      6.61%     97.63%     18.93%      8.86%      70.66%      54.77%
# 201      6.61%     97.95%     16.06%      9.44%      56.51%      60.00%
# 202      0.00%     98.28%     15.50%     10.47%     100.00%      90.29%
# 203      0.00%     98.83%     18.00%     11.79%      82.19%      70.12%
#
#      var1(t)  var2(t)  var3(t)  var4(t)  var5(t)  var6(t)  var7(t)  var8(t)  \
# 12    73.37%   55.49%   89.80%   64.34%    9.21%   95.41%    4.20%   18.95%
# 13    69.23%   56.07%   92.83%   59.79%   10.10%   95.41%    4.51%   20.10%
# 14    64.69%   57.23%   95.63%   65.10%   31.43%   95.41%    4.82%   26.91%
# 15    73.37%   72.25%   97.59%   58.86%   25.70%   95.41%    5.18%   25.80%
# 16    72.39%   50.29%   99.22%   52.15%   22.92%   95.41%    5.49%   22.92%
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 199   57.79%   35.84%    0.22%   95.80%   68.98%    6.61%   97.63%   18.93%
# 200   72.39%   58.96%    0.00%   93.06%   71.93%    6.61%   97.95%   16.06%
# 201   65.09%   71.68%    0.00%   98.36%   76.84%    0.00%   98.28%   15.50%
# 202   70.81%   73.41%    0.00%   91.46%   73.81%    0.00%   98.83%   18.00%
# 203   82.84%  100.00%    0.00%   81.41%   76.24%    0.00%   99.35%   24.00%
#
#      var9(t)  var10(t)  var11(t)
# 12     2.38%    11.09%    11.47%
# 13     3.63%     6.97%     4.08%
# 14     5.90%     9.42%     5.37%
# 15     7.41%    10.63%    12.94%
# 16     9.23%     8.35%     6.93%
# ..       ...       ...       ...
# 199    8.86%    70.66%    54.77%
# 200    9.44%    56.51%    60.00%
# 201   10.47%   100.00%    90.29%
# 202   11.79%    82.19%    70.12%
# 203   16.13%    69.09%    78.41%
#
# [192 rows x 143 columns]

# %% [markdown]
# ### 2.3 Dividindo o dataset em sets de treino e teste

# %%
# split into train and test sets
values = serie_cluster2_prepared.values
# Base de treino com 156 meses
periodo_treino = 156
train = values[:periodo_treino, :]
test = values[periodo_treino:, :]

# %%
print(train)
# Out:
# [[0.7061144  0.65895954 0.80784314 ... 0.02379283 0.11094089 0.11466373]
#  [0.68836292 0.57225434 0.80672269 ... 0.03628666 0.06967225 0.04075126]
#  [0.88362919 0.49132948 0.80056022 ... 0.05896257 0.09418763 0.05368928]
#  ...
#  [0.48717949 0.3699422  0.68067227 ... 0.14667913 0.61834442 0.58019928]
#  [0.5877712  0.32369942 0.67226891 ... 0.16090028 0.56197453 0.56641402]
#  [0.60552268 0.39306358 0.65826331 ... 0.18321255 0.55778298 0.48455317]]

# %%
print(test)
# Out:
# [[0.63510848 0.43930636 0.63137255 ... 0.00185719 0.71476178 0.77061351]
#  [0.60749507 0.41040462 0.61176471 ... 0.00825995 0.48883814 0.38647218]
#  [0.64891519 0.36416185 0.57422969 ... 0.01832515 0.59498875 0.46623835]
#  ...
#  [0.6765286  0.27745665 0.19495798 ... 0.10470402 1.         0.90291832]
#  [0.61538462 0.51445087 0.16806723 ... 0.11793813 0.82194165 0.70121076]
#  [0.63905325 0.88439306 0.15070028 ... 0.16125094 0.69090084 0.78407849]]

# %%
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (156, 1, 142) (156,) (36, 1, 142) (36,)

# %% [markdown]
# ## 3. Implementando o modelo LSTM

# %%
#Função para calculo do MAPE - Mean Absolute Percentage Error, que será  utilizado como medida de erro do modelo

def calculo_mape(y_pred,y_true):

    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
train_X.shape
# Out:
# (156, 1, 142)

# %%
initializer = tf.keras.initializers.GlorotNormal(seed=11)

model = Sequential()

model.add(LSTM(142, return_sequences = True, kernel_initializer=initializer, use_bias=True, 
               input_shape=(train_X.shape[1], train_X.shape[2])))
# O método Dropout é utilizado para reduzir o overfitting

model.add(Dropout(0.2))

model.add(LSTM(284, return_sequences = True, kernel_initializer=initializer))
model.add(Dropout(0.2))

model.add(LSTM(284, return_sequences = True, kernel_initializer=initializer))
model.add(Dropout(0.2))

model.add(LSTM(284, return_sequences = True, kernel_initializer=initializer))
model.add(Dropout(0.2))

model.add(LSTM(284, return_sequences = True, kernel_initializer=initializer))
model.add(Dropout(0.2))

model.add(LSTM(284, return_sequences = True, kernel_initializer=initializer))
model.add(Dropout(0.2))

model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='Adam')
# fit network
history = model.fit(train_X, train_y, epochs=185, batch_size=64, 
                    validation_data=(test_X, test_y),  verbose=1, shuffle=False)
# Out:
# Epoch 1/185
# 3/3 [==============================] - 6s 596ms/step - loss: 0.0905 - val_loss: 0.4086
# Epoch 2/185
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0777 - val_loss: 0.3716
# Epoch 3/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0611 - val_loss: 0.3159
# Epoch 4/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0377 - val_loss: 0.2135
# Epoch 5/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0126 - val_loss: 0.0663
# Epoch 6/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0369 - val_loss: 0.1083
# Epoch 7/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0224 - val_loss: 0.1589
# Epoch 8/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0185 - val_loss: 0.1766
# Epoch 9/185
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0178 - val_loss: 0.1735
# Epoch 10/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0164 - val_loss: 0.1584
# Epoch 11/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0152 - val_loss: 0.1369
# Epoch 12/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0154 - val_loss: 0.1162
# Epoch 13/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0164 - val_loss: 0.1032
# Epoch 14/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0168 - val_loss: 0.1006
# Epoch 15/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0151 - val_loss: 0.1036
# Epoch 16/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0133 - val_loss: 0.1031
# Epoch 17/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0110 - val_loss: 0.0903
# Epoch 18/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0086 - val_loss: 0.0672
# Epoch 19/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0070 - val_loss: 0.0548
# Epoch 20/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0061 - val_loss: 0.0545
# Epoch 21/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0068 - val_loss: 0.0493
# Epoch 22/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0066 - val_loss: 0.0484
# Epoch 23/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0061 - val_loss: 0.0556
# Epoch 24/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0056 - val_loss: 0.0575
# Epoch 25/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0053 - val_loss: 0.0528
# Epoch 26/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0055 - val_loss: 0.0523
# Epoch 27/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0056 - val_loss: 0.0509
# Epoch 28/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0053 - val_loss: 0.0469
# Epoch 29/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0053 - val_loss: 0.0407
# Epoch 30/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0046 - val_loss: 0.0382
# Epoch 31/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0046 - val_loss: 0.0378
# Epoch 32/185
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0048 - val_loss: 0.0354
# Epoch 33/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0041 - val_loss: 0.0321
# Epoch 34/185
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0042 - val_loss: 0.0326
# Epoch 35/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0042 - val_loss: 0.0310
# Epoch 36/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0040 - val_loss: 0.0271
# Epoch 37/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0034 - val_loss: 0.0271
# Epoch 38/185
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0037 - val_loss: 0.0251
# Epoch 39/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0038 - val_loss: 0.0273
# Epoch 40/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0045 - val_loss: 0.0228
# Epoch 41/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0051 - val_loss: 0.0318
# Epoch 42/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0057 - val_loss: 0.0418
# Epoch 43/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0035 - val_loss: 0.0213
# Epoch 44/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0047 - val_loss: 0.0298
# Epoch 45/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0046 - val_loss: 0.0376
# Epoch 46/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0033 - val_loss: 0.0208
# Epoch 47/185
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0043 - val_loss: 0.0291
# Epoch 48/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0057 - val_loss: 0.0462
# Epoch 49/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0033 - val_loss: 0.0221
# Epoch 50/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0053 - val_loss: 0.0272
# Epoch 51/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0046 - val_loss: 0.0551
# Epoch 52/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0043 - val_loss: 0.0344
# Epoch 53/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0034 - val_loss: 0.0220
# Epoch 54/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0034 - val_loss: 0.0284
# Epoch 55/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0031 - val_loss: 0.0318
# Epoch 56/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0025 - val_loss: 0.0228
# Epoch 57/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0029 - val_loss: 0.0232
# Epoch 58/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0027 - val_loss: 0.0274
# Epoch 59/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0025 - val_loss: 0.0229
# Epoch 60/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0022 - val_loss: 0.0210
# Epoch 61/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0025 - val_loss: 0.0221
# Epoch 62/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0022 - val_loss: 0.0215
# Epoch 63/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0023 - val_loss: 0.0201
# Epoch 64/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0021 - val_loss: 0.0204
# Epoch 65/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0019 - val_loss: 0.0202
# Epoch 66/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0024 - val_loss: 0.0205
# Epoch 67/185
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0020 - val_loss: 0.0212
# Epoch 68/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0020 - val_loss: 0.0193
# Epoch 69/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0019 - val_loss: 0.0208
# Epoch 70/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0021 - val_loss: 0.0196
# Epoch 71/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0020 - val_loss: 0.0188
# Epoch 72/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0019 - val_loss: 0.0198
# Epoch 73/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0019 - val_loss: 0.0186
# Epoch 74/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0021 - val_loss: 0.0211
# Epoch 75/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0023 - val_loss: 0.0194
# Epoch 76/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0028 - val_loss: 0.0223
# Epoch 77/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0030 - val_loss: 0.0300
# Epoch 78/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0020 - val_loss: 0.0193
# Epoch 79/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0024 - val_loss: 0.0245
# Epoch 80/185
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0024 - val_loss: 0.0241
# Epoch 81/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0020 - val_loss: 0.0188
# Epoch 82/185
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0018 - val_loss: 0.0225
# Epoch 83/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0019 - val_loss: 0.0221
# Epoch 84/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0016 - val_loss: 0.0198
# Epoch 85/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 0.0207
# Epoch 86/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 0.0203
# Epoch 87/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0017 - val_loss: 0.0199
# Epoch 88/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 0.0200
# Epoch 89/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0014 - val_loss: 0.0206
# Epoch 90/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 0.0180
# Epoch 91/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0016 - val_loss: 0.0195
# Epoch 92/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0017 - val_loss: 0.0191
# Epoch 93/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0183
# Epoch 94/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 0.0183
# Epoch 95/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0013 - val_loss: 0.0196
# Epoch 96/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0018 - val_loss: 0.0186
# Epoch 97/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0017 - val_loss: 0.0206
# Epoch 98/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0018 - val_loss: 0.0207
# Epoch 99/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0017 - val_loss: 0.0184
# Epoch 100/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0017 - val_loss: 0.0205
# Epoch 101/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 0.0169
# Epoch 102/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0017 - val_loss: 0.0200
# Epoch 103/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 0.0201
# Epoch 104/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0017 - val_loss: 0.0199
# Epoch 105/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0015 - val_loss: 0.0199
# Epoch 106/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0175
# Epoch 107/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 0.0187
# Epoch 108/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0016 - val_loss: 0.0178
# Epoch 109/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 0.0211
# Epoch 110/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0016 - val_loss: 0.0176
# Epoch 111/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0019 - val_loss: 0.0208
# Epoch 112/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0023 - val_loss: 0.0205
# Epoch 113/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0018 - val_loss: 0.0181
# Epoch 114/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 0.0229
# Epoch 115/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0015 - val_loss: 0.0177
# Epoch 116/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0017 - val_loss: 0.0184
# Epoch 117/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0016 - val_loss: 0.0180
# Epoch 118/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0016 - val_loss: 0.0189
# Epoch 119/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0017 - val_loss: 0.0206
# Epoch 120/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0017 - val_loss: 0.0181
# Epoch 121/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0184
# Epoch 122/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 0.0174
# Epoch 123/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0011 - val_loss: 0.0193
# Epoch 124/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0013 - val_loss: 0.0185
# Epoch 125/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0014 - val_loss: 0.0179
# Epoch 126/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0013 - val_loss: 0.0181
# Epoch 127/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0012 - val_loss: 0.0182
# Epoch 128/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0185
# Epoch 129/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0175
# Epoch 130/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0179
# Epoch 131/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0015 - val_loss: 0.0170
# Epoch 132/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0015 - val_loss: 0.0198
# Epoch 133/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0019 - val_loss: 0.0186
# Epoch 134/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0018 - val_loss: 0.0186
# Epoch 135/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0013 - val_loss: 0.0200
# Epoch 136/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0012 - val_loss: 0.0174
# Epoch 137/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0182
# Epoch 138/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0011 - val_loss: 0.0179
# Epoch 139/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0192
# Epoch 140/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0174
# Epoch 141/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0174
# Epoch 142/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0169
# Epoch 143/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0011 - val_loss: 0.0180
# Epoch 144/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0016 - val_loss: 0.0167
# Epoch 145/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0018 - val_loss: 0.0174
# Epoch 146/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0174
# Epoch 147/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0014 - val_loss: 0.0174
# Epoch 148/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 0.0176
# Epoch 149/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0172
# Epoch 150/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0177
# Epoch 151/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0010 - val_loss: 0.0168
# Epoch 152/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0171
# Epoch 153/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0012 - val_loss: 0.0165
# Epoch 154/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0011 - val_loss: 0.0163
# Epoch 155/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0165
# Epoch 156/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0010 - val_loss: 0.0162
# Epoch 157/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0011 - val_loss: 0.0173
# Epoch 158/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0171
# Epoch 159/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0012 - val_loss: 0.0179
# Epoch 160/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0014 - val_loss: 0.0168
# Epoch 161/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 0.0179
# Epoch 162/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0015 - val_loss: 0.0193
# Epoch 163/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0016 - val_loss: 0.0175
# Epoch 164/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0164
# Epoch 165/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 0.0167
# Epoch 166/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0015 - val_loss: 0.0175
# Epoch 167/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0015 - val_loss: 0.0195
# Epoch 168/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0019 - val_loss: 0.0164
# Epoch 169/185
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0021 - val_loss: 0.0170
# Epoch 170/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0015 - val_loss: 0.0201
# Epoch 171/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0167
# Epoch 172/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0012 - val_loss: 0.0169
# Epoch 173/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 0.0162
# Epoch 174/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0013 - val_loss: 0.0173
# Epoch 175/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0012 - val_loss: 0.0188
# Epoch 176/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0010 - val_loss: 0.0159
# Epoch 177/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0011 - val_loss: 0.0162
# Epoch 178/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0158
# Epoch 179/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0011 - val_loss: 0.0162
# Epoch 180/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0010 - val_loss: 0.0165
# Epoch 181/185
# 3/3 [==============================] - 0s 20ms/step - loss: 9.8524e-04 - val_loss: 0.0159
# Epoch 182/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0012 - val_loss: 0.0162
# Epoch 183/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0022 - val_loss: 0.0160
# Epoch 184/185
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0022 - val_loss: 0.0173
# Epoch 185/185
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0017 - val_loss: 0.0175

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()

# %%
plot_model(model, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 1, 142)            161880
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 1, 142)            0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 1, 284)            485072
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 1, 284)            0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 1, 284)            646384
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 1, 284)            0
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 1, 284)            646384
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 1, 284)            0
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 1, 284)            646384
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 1, 284)            0
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 1, 284)            646384
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 1, 284)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1, 1)              285
# =================================================================
# Total params: 3,232,773
# Trainable params: 3,232,773
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 4. Fazendo a Previsão para 2018 a 2020

# %%
# make a prediction


yhat = model.predict(test_X)
test_X_final = test_X.reshape(test_X.shape[0], test_X.shape[2])
# invert scaling for forecast



inv_yhat = np.concatenate((np.squeeze(yhat, axis=(2,)), test_X_final[:, :-1]), axis=1)

# inv_yhat = scaler_in.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

# invert scaling for actual

test_y_final = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y_final, test_X_final[:, 1:]), axis=1)
# inv_y = scaler_in.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))

mape = calculo_mape(inv_yhat, inv_y)
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.132

# %%
test_y_inv = scaler_out.inverse_transform(test_y_final)
yhat_final_inv = scaler_out.inverse_transform(np.squeeze(yhat, axis=(2,)))


df_data = pd.date_range('2018-01','2021-01', freq = 'm')

# Plota o valor observado vs previsto. 

plt.figure(figsize=(10,10))
plt.plot(test_y_inv, label='Esperado')
plt.plot(yhat_final_inv, label='Previsto LSTM')
plt.legend()
plt.title('Teste LSTM - MAPE: %.4f' % mape)
plt.xticks(np.arange(len(test_y_inv)),df_data.strftime('%m/%Y'), rotation='vertical')
plt.grid(True,axis='y')
plt.show()

# %%
## Formatação das tabelas

pd.set_option('max_columns', None)
pd.options.display.float_format = '{:,.2%}'.format

# %%
variacao_percentual = pd.DataFrame(((yhat_final_inv/test_y_inv)-1) ,columns=['variacao'])

# %%
set_alerta_negativo = pd.DataFrame()
set_normal= pd.DataFrame()
set_alerta_positivo = pd.DataFrame()

# %%
for i in range (len(variacao_percentual)):
    if variacao_percentual.iloc[i].values[0] > 0.05:
        set_alerta_negativo = set_alerta_negativo.append(variacao_percentual[i:i+1])
    elif variacao_percentual.iloc[i].values[0] < -0.05:
        set_alerta_positivo = set_alerta_positivo.append(variacao_percentual[i:i+1])
    else:
        set_normal = set_normal.append(variacao_percentual[i:i+1])

# %%
df_data = pd.date_range('2018-01','2021-01', freq = 'm')

#Plota o resultado do modelo
fig, ax = plt.subplots(figsize=(12,6))
ax.set_ylabel('Variação %')

plt.plot(variacao_percentual * 100, 'o', color='white')
plt.plot(set_alerta_negativo * 100, 'o', color='red',  label='Arrecadaçao < Previsão Crítico')
plt.plot(set_normal * 100, 'o', color='green',  label='Períodos Normais')
plt.plot(set_alerta_positivo * 100, 'o', color='blue',  label='Arrecadação > Previsão Crítico')
plt.title('Variação entre valores previstos e observados - LSTM' )
plt.grid(True,axis='y')
ax.set_xticks(range(0,36))
plt.xticks(ax.get_xticks(), df_data.strftime('%m/%Y'), rotation='vertical')
plt.legend(loc='upper left')
