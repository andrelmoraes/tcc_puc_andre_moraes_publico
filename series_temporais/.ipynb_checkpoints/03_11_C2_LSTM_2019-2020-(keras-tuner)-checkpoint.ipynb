# %% [markdown]
# # Modelo LSTM para predição
#
# ---
#
#
# ___

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import math
import requests
import json
import os
import statsmodels.api as sm
import tensorflow as tf
from pandas import concat

from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore")

from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)

import math

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
import keras_tuner as kt
from tensorflow.keras.utils import plot_model
from tensorflow.keras import initializers
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## 1. Importando os datasets

# %%
dataset_cluster2_series = pd.read_csv("datasets//dataset_cluster2_series.csv", header=0, index_col=0)
dataset_cluster2_validacao = pd.read_csv("datasets//dataset_cluster2_validation.csv", header=0, index_col=0)

dataset_cluster2_series = dataset_cluster2_series.append(dataset_cluster2_validacao)

# %%
dataset_cluster2_series.tail(20)
# Out:
#                      indice_pimpf  ipca  taxa_selic  taxa_cambio   ibcbr  \
# mes
# 2019-05-01 00:00:00         111.7  0.13        6.40       113.78  139.25
# 2019-06-01 00:00:00          95.5  0.01        6.40       109.82  135.00
# 2019-07-01 00:00:00          98.4  0.19        6.40       107.51  142.94
# 2019-08-01 00:00:00          97.9  0.11        5.90       114.23  141.78
# 2019-09-01 00:00:00         101.7 -0.04        5.71       117.25  138.26
# 2019-10-01 00:00:00         102.5  0.10        5.38       116.42  142.80
# 2019-11-01 00:00:00          99.4  0.51        4.90       117.74  138.83
# 2019-12-01 00:00:00         100.6  1.15        4.59       114.94  137.50
# 2020-01-01 00:00:00         101.5  0.21        4.40       116.16  133.60
# 2020-02-01 00:00:00          99.6  0.25        4.19       121.84  134.65
# 2020-03-01 00:00:00          95.7  0.07        3.95       136.52  136.70
# 2020-04-01 00:00:00          68.2 -0.31        3.65       147.97  119.15
# 2020-05-01 00:00:00          76.2 -0.38        3.01       157.50  119.78
# 2020-06-01 00:00:00          90.3  0.26        2.58       145.32  126.15
# 2020-07-01 00:00:00          96.8  0.36        2.15       148.27  135.85
# 2020-08-01 00:00:00          97.5  0.24        1.94       153.47  135.52
# 2020-09-01 00:00:00         104.9  0.64        1.90       150.84  137.10
# 2020-10-01 00:00:00         101.2  0.86        1.90       155.93  139.73
# 2020-11-01 00:00:00         104.1  0.89        1.90       149.31  138.11
# 2020-12-01 00:00:00         110.2  1.35        1.90       139.66  139.41
#
#                      tjlp  pib_mensal  preco_brent  desembolso       debitos  \
# mes
# 2019-05-01 00:00:00  6.26   7176451.3        70.53      3746.0  1.296587e+10
# 2019-06-01 00:00:00  6.26   7189820.6        63.30      4755.0  1.354678e+10
# 2019-07-01 00:00:00  5.95   7231391.3        64.00      5264.0  2.005273e+10
# 2019-08-01 00:00:00  5.95   7259724.1        59.25      5751.0  1.614003e+10
# 2019-09-01 00:00:00  5.95   7305486.4        62.33      6270.0  1.398523e+10
# 2019-10-01 00:00:00  5.57   7343681.6        59.37      6678.0  1.771015e+10
# 2019-11-01 00:00:00  5.57   7374387.3        62.74      7202.0  1.508082e+10
# 2019-12-01 00:00:00  5.57   7407023.6        65.85      8737.0  1.526310e+10
# 2020-01-01 00:00:00  5.09   7435826.2        63.60       257.0  2.095456e+10
# 2020-02-01 00:00:00  5.09   7463826.9        55.00       792.0  1.304137e+10
# 2020-03-01 00:00:00  5.09   7485253.1        32.98      1294.0  1.587917e+10
# 2020-04-01 00:00:00  4.94   7422874.5        23.34      2254.0  1.198779e+10
# 2020-05-01 00:00:00  4.94   7365193.7        31.02      3078.0  5.769186e+09
# 2020-06-01 00:00:00  4.94   7359646.6        39.93      4283.0  6.266141e+09
# 2020-07-01 00:00:00  4.91   7349280.0        42.81      4883.0  1.784355e+10
# 2020-08-01 00:00:00  4.91   7348772.7        44.26      7081.0  1.898179e+10
# 2020-09-01 00:00:00  4.91   7367379.0        41.09      7525.0  1.518463e+10
# 2020-10-01 00:00:00  4.55   7386165.6        40.47      8319.0  2.685862e+10
# 2020-11-01 00:00:00  4.55   7417829.9        43.23      9338.0  2.207857e+10
# 2020-12-01 00:00:00  4.55   7447858.3        49.87     12673.0  1.856073e+10
#
#                       arrecadacao
# mes
# 2019-05-01 00:00:00  2.321507e+10
# 2019-06-01 00:00:00  2.417660e+10
# 2019-07-01 00:00:00  3.327620e+10
# 2019-08-01 00:00:00  2.611246e+10
# 2019-09-01 00:00:00  2.364670e+10
# 2019-10-01 00:00:00  3.041535e+10
# 2019-11-01 00:00:00  2.438107e+10
# 2019-12-01 00:00:00  2.676134e+10
# 2020-01-01 00:00:00  3.553139e+10
# 2020-02-01 00:00:00  2.220378e+10
# 2020-03-01 00:00:00  1.932962e+10
# 2020-04-01 00:00:00  2.014531e+10
# 2020-05-01 00:00:00  1.314481e+10
# 2020-06-01 00:00:00  1.234030e+10
# 2020-07-01 00:00:00  1.983441e+10
# 2020-08-01 00:00:00  2.206463e+10
# 2020-09-01 00:00:00  2.362301e+10
# 2020-10-01 00:00:00  3.264090e+10
# 2020-11-01 00:00:00  2.663530e+10
# 2020-12-01 00:00:00  2.910259e+10

# %%
dataset_cluster2_validacao.head(20)
# Out:
#                      indice_pimpf  ipca  taxa_selic  taxa_cambio   ibcbr  \
# mes
# 2020-01-01 00:00:00         101.5  0.21        4.40       116.16  133.60
# 2020-02-01 00:00:00          99.6  0.25        4.19       121.84  134.65
# 2020-03-01 00:00:00          95.7  0.07        3.95       136.52  136.70
# 2020-04-01 00:00:00          68.2 -0.31        3.65       147.97  119.15
# 2020-05-01 00:00:00          76.2 -0.38        3.01       157.50  119.78
# 2020-06-01 00:00:00          90.3  0.26        2.58       145.32  126.15
# 2020-07-01 00:00:00          96.8  0.36        2.15       148.27  135.85
# 2020-08-01 00:00:00          97.5  0.24        1.94       153.47  135.52
# 2020-09-01 00:00:00         104.9  0.64        1.90       150.84  137.10
# 2020-10-01 00:00:00         101.2  0.86        1.90       155.93  139.73
# 2020-11-01 00:00:00         104.1  0.89        1.90       149.31  138.11
# 2020-12-01 00:00:00         110.2  1.35        1.90       139.66  139.41
#
#                      tjlp  pib_mensal  preco_brent  desembolso       debitos  \
# mes
# 2020-01-01 00:00:00  5.09   7435826.2        63.60       257.0  2.095456e+10
# 2020-02-01 00:00:00  5.09   7463826.9        55.00       792.0  1.304137e+10
# 2020-03-01 00:00:00  5.09   7485253.1        32.98      1294.0  1.587917e+10
# 2020-04-01 00:00:00  4.94   7422874.5        23.34      2254.0  1.198779e+10
# 2020-05-01 00:00:00  4.94   7365193.7        31.02      3078.0  5.769186e+09
# 2020-06-01 00:00:00  4.94   7359646.6        39.93      4283.0  6.266141e+09
# 2020-07-01 00:00:00  4.91   7349280.0        42.81      4883.0  1.784355e+10
# 2020-08-01 00:00:00  4.91   7348772.7        44.26      7081.0  1.898179e+10
# 2020-09-01 00:00:00  4.91   7367379.0        41.09      7525.0  1.518463e+10
# 2020-10-01 00:00:00  4.55   7386165.6        40.47      8319.0  2.685862e+10
# 2020-11-01 00:00:00  4.55   7417829.9        43.23      9338.0  2.207857e+10
# 2020-12-01 00:00:00  4.55   7447858.3        49.87     12673.0  1.856073e+10
#
#                       arrecadacao
# mes
# 2020-01-01 00:00:00  3.553139e+10
# 2020-02-01 00:00:00  2.220378e+10
# 2020-03-01 00:00:00  1.932962e+10
# 2020-04-01 00:00:00  2.014531e+10
# 2020-05-01 00:00:00  1.314481e+10
# 2020-06-01 00:00:00  1.234030e+10
# 2020-07-01 00:00:00  1.983441e+10
# 2020-08-01 00:00:00  2.206463e+10
# 2020-09-01 00:00:00  2.362301e+10
# 2020-10-01 00:00:00  3.264090e+10
# 2020-11-01 00:00:00  2.663530e+10
# 2020-12-01 00:00:00  2.910259e+10

# %% [markdown]
# ## 2. Preparando o dataset para a rede neural LSTM

# %%
np.random.seed(10)

# %%
serie_cluster2 = np.array(dataset_cluster2_series)

# %%
print(serie_cluster2)
# Out:
# [[1.04000000e+02 7.60000000e-01 1.63200000e+01 ... 1.10700000e+03
#   7.30970152e+08 6.70972820e+09]
#  [1.03100000e+02 6.10000000e-01 1.63000000e+01 ... 2.55900000e+03
#   4.15087444e+09 5.84414384e+09]
#  [1.13000000e+02 4.70000000e-01 1.61900000e+01 ... 4.30200000e+03
#   3.77861435e+09 5.75759405e+09]
#  ...
#  [1.01200000e+02 8.60000000e-01 1.90000000e+00 ... 8.31900000e+03
#   2.68586194e+10 3.26409023e+10]
#  [1.04100000e+02 8.90000000e-01 1.90000000e+00 ... 9.33800000e+03
#   2.20785725e+10 2.66353020e+10]
#  [1.10200000e+02 1.35000000e+00 1.90000000e+00 ... 1.26730000e+04
#   1.85607303e+10 2.91025891e+10]]

# %%
validacao_cluster2 = np.array(dataset_cluster2_validacao)

# %%
print(validacao_cluster2)
# Out:
# [[ 1.01500000e+02  2.10000000e-01  4.40000000e+00  1.16160000e+02
#    1.33600000e+02  5.09000000e+00  7.43582620e+06  6.36000000e+01
#    2.57000000e+02  2.09545628e+10  3.55313926e+10]
#  [ 9.96000000e+01  2.50000000e-01  4.19000000e+00  1.21840000e+02
#    1.34650000e+02  5.09000000e+00  7.46382690e+06  5.50000000e+01
#    7.92000000e+02  1.30413722e+10  2.22037820e+10]
#  [ 9.57000000e+01  7.00000000e-02  3.95000000e+00  1.36520000e+02
#    1.36700000e+02  5.09000000e+00  7.48525310e+06  3.29800000e+01
#    1.29400000e+03  1.58791730e+10  1.93296182e+10]
#  [ 6.82000000e+01 -3.10000000e-01  3.65000000e+00  1.47970000e+02
#    1.19150000e+02  4.94000000e+00  7.42287450e+06  2.33400000e+01
#    2.25400000e+03  1.19877895e+10  2.01453135e+10]
#  [ 7.62000000e+01 -3.80000000e-01  3.01000000e+00  1.57500000e+02
#    1.19780000e+02  4.94000000e+00  7.36519370e+06  3.10200000e+01
#    3.07800000e+03  5.76918631e+09  1.31448091e+10]
#  [ 9.03000000e+01  2.60000000e-01  2.58000000e+00  1.45320000e+02
#    1.26150000e+02  4.94000000e+00  7.35964660e+06  3.99300000e+01
#    4.28300000e+03  6.26614141e+09  1.23402953e+10]
#  [ 9.68000000e+01  3.60000000e-01  2.15000000e+00  1.48270000e+02
#    1.35850000e+02  4.91000000e+00  7.34928000e+06  4.28100000e+01
#    4.88300000e+03  1.78435524e+10  1.98344139e+10]
#  [ 9.75000000e+01  2.40000000e-01  1.94000000e+00  1.53470000e+02
#    1.35520000e+02  4.91000000e+00  7.34877270e+06  4.42600000e+01
#    7.08100000e+03  1.89817853e+10  2.20646283e+10]
#  [ 1.04900000e+02  6.40000000e-01  1.90000000e+00  1.50840000e+02
#    1.37100000e+02  4.91000000e+00  7.36737900e+06  4.10900000e+01
#    7.52500000e+03  1.51846312e+10  2.36230069e+10]
#  [ 1.01200000e+02  8.60000000e-01  1.90000000e+00  1.55930000e+02
#    1.39730000e+02  4.55000000e+00  7.38616560e+06  4.04700000e+01
#    8.31900000e+03  2.68586194e+10  3.26409023e+10]
#  [ 1.04100000e+02  8.90000000e-01  1.90000000e+00  1.49310000e+02
#    1.38110000e+02  4.55000000e+00  7.41782990e+06  4.32300000e+01
#    9.33800000e+03  2.20785725e+10  2.66353020e+10]
#  [ 1.10200000e+02  1.35000000e+00  1.90000000e+00  1.39660000e+02
#    1.39410000e+02  4.55000000e+00  7.44785830e+06  4.98700000e+01
#    1.26730000e+04  1.85607303e+10  2.91025891e+10]]

# %%
# np.random.seed(10)

# %% [markdown]
# ### 2.1 Normalizando a escala do dataset

# %%
## Criando um scaler para o campo de saída


scaler_in = MinMaxScaler(feature_range=(0, 1))
scaler_out = MinMaxScaler(feature_range=(0, 1))

serie_cluster2 = scaler_in.fit_transform(serie_cluster2)
validacao_cluster2 = scaler_out.fit_transform(validacao_cluster2)



# Criando um scaler específico para a 

arrecadacao = np.array(dataset_cluster2_series['arrecadacao'])

arrecadacao = arrecadacao.reshape(-1,1)

arrecadacao = scaler_out.fit_transform(arrecadacao)

# %%
print(serie_cluster2)
# Out:
# [[0.7061144  0.65895954 0.80784314 ... 0.01103925 0.02673628 0.03197893]
#  [0.68836292 0.57225434 0.80672269 ... 0.02989688 0.15412886 0.00290691]
#  [0.88362919 0.49132948 0.80056022 ... 0.05253383 0.14026205 0.        ]
#  ...
#  [0.65088757 0.71676301 0.         ... 0.10470402 1.         0.90291832]
#  [0.70808679 0.73410405 0.         ... 0.11793813 0.82194165 0.70121076]
#  [0.82840237 1.         0.         ... 0.16125094 0.69090084 0.78407849]]

# %%
print(validacao_cluster2)
# Out:
# [[0.79285714 0.34104046 1.         0.         0.702138   1.
#   0.63784617 1.         0.         0.72004669 1.        ]
#  [0.74761905 0.36416185 0.916      0.13739719 0.75315841 1.
#   0.84300896 0.78638847 0.04308956 0.34482605 0.4253135 ]
#  [0.6547619  0.26011561 0.82       0.49250121 0.85276968 1.
#   1.         0.23944362 0.08352126 0.47938637 0.30137957]
#  [0.         0.04046243 0.7        0.76947267 0.         0.72222222
#   0.54294829 0.         0.16084085 0.2948682  0.33655235]
#  [0.19047619 0.         0.444      1.         0.03061224 0.72222222
#   0.12031764 0.19076006 0.22720683 0.         0.03469063]
#  [0.52619048 0.3699422  0.272      0.7053701  0.34013605 0.72222222
#   0.07967371 0.41207154 0.32425902 0.02356418 0.        ]
#  [0.68095238 0.42774566 0.1        0.77672956 0.81146744 0.66666667
#   0.00371702 0.48360656 0.37258376 0.57253156 0.32314636]
#  [0.69761905 0.3583815  0.016      0.90251572 0.79543246 0.66666667
#   0.         0.51962245 0.5496134  0.62650328 0.41931319]
#  [0.87380952 0.58959538 0.         0.83889695 0.87220603 0.66666667
#   0.13632947 0.44088425 0.58537371 0.4464532  0.48651047]
#  [0.78571429 0.71676301 0.         0.96202225 1.         0.
#   0.27398    0.42548435 0.64932345 1.         0.87536207]
#  [0.8547619  0.73410405 0.         0.80188679 0.9212828  0.
#   0.50598621 0.49403875 0.73139497 0.77334398 0.61640062]
#  [1.         1.         0.         0.5684567  0.98445092 0.
#   0.72600608 0.65896672 1.         0.60653807 0.72279002]]

# %% [markdown]
# ### 2.2 Convertendo o array em um modelo de dados 3D para entrada na rede LSTM
#
# ---
# Créditos: https://machinelearningmastery.com/convert-time-series-supervised-learning-problem-python/
#
# Para fazer a predição, utilizei os 12 primeiros meses para predizer o seguinte. Com isso, o dataset perde 12 meses, uma vez que os 11 primeiros meses não possuem 12 meses anteriores e o último mês não possui valor conhecido da arrecadação do mês subsequente.
#
# ___

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
 
raw = DataFrame()
raw['ob1'] = [x for x in range(10)]
raw['ob2'] = [x for x in range(50, 60)]
# values = raw.values
values = pd.DataFrame(serie_cluster2).values
serie_cluster2_prepared = series_to_supervised(values,12)
print(serie_cluster2_prepared)
# Out:
#      var1(t-12)  var2(t-12)  var3(t-12)  var4(t-12)  var5(t-12)  var6(t-12)  \
# 12     0.706114    0.658960    0.807843    0.777882    0.000000    1.000000
# 13     0.688363    0.572254    0.806723    0.815927    0.016063    1.000000
# 14     0.883629    0.491329    0.800560    0.806025    0.250093    1.000000
# 15     0.781065    0.433526    0.787675    0.805608    0.163803    0.954128
# 16     0.802761    0.514451    0.777031    0.903586    0.138962    0.954128
# ..          ...         ...         ...         ...         ...         ...
# 199    0.585799    0.283237    0.224090    0.548989    0.806687    0.256881
# 200    0.660750    0.196532    0.213445    0.580467    0.740941    0.256881
# 201    0.676529    0.277457    0.194958    0.571816    0.825738    0.187156
# 202    0.615385    0.514451    0.168067    0.585574    0.751588    0.187156
# 203    0.639053    0.884393    0.150700    0.556389    0.726746    0.187156
#
#      var7(t-12)  var8(t-12)  var9(t-12)  var10(t-12)  ...   var2(t)   var3(t)  \
# 12     0.000000    0.070931    0.011039     0.026736  ...  0.554913  0.898039
# 13     0.001998    0.068126    0.029897     0.154129  ...  0.560694  0.928291
# 14     0.005245    0.094635    0.052534     0.140262  ...  0.572254  0.956303
# 15     0.007953    0.090654    0.067755     0.183052  ...  0.722543  0.975910
# 16     0.011412    0.131910    0.074275     0.080545  ...  0.502890  0.992157
# ..          ...         ...         ...          ...  ...       ...       ...
# 199    0.960777    0.324889    0.071353     0.600729  ...  0.358382  0.002241
# 200    0.968736    0.352755    0.078093     0.520462  ...  0.589595  0.000000
# 201    0.975379    0.325975    0.083392     0.659216  ...  0.716763  0.000000
# 202    0.980719    0.356464    0.090197     0.561273  ...  0.734104  0.000000
# 203    0.986395    0.384601    0.110133     0.568063  ...  1.000000  0.000000
#
#       var4(t)   var5(t)   var6(t)   var7(t)   var8(t)   var9(t)  var10(t)  \
# 12   0.643423  0.092081  0.954128  0.041983  0.189451  0.023793  0.110941
# 13   0.597874  0.101046  0.954128  0.045086  0.201031  0.036287  0.069672
# 14   0.651032  0.314344  0.954128  0.048235  0.269067  0.058963  0.094188
# 15   0.588597  0.257004  0.954128  0.051752  0.258029  0.074145  0.106258
# 16   0.521472  0.229174  0.954128  0.054882  0.229169  0.092288  0.083481
# ..        ...       ...       ...       ...       ...       ...       ...
# 199  0.957995  0.689765  0.066055  0.976264  0.189270  0.088626  0.706585
# 200  0.930582  0.719275  0.066055  0.979500  0.160590  0.094392  0.565140
# 201  0.983636  0.768397  0.000000  0.982767  0.154981  0.104704  1.000000
# 202  0.914634  0.738140  0.000000  0.988274  0.179951  0.117938  0.821942
# 203  0.814050  0.762421  0.000000  0.993496  0.240025  0.161251  0.690901
#
#      var11(t)
# 12   0.114664
# 13   0.040751
# 14   0.053689
# 15   0.129435
# 16   0.069296
# ..        ...
# 199  0.547697
# 200  0.600038
# 201  0.902918
# 202  0.701211
# 203  0.784078
#
# [192 rows x 143 columns]

# %% [markdown]
# ### 2.3 Dividindo o dataset em sets de treino e teste

# %%
# split into train and test sets
values = serie_cluster2_prepared.values
# Base de treino com 156 meses
periodo_treino = 168
train = values[:periodo_treino, :]
test = values[periodo_treino:, :]

# %%
print(train)
# Out:
# [[0.7061144  0.65895954 0.80784314 ... 0.02379283 0.11094089 0.11466373]
#  [0.68836292 0.57225434 0.80672269 ... 0.03628666 0.06967225 0.04075126]
#  [0.88362919 0.49132948 0.80056022 ... 0.05896257 0.09418763 0.05368928]
#  ...
#  [0.74556213 0.46242775 0.34229692 ... 0.11819788 0.65626803 0.88537209]
#  [0.73175542 0.38150289 0.30812325 ... 0.13395153 0.59027169 0.67186137]
#  [0.75345168 0.47398844 0.28571429 ... 0.15413387 0.56198087 0.69534067]]

# %%
print(test)
# Out:
# [[0.75739645 0.38728324 0.28011204 ... 0.00993532 0.75418628 0.98152505]
#  [0.68639053 0.40462428 0.27002801 ... 0.02319541 0.47065838 0.52530715]
#  [0.65680473 0.2716763  0.26218487 ... 0.03009169 0.5882852  0.56118134]
#  ...
#  [0.6765286  0.27745665 0.19495798 ... 0.10470402 1.         0.90291832]
#  [0.61538462 0.51445087 0.16806723 ... 0.11793813 0.82194165 0.70121076]
#  [0.63905325 0.88439306 0.15070028 ... 0.16125094 0.69090084 0.78407849]]

# %%
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (168, 1, 142) (168,) (24, 1, 142) (24,)

# %% [markdown]
# ## 3. Implementando o modelo LSTM

# %%
def model_builder(hp):
    
    
    model = keras.Sequential()
    
    # initializer = hp.Choice('kernel_initializer', values = ['glorot_uniform', 'glorot_normal',
    #                                 'RandomNormal' ])
    
    model.add(keras.layers.LSTM(142, return_sequences= True, 
                                input_shape=(train_X.shape[1], train_X.shape[2])))
    
    dropout_rate = hp.Float('dropout_rate', min_value = 0.2, max_value = 0.5, step=0.05)
    
    model.add(keras.layers.Dropout(dropout_rate))
    
    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 32-512
    hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
    model.add(keras.layers.LSTM(units=hp_units, return_sequences= True))
    
    model.add(keras.layers.Dropout(dropout_rate))
    
    model.add(keras.layers.LSTM(units=hp_units, return_sequences= True))
    
    model.add(keras.layers.Dropout(dropout_rate))
    
    model.add(keras.layers.LSTM(units=hp_units, return_sequences= True))
    
    model.add(keras.layers.Dropout(dropout_rate))
    
    model.add(keras.layers.LSTM(units=hp_units, return_sequences= True))
    
    model.add(keras.layers.Dropout(dropout_rate))
    
    model.add(keras.layers.Dense(1))

    # Tune the learning rate for the optimizer
    # Choose an optimal value from 0.01, 0.001, or 0.0001
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss='mean_squared_error',
                metrics=[keras.metrics.MeanSquaredError()])

    return model

# %%
tuner = kt.Hyperband(model_builder,
                     objective= 'loss',
                     max_epochs=200,
                     factor=3,
                     directory='hypertuner',
                     project_name='treino-v2-2020-9')

# %%
tuner.search(train_X, train_y, epochs=200)
best_hps = tuner.get_best_hyperparameters()[0]
# Out:
# Trial 254 Complete [00h 00m 41s]
# loss: 0.003565132152289152
#
# Best loss So Far: 0.0009911314118653536
# Total elapsed time: 00h 37m 13s
# INFO:tensorflow:Oracle triggered exit

# %%
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')} and best dropout rate is {best_hps.get('dropout_rate')}.
""")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 416 and the optimal learning rate for the optimizer
# is 0.01 and best dropout rate is 0.2.

# %%
model = tuner.hypermodel.build(best_hps)

history = model.fit(train_X, train_y, epochs=185, batch_size=64, 
                    validation_data=(test_X, test_y),  verbose=1, shuffle=False)
# Out:
# Epoch 1/185
# 3/3 [==============================] - 6s 597ms/step - loss: 0.1108 - mean_squared_error: 0.1108 - val_loss: 0.4195 - val_mean_squared_error: 0.4195
# Epoch 2/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0920 - mean_squared_error: 0.0920 - val_loss: 0.3565 - val_mean_squared_error: 0.3565
# Epoch 3/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0553 - mean_squared_error: 0.0553 - val_loss: 0.2017 - val_mean_squared_error: 0.2017
# Epoch 4/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0403 - val_mean_squared_error: 0.0403
# Epoch 5/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0632 - mean_squared_error: 0.0632 - val_loss: 0.1096 - val_mean_squared_error: 0.1096
# Epoch 6/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0304 - mean_squared_error: 0.0304 - val_loss: 0.1867 - val_mean_squared_error: 0.1867
# Epoch 7/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0301 - mean_squared_error: 0.0301 - val_loss: 0.2022 - val_mean_squared_error: 0.2022
# Epoch 8/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0283 - mean_squared_error: 0.0283 - val_loss: 0.1810 - val_mean_squared_error: 0.1810
# Epoch 9/185
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.1353 - val_mean_squared_error: 0.1353
# Epoch 10/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0845 - val_mean_squared_error: 0.0845
# Epoch 11/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0607 - val_mean_squared_error: 0.0607
# Epoch 12/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0681 - val_mean_squared_error: 0.0681
# Epoch 13/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0871 - val_mean_squared_error: 0.0871
# Epoch 14/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0925 - val_mean_squared_error: 0.0925
# Epoch 15/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0744 - val_mean_squared_error: 0.0744
# Epoch 16/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
# Epoch 17/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0402 - val_mean_squared_error: 0.0402
# Epoch 18/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0408 - val_mean_squared_error: 0.0408
# Epoch 19/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0406 - val_mean_squared_error: 0.0406
# Epoch 20/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0385 - val_mean_squared_error: 0.0385
# Epoch 21/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0383 - val_mean_squared_error: 0.0383
# Epoch 22/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0382 - val_mean_squared_error: 0.0382
# Epoch 23/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0379 - val_mean_squared_error: 0.0379
# Epoch 24/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0368 - val_mean_squared_error: 0.0368
# Epoch 25/185
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0362 - val_mean_squared_error: 0.0362
# Epoch 26/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0357 - val_mean_squared_error: 0.0357
# Epoch 27/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0364 - val_mean_squared_error: 0.0364
# Epoch 28/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0366 - val_mean_squared_error: 0.0366
# Epoch 29/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0355 - val_mean_squared_error: 0.0355
# Epoch 30/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0414 - val_mean_squared_error: 0.0414
# Epoch 31/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0376 - val_mean_squared_error: 0.0376
# Epoch 32/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0342 - val_mean_squared_error: 0.0342
# Epoch 33/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0379 - val_mean_squared_error: 0.0379
# Epoch 34/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0362 - val_mean_squared_error: 0.0362
# Epoch 35/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0348 - val_mean_squared_error: 0.0348
# Epoch 36/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0373 - val_mean_squared_error: 0.0373
# Epoch 37/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0354 - val_mean_squared_error: 0.0354
# Epoch 38/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0348 - val_mean_squared_error: 0.0348
# Epoch 39/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0371 - val_mean_squared_error: 0.0371
# Epoch 40/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0296 - val_mean_squared_error: 0.0296
# Epoch 41/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0367 - val_mean_squared_error: 0.0367
# Epoch 42/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0309 - val_mean_squared_error: 0.0309
# Epoch 43/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0288 - val_mean_squared_error: 0.0288
# Epoch 44/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0358 - val_mean_squared_error: 0.0358
# Epoch 45/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0269 - val_mean_squared_error: 0.0269
# Epoch 46/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0356 - val_mean_squared_error: 0.0356
# Epoch 47/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0291 - val_mean_squared_error: 0.0291
# Epoch 48/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0285 - val_mean_squared_error: 0.0285
# Epoch 49/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0308 - val_mean_squared_error: 0.0308
# Epoch 50/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0250 - val_mean_squared_error: 0.0250
# Epoch 51/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0283 - val_mean_squared_error: 0.0283
# Epoch 52/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 53/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# Epoch 54/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0282 - val_mean_squared_error: 0.0282
# Epoch 55/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# Epoch 56/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0249 - val_mean_squared_error: 0.0249
# Epoch 57/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0273 - val_mean_squared_error: 0.0273
# Epoch 58/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 59/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0287 - val_mean_squared_error: 0.0287
# Epoch 60/185
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 61/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0249 - val_mean_squared_error: 0.0249
# Epoch 62/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0286 - val_mean_squared_error: 0.0286
# Epoch 63/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0275 - val_mean_squared_error: 0.0275
# Epoch 64/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0292 - val_mean_squared_error: 0.0292
# Epoch 65/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0295 - val_mean_squared_error: 0.0295
# Epoch 66/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0271 - val_mean_squared_error: 0.0271
# Epoch 67/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0269 - val_mean_squared_error: 0.0269
# Epoch 68/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 69/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 70/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0311 - val_mean_squared_error: 0.0311
# Epoch 71/185
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0247 - val_mean_squared_error: 0.0247
# Epoch 72/185
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0266 - val_mean_squared_error: 0.0266
# Epoch 73/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0251 - val_mean_squared_error: 0.0251
# Epoch 74/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0293 - val_mean_squared_error: 0.0293
# Epoch 75/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 76/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0251 - val_mean_squared_error: 0.0251
# Epoch 77/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 78/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 79/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0280 - val_mean_squared_error: 0.0280
# Epoch 80/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 81/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0213 - val_mean_squared_error: 0.0213
# Epoch 82/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0390 - val_mean_squared_error: 0.0390
# Epoch 83/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 84/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 85/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0319 - val_mean_squared_error: 0.0319
# Epoch 86/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0216 - val_mean_squared_error: 0.0216
# Epoch 87/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 88/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0276 - val_mean_squared_error: 0.0276
# Epoch 89/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0256 - val_mean_squared_error: 0.0256
# Epoch 90/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 91/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0340 - val_mean_squared_error: 0.0340
# Epoch 92/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0287 - val_mean_squared_error: 0.0287
# Epoch 93/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 94/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0250 - val_mean_squared_error: 0.0250
# Epoch 95/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0240 - val_mean_squared_error: 0.0240
# Epoch 96/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0212 - val_mean_squared_error: 0.0212
# Epoch 97/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0269 - val_mean_squared_error: 0.0269
# Epoch 98/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0242 - val_mean_squared_error: 0.0242
# Epoch 99/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 100/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0302 - val_mean_squared_error: 0.0302
# Epoch 101/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 102/185
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 103/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 104/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 105/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 106/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0249 - val_mean_squared_error: 0.0249
# Epoch 107/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 108/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# Epoch 109/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0224 - val_mean_squared_error: 0.0224
# Epoch 110/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0238 - val_mean_squared_error: 0.0238
# Epoch 111/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 112/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 113/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0265 - val_mean_squared_error: 0.0265
# Epoch 114/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0217 - val_mean_squared_error: 0.0217
# Epoch 115/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 116/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 117/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 118/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
# Epoch 119/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 120/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0222 - val_mean_squared_error: 0.0222
# Epoch 121/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0213 - val_mean_squared_error: 0.0213
# Epoch 122/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 123/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0224 - val_mean_squared_error: 0.0224
# Epoch 124/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 125/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0272 - val_mean_squared_error: 0.0272
# Epoch 126/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Epoch 127/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 128/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 129/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0214 - val_mean_squared_error: 0.0214
# Epoch 130/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 131/185
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 132/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0223 - val_mean_squared_error: 0.0223
# Epoch 133/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0214 - val_mean_squared_error: 0.0214
# Epoch 134/185
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0223 - val_mean_squared_error: 0.0223
# Epoch 135/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 136/185
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 137/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 138/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 139/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0226 - val_mean_squared_error: 0.0226
# Epoch 140/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 141/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0250 - val_mean_squared_error: 0.0250
# Epoch 142/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 143/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
# Epoch 144/185
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 145/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 146/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0253 - val_mean_squared_error: 0.0253
# Epoch 147/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# Epoch 148/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0248 - val_mean_squared_error: 0.0248
# Epoch 149/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 150/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0222 - val_mean_squared_error: 0.0222
# Epoch 151/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0214 - val_mean_squared_error: 0.0214
# Epoch 152/185
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0215 - val_mean_squared_error: 0.0215
# Epoch 153/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0250 - val_mean_squared_error: 0.0250
# Epoch 154/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 155/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0247 - val_mean_squared_error: 0.0247
# Epoch 156/185
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0213 - val_mean_squared_error: 0.0213
# Epoch 157/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 158/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 159/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Epoch 160/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 161/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0197 - val_mean_squared_error: 0.0197
# Epoch 162/185
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0223 - val_mean_squared_error: 0.0223
# Epoch 163/185
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0209 - val_mean_squared_error: 0.0209
# Epoch 164/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0250 - val_mean_squared_error: 0.0250
# Epoch 165/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 166/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0201 - val_mean_squared_error: 0.0201
# Epoch 167/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 168/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# Epoch 169/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 170/185
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0217 - val_mean_squared_error: 0.0217
# Epoch 171/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
# Epoch 172/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 173/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0218 - val_mean_squared_error: 0.0218
# Epoch 174/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0226 - val_mean_squared_error: 0.0226
# Epoch 175/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 176/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0211 - val_mean_squared_error: 0.0211
# Epoch 177/185
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0214 - val_mean_squared_error: 0.0214
# Epoch 178/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 179/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 180/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 181/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0207 - val_mean_squared_error: 0.0207
# Epoch 182/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
# Epoch 183/185
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0208 - val_mean_squared_error: 0.0208
# Epoch 184/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# Epoch 185/185
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0210 - val_mean_squared_error: 0.0210

# %%
#Função para calculo do MAPE - Mean Absolute Percentage Error, que será  utilizado como medida de erro do modelo

def calculo_mape(y_pred,y_true):

    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
train_X.shape
# Out:
# (168, 1, 142)

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()

# %%
plot_model(model, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 1, 142)            161880
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 142)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1, 320)            592640
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 320)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 320)            820480
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 320)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 1, 320)            820480
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 320)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 1, 320)            820480
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 320)            0
# _________________________________________________________________
# dense (Dense)                (None, 1, 1)              321
# =================================================================
# Total params: 3,216,281
# Trainable params: 3,216,281
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 4. Fazendo a Previsão para 2018 a 2020

# %%
# make a prediction


yhat = model.predict(test_X)
test_X_final = test_X.reshape(test_X.shape[0], test_X.shape[2])
# invert scaling for forecast



inv_yhat = np.concatenate((np.squeeze(yhat, axis=(2,)), test_X_final[:, :-1]), axis=1)

# inv_yhat = scaler_in.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

# invert scaling for actual

test_y_final = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y_final, test_X_final[:, 1:]), axis=1)
# inv_y = scaler_in.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))

mape = calculo_mape(inv_yhat, inv_y)
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.145

# %%
test_y_inv = scaler_out.inverse_transform(test_y_final)
yhat_final_inv = scaler_out.inverse_transform(np.squeeze(yhat, axis=(2,)))


df_data = pd.date_range('2019-01','2021-01', freq = 'm')

# Plota o valor observado vs previsto. 

plt.figure(figsize=(10,10))
plt.plot(test_y_inv, label='Esperado')
plt.plot(yhat_final_inv, label='Previsto LSTM')
plt.legend()
plt.title('Teste LSTM - MAPE: %.4f' % mape)
plt.xticks(np.arange(len(test_y_inv)),df_data.strftime('%m/%Y'), rotation='vertical')
plt.grid(True,axis='y')
plt.show()

# %%
## Formatação das tabelas

pd.set_option('max_columns', None)
pd.options.display.float_format = '{:,.2%}'.format

# %%
variacao_percentual = pd.DataFrame(((yhat_final_inv/test_y_inv)-1) ,columns=['variacao'])

# %%
set_alerta_negativo = pd.DataFrame()
set_normal= pd.DataFrame()
set_alerta_positivo = pd.DataFrame()

# %%
for i in range (len(variacao_percentual)):
    if variacao_percentual.iloc[i].values[0] > 0.05:
        set_alerta_negativo = set_alerta_negativo.append(variacao_percentual[i:i+1])
    elif variacao_percentual.iloc[i].values[0] < -0.05:
        set_alerta_positivo = set_alerta_positivo.append(variacao_percentual[i:i+1])
    else:
        set_normal = set_normal.append(variacao_percentual[i:i+1])

# %%
df_data = pd.date_range('2019-01','2021-01', freq = 'm')

#Plota o resultado do modelo
fig, ax = plt.subplots(figsize=(12,6))
ax.set_ylabel('Variação %')

if len(set_alerta_negativo) > 0:
    plt.plot(set_alerta_negativo * 100, 'o', color='red',  label='Arrecadaçao < Previsão Crítico')

if len(set_normal) > 0:
    plt.plot(set_normal * 100, 'o', color='green',  label='Períodos Normais')

if len(set_alerta_positivo) > 0:
    plt.plot(set_alerta_positivo * 100, 'o', color='blue',  label='Arrecadação > Previsão Crítico')

plt.title('Variação entre valores previstos e observados - LSTM' )
plt.grid(True,axis='y')
ax.set_xticks(range(0,24))
plt.xticks(ax.get_xticks(), df_data.strftime('%m/%Y'), rotation='vertical')
plt.legend(loc='upper left')
