# %% [markdown]
# # Modelo LSTM para predição
#
# ---
#
#
# ___

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import math
import requests
import json
import os
import statsmodels.api as sm
import tensorflow as tf
from pandas import concat

from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore")

from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)

import math

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import Dropout
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## 1. Importando os datasets

# %%
dataset_cluster2_series = pd.read_csv("..//datasets//dataset_cluster2_series.csv", header=0, index_col=0)
dataset_cluster2_validacao = pd.read_csv("..//datasets//dataset_cluster2_validation.csv", header=0, index_col=0)

# %%
dataset_cluster2_series = dataset_cluster2_series.append(dataset_cluster2_validacao)

# %%
dataset_cluster2_validacao.head(20)
# Out:
#                      indice_pimpf  ipca  taxa_selic  taxa_cambio   ibcbr  \
# mes
# 2020-01-01 00:00:00         101.5  0.21        4.40       116.16  133.60
# 2020-02-01 00:00:00          99.6  0.25        4.19       121.84  134.63
# 2020-03-01 00:00:00          95.7  0.07        3.95       136.52  136.72
# 2020-04-01 00:00:00          68.2 -0.31        3.65       147.97  119.13
# 2020-05-01 00:00:00          76.2 -0.38        3.01       157.50  119.79
# 2020-06-01 00:00:00          90.3  0.26        2.58       145.32  126.18
# 2020-07-01 00:00:00          96.8  0.36        2.15       148.27  135.82
# 2020-08-01 00:00:00          97.5  0.24        1.94       153.47  135.50
# 2020-09-01 00:00:00         104.9  0.64        1.90       150.84  137.14
# 2020-10-01 00:00:00         101.2  0.86        1.90       155.93  139.62
# 2020-11-01 00:00:00         104.1  0.89        1.90       149.31  138.10
# 2020-12-01 00:00:00         110.2  1.35        1.90       139.66  139.53
#
#                      tjlp  pib_mensal  preco_brent  desembolso   arrecadacao
# mes
# 2020-01-01 00:00:00  5.09   7435826.2        63.60       257.0  3.553139e+10
# 2020-02-01 00:00:00  5.09   7463826.9        55.00       792.0  2.220378e+10
# 2020-03-01 00:00:00  5.09   7485253.1        32.98      1294.0  1.932962e+10
# 2020-04-01 00:00:00  4.94   7422874.5        23.34      2254.0  2.014531e+10
# 2020-05-01 00:00:00  4.94   7365193.7        31.02      3078.0  1.314481e+10
# 2020-06-01 00:00:00  4.94   7359646.6        39.93      4283.0  1.234030e+10
# 2020-07-01 00:00:00  4.91   7349280.0        42.81      4883.0  1.983441e+10
# 2020-08-01 00:00:00  4.91   7348772.7        44.26      7081.0  2.206463e+10
# 2020-09-01 00:00:00  4.91   7367379.0        41.09      7525.0  2.362301e+10
# 2020-10-01 00:00:00  4.55   7386165.6        40.47      8319.0  3.264090e+10
# 2020-11-01 00:00:00  4.55   7417829.9        43.23      9338.0  2.663530e+10
# 2020-12-01 00:00:00  4.55   7447858.3        49.87     12673.0  2.910259e+10

# %%
len(dataset_cluster2_series)
# Out:
# 204

# %% [markdown]
# ## 2. Preparando o dataset para a rede neural LSTM

# %%
serie_cluster2 = np.array(dataset_cluster2_series)

# %%
print(serie_cluster2)
# Out:
# [[1.04000000e+02 7.60000000e-01 1.63200000e+01 ... 3.11800000e+01
#   1.10700000e+03 6.70972820e+09]
#  [1.03100000e+02 6.10000000e-01 1.63000000e+01 ... 3.08700000e+01
#   2.55900000e+03 5.84414384e+09]
#  [1.13000000e+02 4.70000000e-01 1.61900000e+01 ... 3.38000000e+01
#   4.30200000e+03 5.75759405e+09]
#  ...
#  [1.01200000e+02 8.60000000e-01 1.90000000e+00 ... 4.04700000e+01
#   8.31900000e+03 3.26409023e+10]
#  [1.04100000e+02 8.90000000e-01 1.90000000e+00 ... 4.32300000e+01
#   9.33800000e+03 2.66353020e+10]
#  [1.10200000e+02 1.35000000e+00 1.90000000e+00 ... 4.98700000e+01
#   1.26730000e+04 2.91025891e+10]]

# %%
validacao_cluster2 = np.array(dataset_cluster2_validacao)

# %%
print(validacao_cluster2)
# Out:
# [[ 1.01500000e+02  2.10000000e-01  4.40000000e+00  1.16160000e+02
#    1.33600000e+02  5.09000000e+00  7.43582620e+06  6.36000000e+01
#    2.57000000e+02  3.55313926e+10]
#  [ 9.96000000e+01  2.50000000e-01  4.19000000e+00  1.21840000e+02
#    1.34630000e+02  5.09000000e+00  7.46382690e+06  5.50000000e+01
#    7.92000000e+02  2.22037820e+10]
#  [ 9.57000000e+01  7.00000000e-02  3.95000000e+00  1.36520000e+02
#    1.36720000e+02  5.09000000e+00  7.48525310e+06  3.29800000e+01
#    1.29400000e+03  1.93296182e+10]
#  [ 6.82000000e+01 -3.10000000e-01  3.65000000e+00  1.47970000e+02
#    1.19130000e+02  4.94000000e+00  7.42287450e+06  2.33400000e+01
#    2.25400000e+03  2.01453135e+10]
#  [ 7.62000000e+01 -3.80000000e-01  3.01000000e+00  1.57500000e+02
#    1.19790000e+02  4.94000000e+00  7.36519370e+06  3.10200000e+01
#    3.07800000e+03  1.31448091e+10]
#  [ 9.03000000e+01  2.60000000e-01  2.58000000e+00  1.45320000e+02
#    1.26180000e+02  4.94000000e+00  7.35964660e+06  3.99300000e+01
#    4.28300000e+03  1.23402953e+10]
#  [ 9.68000000e+01  3.60000000e-01  2.15000000e+00  1.48270000e+02
#    1.35820000e+02  4.91000000e+00  7.34928000e+06  4.28100000e+01
#    4.88300000e+03  1.98344139e+10]
#  [ 9.75000000e+01  2.40000000e-01  1.94000000e+00  1.53470000e+02
#    1.35500000e+02  4.91000000e+00  7.34877270e+06  4.42600000e+01
#    7.08100000e+03  2.20646283e+10]
#  [ 1.04900000e+02  6.40000000e-01  1.90000000e+00  1.50840000e+02
#    1.37140000e+02  4.91000000e+00  7.36737900e+06  4.10900000e+01
#    7.52500000e+03  2.36230069e+10]
#  [ 1.01200000e+02  8.60000000e-01  1.90000000e+00  1.55930000e+02
#    1.39620000e+02  4.55000000e+00  7.38616560e+06  4.04700000e+01
#    8.31900000e+03  3.26409023e+10]
#  [ 1.04100000e+02  8.90000000e-01  1.90000000e+00  1.49310000e+02
#    1.38100000e+02  4.55000000e+00  7.41782990e+06  4.32300000e+01
#    9.33800000e+03  2.66353020e+10]
#  [ 1.10200000e+02  1.35000000e+00  1.90000000e+00  1.39660000e+02
#    1.39530000e+02  4.55000000e+00  7.44785830e+06  4.98700000e+01
#    1.26730000e+04  2.91025891e+10]]

# %%
np.random.seed(10)

# %% [markdown]
# ### 2.1 Normalizando a escala do dataset

# %%
## Criando um scaler para o campo de saída


scaler_in = MinMaxScaler(feature_range=(0, 1))
scaler_out = MinMaxScaler(feature_range=(0, 1))

serie_cluster2 = scaler_in.fit_transform(serie_cluster2)
validacao_cluster2 = scaler_out.fit_transform(validacao_cluster2)



# Criando um scaler específico para a 

arrecadacao = np.array(dataset_cluster2_series['arrecadacao'])

arrecadacao = arrecadacao.reshape(-1,1)

arrecadacao = scaler_out.fit_transform(arrecadacao)

print(arrecadacao)
# Out:
# [[0.03197893]
#  [0.00290691]
#  [0.        ]
#  [0.07101945]
#  [0.04697178]
#  [0.04336947]
#  [0.09043814]
#  [0.04513388]
#  [0.06554579]
#  [0.1017538 ]
#  [0.03653988]
#  [0.07271081]
#  [0.11466373]
#  [0.04075126]
#  [0.05368928]
#  [0.12943522]
#  [0.06929605]
#  [0.05786429]
#  [0.10810623]
#  [0.06959359]
#  [0.07557969]
#  [0.16113377]
#  [0.09564595]
#  [0.11005928]
#  [0.12256171]
#  [0.05690476]
#  [0.06269956]
#  [0.17413339]
#  [0.08017074]
#  [0.11777914]
#  [0.16132912]
#  [0.12385077]
#  [0.13878456]
#  [0.20819618]
#  [0.08878526]
#  [0.12195563]
#  [0.15937583]
#  [0.08276886]
#  [0.10593055]
#  [0.19789492]
#  [0.13959732]
#  [0.09693247]
#  [0.17639412]
#  [0.12520147]
#  [0.1864972 ]
#  [0.21860904]
#  [0.16194759]
#  [0.20198246]
#  [0.25738449]
#  [0.14754001]
#  [0.1690323 ]
#  [0.29123743]
#  [0.16822154]
#  [0.19155093]
#  [0.3469625 ]
#  [0.23729904]
#  [0.23999107]
#  [0.4433388 ]
#  [0.20018702]
#  [0.11922986]
#  [0.19881899]
#  [0.03962304]
#  [0.10160055]
#  [0.18309066]
#  [0.10889253]
#  [0.1657051 ]
#  [0.23761197]
#  [0.12426865]
#  [0.16449662]
#  [0.29073203]
#  [0.22792695]
#  [0.21462844]
#  [0.3141784 ]
#  [0.16219808]
#  [0.19554406]
#  [0.34657063]
#  [0.23117478]
#  [0.21951071]
#  [0.29349692]
#  [0.20860432]
#  [0.23204807]
#  [0.32218786]
#  [0.23750397]
#  [0.25930435]
#  [0.4142141 ]
#  [0.19339759]
#  [0.24420079]
#  [0.38326402]
#  [0.24639695]
#  [0.27268718]
#  [0.38685697]
#  [0.27172483]
#  [0.27647149]
#  [0.43184827]
#  [0.27392189]
#  [0.27079017]
#  [0.49917232]
#  [0.21183359]
#  [0.24038459]
#  [0.43776074]
#  [0.26881241]
#  [0.26154137]
#  [0.40732186]
#  [0.25664111]
#  [0.29060459]
#  [0.41359198]
#  [0.29924342]
#  [0.301332  ]
#  [0.54514761]
#  [0.1983706 ]
#  [0.29514453]
#  [0.45919482]
#  [0.323292  ]
#  [0.30478792]
#  [0.44474125]
#  [0.32417603]
#  [0.3244358 ]
#  [0.49389733]
#  [0.34359729]
#  [0.42497365]
#  [0.60389722]
#  [0.30014058]
#  [0.34139861]
#  [0.48690918]
#  [0.31697245]
#  [0.33391403]
#  [0.43718309]
#  [0.32489568]
#  [0.33119745]
#  [0.54787316]
#  [0.4599673 ]
#  [0.37318528]
#  [0.58236285]
#  [0.26238877]
#  [0.34154564]
#  [0.4908937 ]
#  [0.33453976]
#  [0.34470969]
#  [0.51197337]
#  [0.4035922 ]
#  [0.39216783]
#  [0.45350207]
#  [0.34447798]
#  [0.36588261]
#  [0.53294028]
#  [0.26857366]
#  [0.31394386]
#  [0.35150719]
#  [0.31182977]
#  [0.28877275]
#  [0.34990462]
#  [0.28079959]
#  [0.30555365]
#  [0.36851035]
#  [0.34779511]
#  [0.36333828]
#  [0.5373562 ]
#  [0.24991395]
#  [0.31880399]
#  [0.4990555 ]
#  [0.31718779]
#  [0.31876462]
#  [0.41663499]
#  [0.40180043]
#  [0.41294425]
#  [0.58019928]
#  [0.56641402]
#  [0.48455317]
#  [0.77061351]
#  [0.38647218]
#  [0.46623835]
#  [0.6713958 ]
#  [0.45426807]
#  [0.4675181 ]
#  [0.77867743]
#  [0.4954713 ]
#  [0.65138209]
#  [0.88537209]
#  [0.67186137]
#  [0.69534067]
#  [0.98152505]
#  [0.52530715]
#  [0.56118134]
#  [0.83971129]
#  [0.58633696]
#  [0.61863136]
#  [0.92425571]
#  [0.68365039]
#  [0.60083379]
#  [0.82816954]
#  [0.62549876]
#  [0.70544393]
#  [1.        ]
#  [0.55237117]
#  [0.45583784]
#  [0.48323426]
#  [0.24811127]
#  [0.22109041]
#  [0.4727922 ]
#  [0.54769747]
#  [0.60003808]
#  [0.90291832]
#  [0.70121076]
#  [0.78407849]]

# %%
print(serie_cluster2)
# Out:
# [[0.7061144  0.65895954 0.80784314 ... 0.07093097 0.01103925 0.03197893]
#  [0.68836292 0.57225434 0.80672269 ... 0.0681263  0.02989688 0.00290691]
#  [0.88362919 0.49132948 0.80056022 ... 0.09463494 0.05253383 0.        ]
#  ...
#  [0.65088757 0.71676301 0.         ... 0.15498055 0.10470402 0.90291832]
#  [0.70808679 0.73410405 0.         ... 0.17995114 0.11793813 0.70121076]
#  [0.82840237 1.         0.         ... 0.24002533 0.16125094 0.78407849]]

# %%
print(validacao_cluster2)
# Out:
# [[0.79285714 0.34104046 1.         0.         0.70619815 1.
#   0.63784617 1.         0.         1.        ]
#  [0.74761905 0.36416185 0.916      0.13739719 0.75646657 1.
#   0.84300896 0.78638847 0.04308956 0.4253135 ]
#  [0.6547619  0.26011561 0.82       0.49250121 0.85846755 1.
#   1.         0.23944362 0.08352126 0.30137957]
#  [0.         0.04046243 0.7        0.76947267 0.         0.72222222
#   0.54294829 0.         0.16084085 0.33655235]
#  [0.19047619 0.         0.444      1.         0.03221083 0.72222222
#   0.12031764 0.19076006 0.22720683 0.03469063]
#  [0.52619048 0.3699422  0.272      0.7053701  0.34407028 0.72222222
#   0.07967371 0.41207154 0.32425902 0.        ]
#  [0.68095238 0.42774566 0.1        0.77672956 0.81454368 0.66666667
#   0.00371702 0.48360656 0.37258376 0.32314636]
#  [0.69761905 0.3583815  0.016      0.90251572 0.79892631 0.66666667
#   0.         0.51962245 0.5496134  0.41931319]
#  [0.87380952 0.58959538 0.         0.83889695 0.87896535 0.66666667
#   0.13632947 0.44088425 0.58537371 0.48651047]
#  [0.78571429 0.71676301 0.         0.96202225 1.         0.
#   0.27398    0.42548435 0.64932345 0.87536207]
#  [0.8547619  0.73410405 0.         0.80188679 0.92581747 0.
#   0.50598621 0.49403875 0.73139497 0.61640062]
#  [1.         1.         0.         0.5684567  0.99560761 0.
#   0.72600608 0.65896672 1.         0.72279002]]

# %% [markdown]
# ### 2.2 Convertendo o array em um modelo de dados 3D para entrada na rede LSTM
#
# ---
# Créditos: https://machinelearningmastery.com/convert-time-series-supervised-learning-problem-python/
#
# Para fazer a predição, utilizei os 12 primeiros meses para predizer o seguinte. Com isso, o dataset perde 12 meses, uma vez que os 11 primeiros meses não possuem 12 meses anteriores e o último mês não possui valor conhecido da arrecadação do mês subsequente.
#
# ___

# %%
from pandas import DataFrame
from pandas import concat
 
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
 
 
raw = DataFrame()
raw['ob1'] = [x for x in range(10)]
raw['ob2'] = [x for x in range(50, 60)]
# values = raw.values
values = pd.DataFrame(serie_cluster2).values
serie_cluster2_prepared = series_to_supervised(values,12)
print(serie_cluster2_prepared)
# Out:
#      var1(t-12)  var2(t-12)  var3(t-12)  var4(t-12)  var5(t-12)  var6(t-12)  \
# 12     0.706114    0.658960    0.807843    0.777882    0.000000    1.000000
# 13     0.688363    0.572254    0.806723    0.815927    0.016063    1.000000
# 14     0.883629    0.491329    0.800560    0.806025    0.250093    1.000000
# 15     0.781065    0.433526    0.787675    0.805608    0.163803    0.954128
# 16     0.802761    0.514451    0.777031    0.903586    0.138962    0.954128
# ..          ...         ...         ...         ...         ...         ...
# 199    0.585799    0.283237    0.224090    0.548989    0.806500    0.256881
# 200    0.660750    0.196532    0.213445    0.580467    0.741688    0.256881
# 201    0.676529    0.277457    0.194958    0.571816    0.824991    0.187156
# 202    0.615385    0.514451    0.168067    0.585574    0.751774    0.187156
# 203    0.639053    0.884393    0.150700    0.556389    0.727493    0.187156
#
#      var7(t-12)  var8(t-12)  var9(t-12)  var10(t-12)  ...   var1(t)   var2(t)  \
# 12     0.000000    0.070931    0.011039     0.031979  ...  0.733728  0.554913
# 13     0.001998    0.068126    0.029897     0.002907  ...  0.692308  0.560694
# 14     0.005245    0.094635    0.052534     0.000000  ...  0.646943  0.572254
# 15     0.007953    0.090654    0.067755     0.071019  ...  0.733728  0.722543
# 16     0.011412    0.131910    0.074275     0.046972  ...  0.723866  0.502890
# ..          ...         ...         ...          ...  ...       ...       ...
# 199    0.960777    0.324889    0.071353     0.683650  ...  0.577909  0.358382
# 200    0.968736    0.352755    0.078093     0.600834  ...  0.723866  0.589595
# 201    0.975379    0.325975    0.083392     0.828170  ...  0.650888  0.716763
# 202    0.980719    0.356464    0.090197     0.625499  ...  0.708087  0.734104
# 203    0.986395    0.384601    0.110133     0.705444  ...  0.828402  1.000000
#
#       var3(t)   var4(t)   var5(t)   var6(t)   var7(t)   var8(t)   var9(t)  \
# 12   0.898039  0.643423  0.092081  0.954128  0.041983  0.189451  0.023793
# 13   0.928291  0.597874  0.101046  0.954128  0.045086  0.201031  0.036287
# 14   0.956303  0.651032  0.314344  0.954128  0.048235  0.269067  0.058963
# 15   0.975910  0.588597  0.257004  0.954128  0.051752  0.258029  0.074145
# 16   0.992157  0.521472  0.229174  0.954128  0.054882  0.229169  0.092288
# ..        ...       ...       ...       ...       ...       ...       ...
# 199  0.002241  0.957995  0.689391  0.066055  0.976264  0.189270  0.088626
# 200  0.000000  0.930582  0.720022  0.066055  0.979500  0.160590  0.094392
# 201  0.000000  0.983636  0.766343  0.000000  0.982767  0.154981  0.104704
# 202  0.000000  0.914634  0.737953  0.000000  0.988274  0.179951  0.117938
# 203  0.000000  0.814050  0.764662  0.000000  0.993496  0.240025  0.161251
#
#      var10(t)
# 12   0.114664
# 13   0.040751
# 14   0.053689
# 15   0.129435
# 16   0.069296
# ..        ...
# 199  0.547697
# 200  0.600038
# 201  0.902918
# 202  0.701211
# 203  0.784078
#
# [192 rows x 130 columns]

# %% [markdown]
# ### 2.3 Dividindo o dataset em sets de treino e teste

# %%
# split into train and test sets
values = serie_cluster2_prepared.values
# Base de treino com 144 meses
periodo_treino = 156
train = values[:periodo_treino, :]
test = values[periodo_treino:, :]

# %%
print(train)
# Out:
# [[0.7061144  0.65895954 0.80784314 ... 0.18945083 0.02379283 0.11466373]
#  [0.68836292 0.57225434 0.80672269 ... 0.20103139 0.03628666 0.04075126]
#  [0.88362919 0.49132948 0.80056022 ... 0.26906722 0.05896257 0.05368928]
#  ...
#  [0.48717949 0.3699422  0.68067227 ... 0.31014204 0.14667913 0.58019928]
#  [0.5877712  0.32369942 0.67226891 ... 0.35492626 0.16090028 0.56641402]
#  [0.60552268 0.39306358 0.65826331 ... 0.36976387 0.18321255 0.48455317]]

# %%
print(test)
# Out:
# [[0.63510848 0.43930636 0.63137255 ... 0.41301004 0.00185719 0.77061351]
#  [0.60749507 0.41040462 0.61176471 ... 0.38071112 0.00825995 0.38647218]
#  [0.64891519 0.36416185 0.57422969 ... 0.39002986 0.01832515 0.46623835]
#  ...
#  [0.6765286  0.27745665 0.19495798 ... 0.15498055 0.10470402 0.90291832]
#  [0.61538462 0.51445087 0.16806723 ... 0.17995114 0.11793813 0.70121076]
#  [0.63905325 0.88439306 0.15070028 ... 0.24002533 0.16125094 0.78407849]]

# %%
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (156, 1, 129) (156,) (36, 1, 129) (36,)

# %% [markdown]
# ## 3. Implementando o modelo LSTM

# %%
train_X.shape
# Out:
# (156, 1, 129)

# %%
np.random.seed(12)

# Criando a rede

model = Sequential()
model.add(GRU(130, return_sequences = True, use_bias= True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))

model.add(GRU(260, return_sequences = True, use_bias= True))
model.add(Dropout(0.2))

model.add(GRU(260, return_sequences = True, use_bias= True))
model.add(Dropout(0.2))

model.add(GRU(260, return_sequences = True, use_bias= True))
model.add(Dropout(0.2))

model.add(GRU(260, return_sequences = True, use_bias= True))
model.add(Dropout(0.2))

model.add(GRU(260, return_sequences = True, use_bias= True))
model.add(Dropout(0.2))

model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='Adam')
# fit network
history = model.fit(train_X, train_y, epochs=185, batch_size=32, 
                    validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/185
# 5/5 - 11s - loss: 0.0311 - val_loss: 0.0340
# Epoch 2/185
# 5/5 - 0s - loss: 0.0775 - val_loss: 0.2553
# Epoch 3/185
# 5/5 - 0s - loss: 0.0357 - val_loss: 0.2616
# Epoch 4/185
# 5/5 - 0s - loss: 0.0230 - val_loss: 0.1853
# Epoch 5/185
# 5/5 - 0s - loss: 0.0101 - val_loss: 0.0951
# Epoch 6/185
# 5/5 - 0s - loss: 0.0183 - val_loss: 0.1070
# Epoch 7/185
# 5/5 - 0s - loss: 0.0143 - val_loss: 0.1417
# Epoch 8/185
# 5/5 - 0s - loss: 0.0106 - val_loss: 0.1183
# Epoch 9/185
# 5/5 - 0s - loss: 0.0073 - val_loss: 0.0742
# Epoch 10/185
# 5/5 - 0s - loss: 0.0079 - val_loss: 0.0859
# Epoch 11/185
# 5/5 - 0s - loss: 0.0088 - val_loss: 0.0858
# Epoch 12/185
# 5/5 - 0s - loss: 0.0064 - val_loss: 0.0653
# Epoch 13/185
# 5/5 - 0s - loss: 0.0067 - val_loss: 0.0741
# Epoch 14/185
# 5/5 - 0s - loss: 0.0062 - val_loss: 0.0683
# Epoch 15/185
# 5/5 - 0s - loss: 0.0060 - val_loss: 0.0549
# Epoch 16/185
# 5/5 - 0s - loss: 0.0056 - val_loss: 0.0589
# Epoch 17/185
# 5/5 - 0s - loss: 0.0056 - val_loss: 0.0552
# Epoch 18/185
# 5/5 - 0s - loss: 0.0056 - val_loss: 0.0514
# Epoch 19/185
# 5/5 - 0s - loss: 0.0051 - val_loss: 0.0527
# Epoch 20/185
# 5/5 - 0s - loss: 0.0047 - val_loss: 0.0481
# Epoch 21/185
# 5/5 - 0s - loss: 0.0051 - val_loss: 0.0413
# Epoch 22/185
# 5/5 - 0s - loss: 0.0052 - val_loss: 0.0495
# Epoch 23/185
# 5/5 - 0s - loss: 0.0080 - val_loss: 0.0483
# Epoch 24/185
# 5/5 - 0s - loss: 0.0074 - val_loss: 0.0598
# Epoch 25/185
# 5/5 - 0s - loss: 0.0091 - val_loss: 0.0824
# Epoch 26/185
# 5/5 - 0s - loss: 0.0047 - val_loss: 0.0355
# Epoch 27/185
# 5/5 - 0s - loss: 0.0049 - val_loss: 0.0463
# Epoch 28/185
# 5/5 - 0s - loss: 0.0062 - val_loss: 0.0459
# Epoch 29/185
# 5/5 - 0s - loss: 0.0044 - val_loss: 0.0393
# Epoch 30/185
# 5/5 - 0s - loss: 0.0055 - val_loss: 0.0494
# Epoch 31/185
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0323
# Epoch 32/185
# 5/5 - 0s - loss: 0.0041 - val_loss: 0.0357
# Epoch 33/185
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0303
# Epoch 34/185
# 5/5 - 0s - loss: 0.0031 - val_loss: 0.0318
# Epoch 35/185
# 5/5 - 0s - loss: 0.0035 - val_loss: 0.0273
# Epoch 36/185
# 5/5 - 0s - loss: 0.0031 - val_loss: 0.0288
# Epoch 37/185
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0237
# Epoch 38/185
# 5/5 - 0s - loss: 0.0042 - val_loss: 0.0344
# Epoch 39/185
# 5/5 - 0s - loss: 0.0072 - val_loss: 0.0308
# Epoch 40/185
# 5/5 - 0s - loss: 0.0065 - val_loss: 0.0405
# Epoch 41/185
# 5/5 - 0s - loss: 0.0108 - val_loss: 0.0792
# Epoch 42/185
# 5/5 - 0s - loss: 0.0040 - val_loss: 0.0289
# Epoch 43/185
# 5/5 - 0s - loss: 0.0068 - val_loss: 0.0379
# Epoch 44/185
# 5/5 - 0s - loss: 0.0107 - val_loss: 0.0792
# Epoch 45/185
# 5/5 - 0s - loss: 0.0044 - val_loss: 0.0388
# Epoch 46/185
# 5/5 - 0s - loss: 0.0071 - val_loss: 0.0320
# Epoch 47/185
# 5/5 - 0s - loss: 0.0046 - val_loss: 0.0372
# Epoch 48/185
# 5/5 - 0s - loss: 0.0035 - val_loss: 0.0288
# Epoch 49/185
# 5/5 - 0s - loss: 0.0031 - val_loss: 0.0342
# Epoch 50/185
# 5/5 - 0s - loss: 0.0028 - val_loss: 0.0294
# Epoch 51/185
# 5/5 - 0s - loss: 0.0035 - val_loss: 0.0259
# Epoch 52/185
# 5/5 - 0s - loss: 0.0029 - val_loss: 0.0285
# Epoch 53/185
# 5/5 - 0s - loss: 0.0026 - val_loss: 0.0247
# Epoch 54/185
# 5/5 - 0s - loss: 0.0027 - val_loss: 0.0239
# Epoch 55/185
# 5/5 - 0s - loss: 0.0027 - val_loss: 0.0235
# Epoch 56/185
# 5/5 - 0s - loss: 0.0024 - val_loss: 0.0230
# Epoch 57/185
# 5/5 - 0s - loss: 0.0025 - val_loss: 0.0236
# Epoch 58/185
# 5/5 - 0s - loss: 0.0039 - val_loss: 0.0234
# Epoch 59/185
# 5/5 - 0s - loss: 0.0048 - val_loss: 0.0310
# Epoch 60/185
# 5/5 - 0s - loss: 0.0094 - val_loss: 0.0536
# Epoch 61/185
# 5/5 - 0s - loss: 0.0035 - val_loss: 0.0238
# Epoch 62/185
# 5/5 - 0s - loss: 0.0034 - val_loss: 0.0247
# Epoch 63/185
# 5/5 - 0s - loss: 0.0045 - val_loss: 0.0270
# Epoch 64/185
# 5/5 - 0s - loss: 0.0037 - val_loss: 0.0273
# Epoch 65/185
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0329
# Epoch 66/185
# 5/5 - 0s - loss: 0.0027 - val_loss: 0.0232
# Epoch 67/185
# 5/5 - 0s - loss: 0.0020 - val_loss: 0.0256
# Epoch 68/185
# 5/5 - 0s - loss: 0.0020 - val_loss: 0.0227
# Epoch 69/185
# 5/5 - 0s - loss: 0.0023 - val_loss: 0.0233
# Epoch 70/185
# 5/5 - 0s - loss: 0.0024 - val_loss: 0.0252
# Epoch 71/185
# 5/5 - 0s - loss: 0.0020 - val_loss: 0.0222
# Epoch 72/185
# 5/5 - 0s - loss: 0.0021 - val_loss: 0.0224
# Epoch 73/185
# 5/5 - 0s - loss: 0.0019 - val_loss: 0.0220
# Epoch 74/185
# 5/5 - 0s - loss: 0.0018 - val_loss: 0.0224
# Epoch 75/185
# 5/5 - 0s - loss: 0.0018 - val_loss: 0.0215
# Epoch 76/185
# 5/5 - 0s - loss: 0.0019 - val_loss: 0.0219
# Epoch 77/185
# 5/5 - 0s - loss: 0.0021 - val_loss: 0.0210
# Epoch 78/185
# 5/5 - 0s - loss: 0.0022 - val_loss: 0.0246
# Epoch 79/185
# 5/5 - 0s - loss: 0.0037 - val_loss: 0.0223
# Epoch 80/185
# 5/5 - 0s - loss: 0.0047 - val_loss: 0.0340
# Epoch 81/185
# 5/5 - 0s - loss: 0.0094 - val_loss: 0.0657
# Epoch 82/185
# 5/5 - 0s - loss: 0.0035 - val_loss: 0.0254
# Epoch 83/185
# 5/5 - 0s - loss: 0.0046 - val_loss: 0.0246
# Epoch 84/185
# 5/5 - 0s - loss: 0.0071 - val_loss: 0.0501
# Epoch 85/185
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0290
# Epoch 86/185
# 5/5 - 0s - loss: 0.0034 - val_loss: 0.0251
# Epoch 87/185
# 5/5 - 0s - loss: 0.0034 - val_loss: 0.0237
# Epoch 88/185
# 5/5 - 0s - loss: 0.0029 - val_loss: 0.0258
# Epoch 89/185
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0305
# Epoch 90/185
# 5/5 - 0s - loss: 0.0029 - val_loss: 0.0222
# Epoch 91/185
# 5/5 - 0s - loss: 0.0024 - val_loss: 0.0244
# Epoch 92/185
# 5/5 - 0s - loss: 0.0017 - val_loss: 0.0216
# Epoch 93/185
# 5/5 - 0s - loss: 0.0018 - val_loss: 0.0227
# Epoch 94/185
# 5/5 - 0s - loss: 0.0018 - val_loss: 0.0215
# Epoch 95/185
# 5/5 - 0s - loss: 0.0016 - val_loss: 0.0216
# Epoch 96/185
# 5/5 - 0s - loss: 0.0020 - val_loss: 0.0211
# Epoch 97/185
# 5/5 - 0s - loss: 0.0018 - val_loss: 0.0213
# Epoch 98/185
# 5/5 - 0s - loss: 0.0018 - val_loss: 0.0213
# Epoch 99/185
# 5/5 - 0s - loss: 0.0019 - val_loss: 0.0223
# Epoch 100/185
# 5/5 - 0s - loss: 0.0018 - val_loss: 0.0210
# Epoch 101/185
# 5/5 - 0s - loss: 0.0025 - val_loss: 0.0224
# Epoch 102/185
# 5/5 - 0s - loss: 0.0045 - val_loss: 0.0274
# Epoch 103/185
# 5/5 - 0s - loss: 0.0038 - val_loss: 0.0227
# Epoch 104/185
# 5/5 - 0s - loss: 0.0048 - val_loss: 0.0319
# Epoch 105/185
# 5/5 - 0s - loss: 0.0027 - val_loss: 0.0243
# Epoch 106/185
# 5/5 - 0s - loss: 0.0028 - val_loss: 0.0300
# Epoch 107/185
# 5/5 - 0s - loss: 0.0020 - val_loss: 0.0237
# Epoch 108/185
# 5/5 - 0s - loss: 0.0021 - val_loss: 0.0260
# Epoch 109/185
# 5/5 - 0s - loss: 0.0017 - val_loss: 0.0222
# Epoch 110/185
# 5/5 - 0s - loss: 0.0020 - val_loss: 0.0239
# Epoch 111/185
# 5/5 - 0s - loss: 0.0015 - val_loss: 0.0216
# Epoch 112/185
# 5/5 - 0s - loss: 0.0019 - val_loss: 0.0219
# Epoch 113/185
# 5/5 - 0s - loss: 0.0017 - val_loss: 0.0215
# Epoch 114/185
# 5/5 - 0s - loss: 0.0017 - val_loss: 0.0216
# Epoch 115/185
# 5/5 - 0s - loss: 0.0015 - val_loss: 0.0215
# Epoch 116/185
# 5/5 - 0s - loss: 0.0022 - val_loss: 0.0210
# Epoch 117/185
# 5/5 - 0s - loss: 0.0030 - val_loss: 0.0243
# Epoch 118/185
# 5/5 - 0s - loss: 0.0043 - val_loss: 0.0265
# Epoch 119/185
# 5/5 - 0s - loss: 0.0037 - val_loss: 0.0229
# Epoch 120/185
# 5/5 - 0s - loss: 0.0051 - val_loss: 0.0362
# Epoch 121/185
# 5/5 - 0s - loss: 0.0024 - val_loss: 0.0221
# Epoch 122/185
# 5/5 - 0s - loss: 0.0016 - val_loss: 0.0238
# Epoch 123/185
# 5/5 - 0s - loss: 0.0021 - val_loss: 0.0261
# Epoch 124/185
# 5/5 - 0s - loss: 0.0020 - val_loss: 0.0221
# Epoch 125/185
# 5/5 - 0s - loss: 0.0017 - val_loss: 0.0219
# Epoch 126/185
# 5/5 - 0s - loss: 0.0017 - val_loss: 0.0230
# Epoch 127/185
# 5/5 - 0s - loss: 0.0014 - val_loss: 0.0211
# Epoch 128/185
# 5/5 - 0s - loss: 0.0018 - val_loss: 0.0215
# Epoch 129/185
# 5/5 - 0s - loss: 0.0017 - val_loss: 0.0218
# Epoch 130/185
# 5/5 - 0s - loss: 0.0016 - val_loss: 0.0210
# Epoch 131/185
# 5/5 - 0s - loss: 0.0016 - val_loss: 0.0212
# Epoch 132/185
# 5/5 - 0s - loss: 0.0015 - val_loss: 0.0214
# Epoch 133/185
# 5/5 - 0s - loss: 0.0017 - val_loss: 0.0209
# Epoch 134/185
# 5/5 - 0s - loss: 0.0018 - val_loss: 0.0222
# Epoch 135/185
# 5/5 - 0s - loss: 0.0030 - val_loss: 0.0262
# Epoch 136/185
# 5/5 - 0s - loss: 0.0029 - val_loss: 0.0213
# Epoch 137/185
# 5/5 - 0s - loss: 0.0026 - val_loss: 0.0263
# Epoch 138/185
# 5/5 - 0s - loss: 0.0023 - val_loss: 0.0215
# Epoch 139/185
# 5/5 - 0s - loss: 0.0019 - val_loss: 0.0216
# Epoch 140/185
# 5/5 - 0s - loss: 0.0022 - val_loss: 0.0221
# Epoch 141/185
# 5/5 - 0s - loss: 0.0034 - val_loss: 0.0295
# Epoch 142/185
# 5/5 - 0s - loss: 0.0028 - val_loss: 0.0214
# Epoch 143/185
# 5/5 - 0s - loss: 0.0027 - val_loss: 0.0287
# Epoch 144/185
# 5/5 - 0s - loss: 0.0019 - val_loss: 0.0215
# Epoch 145/185
# 5/5 - 0s - loss: 0.0013 - val_loss: 0.0222
# Epoch 146/185
# 5/5 - 0s - loss: 0.0018 - val_loss: 0.0224
# Epoch 147/185
# 5/5 - 0s - loss: 0.0017 - val_loss: 0.0213
# Epoch 148/185
# 5/5 - 0s - loss: 0.0016 - val_loss: 0.0210
# Epoch 149/185
# 5/5 - 0s - loss: 0.0014 - val_loss: 0.0222
# Epoch 150/185
# 5/5 - 0s - loss: 0.0013 - val_loss: 0.0213
# Epoch 151/185
# 5/5 - 0s - loss: 0.0017 - val_loss: 0.0228
# Epoch 152/185
# 5/5 - 0s - loss: 0.0020 - val_loss: 0.0212
# Epoch 153/185
# 5/5 - 0s - loss: 0.0020 - val_loss: 0.0223
# Epoch 154/185
# 5/5 - 0s - loss: 0.0027 - val_loss: 0.0240
# Epoch 155/185
# 5/5 - 0s - loss: 0.0028 - val_loss: 0.0222
# Epoch 156/185
# 5/5 - 0s - loss: 0.0045 - val_loss: 0.0370
# Epoch 157/185
# 5/5 - 0s - loss: 0.0031 - val_loss: 0.0211
# Epoch 158/185
# 5/5 - 0s - loss: 0.0013 - val_loss: 0.0213
# Epoch 159/185
# 5/5 - 0s - loss: 0.0031 - val_loss: 0.0294
# Epoch 160/185
# 5/5 - 0s - loss: 0.0042 - val_loss: 0.0223
# Epoch 161/185
# 5/5 - 0s - loss: 0.0016 - val_loss: 0.0267
# Epoch 162/185
# 5/5 - 0s - loss: 0.0022 - val_loss: 0.0235
# Epoch 163/185
# 5/5 - 0s - loss: 0.0024 - val_loss: 0.0208
# Epoch 164/185
# 5/5 - 0s - loss: 0.0022 - val_loss: 0.0216
# Epoch 165/185
# 5/5 - 0s - loss: 0.0029 - val_loss: 0.0207
# Epoch 166/185
# 5/5 - 0s - loss: 0.0043 - val_loss: 0.0297
# Epoch 167/185
# 5/5 - 0s - loss: 0.0072 - val_loss: 0.0355
# Epoch 168/185
# 5/5 - 0s - loss: 0.0031 - val_loss: 0.0221
# Epoch 169/185
# 5/5 - 0s - loss: 0.0041 - val_loss: 0.0324
# Epoch 170/185
# 5/5 - 0s - loss: 0.0021 - val_loss: 0.0222
# Epoch 171/185
# 5/5 - 0s - loss: 0.0016 - val_loss: 0.0252
# Epoch 172/185
# 5/5 - 0s - loss: 0.0018 - val_loss: 0.0217
# Epoch 173/185
# 5/5 - 0s - loss: 0.0016 - val_loss: 0.0218
# Epoch 174/185
# 5/5 - 0s - loss: 0.0018 - val_loss: 0.0223
# Epoch 175/185
# 5/5 - 0s - loss: 0.0018 - val_loss: 0.0207
# Epoch 176/185
# 5/5 - 0s - loss: 0.0014 - val_loss: 0.0206
# Epoch 177/185
# 5/5 - 0s - loss: 0.0013 - val_loss: 0.0206
# Epoch 178/185
# 5/5 - 0s - loss: 0.0016 - val_loss: 0.0205
# Epoch 179/185
# 5/5 - 0s - loss: 0.0017 - val_loss: 0.0206
# Epoch 180/185
# 5/5 - 0s - loss: 0.0023 - val_loss: 0.0218
# Epoch 181/185
# 5/5 - 0s - loss: 0.0024 - val_loss: 0.0243
# Epoch 182/185
# 5/5 - 0s - loss: 0.0047 - val_loss: 0.0381
# Epoch 183/185
# 5/5 - 0s - loss: 0.0029 - val_loss: 0.0214
# Epoch 184/185
# 5/5 - 0s - loss: 0.0018 - val_loss: 0.0219
# Epoch 185/185
# 5/5 - 0s - loss: 0.0022 - val_loss: 0.0238

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()

# %%
plot_model(model, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 1, 130)            101790
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 130)            0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 1, 260)            305760
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 260)            0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 1, 260)            407160
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 260)            0
# _________________________________________________________________
# gru_3 (GRU)                  (None, 1, 260)            407160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 260)            0
# _________________________________________________________________
# gru_4 (GRU)                  (None, 1, 260)            407160
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 260)            0
# _________________________________________________________________
# gru_5 (GRU)                  (None, 1, 260)            407160
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1, 260)            0
# _________________________________________________________________
# dense (Dense)                (None, 1, 1)              261
# =================================================================
# Total params: 2,036,451
# Trainable params: 2,036,451
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 4. Previsão para 2018 e 2019

# %%
# Realizando a predição


yhat = model.predict(test_X)
test_X_final = test_X.reshape(test_X.shape[0], test_X.shape[2])

# invertendo a normalização para apresentar a previsão



inv_yhat = np.concatenate((np.squeeze(yhat, axis=(2,)), test_X_final[:, :-1]), axis=1)

inv_yhat = inv_yhat[:,0]



test_y_final = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y_final, test_X_final[:, 1:]), axis=1)

inv_y = inv_y[:,0]


# Calculando RMSE e MAPE
rmse = math.sqrt(mean_squared_error(inv_y, inv_yhat))

mape = np.mean(np.abs((inv_y - inv_yhat) / test_y)) * 100
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.154

# %%
test_y_inv = scaler_out.inverse_transform(test_y_final)
yhat_final_inv = scaler_out.inverse_transform(np.squeeze(yhat, axis=(2,)))


df_data = pd.date_range('2018-01','2021-01', freq = 'm')

# Plota o valor observado vs previsto. 

plt.figure(figsize=(15,15))
plt.plot(test_y_inv, label='Esperado')
plt.plot(yhat_final_inv, label='Previsto GRU')
plt.legend()
plt.title('Teste GRU - MAPE: %.4f' % mape)
plt.xticks(np.arange(len(test_y_inv)),df_data.strftime('%m/%Y'), rotation='vertical')
plt.grid(True,axis='y')
plt.show()
